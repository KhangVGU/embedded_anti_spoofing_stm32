# %% [markdown]
# <a href="https://colab.research.google.com/github/KhangVGU/embedded_anti_spoofing_stm32/blob/main/calibration_schemes/RawGAT_ST_Quantization_original_eval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/
# !git clone https://github.com/eurecom-asp/RawGAT-ST-antispoofing.git
# Out:
# /content
# Cloning into 'RawGAT-ST-antispoofing'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 128 (delta 32), reused 84 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (128/128), 9.33 MiB | 9.13 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# %cd /content/RawGAT-ST-antispoofing
# !pip uninstall -y torch torchaudio numpy scipy
# !pip install torch==2.2.0 torchaudio==2.2.0 numpy==1.23.5 scipy==1.10.1
# !pip install torch torchaudio numpy scipy
# !pip install --upgrade soundfile onnx onnxscript onnxruntime
# Out:
# /content/RawGAT-ST-antispoofing
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.16.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 53.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 758.1 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Collecting onnx
#   Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting onnxscript
#   Downloading onnxscript-0.3.2-py3-none-any.whl.metadata (13 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.22.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from soundfile) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.11/dist-packages (from onnx) (5.29.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.11/dist-packages (from onnx) (4.14.1)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.11/dist-packages (from onnxscript) (0.5.3)
# Collecting onnx_ir<2,>=0.1.3 (from onnxscript)
#   Downloading onnx_ir-0.1.6-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxscript) (25.0)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (25.2.10)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.13.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime) (1.3.0)
# Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 104.2 MB/s eta 0:00:00
# Downloading onnxscript-0.3.2-py3-none-any.whl (667 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 667.4/667.4 kB 49.9 MB/s eta 0:00:00
# Downloading onnxruntime-1.22.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 24.0 MB/s eta 0:00:00
# Downloading onnx_ir-0.1.6-py3-none-any.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 12.8 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.4 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.3 MB/s eta 0:00:00
# Installing collected packages: onnx, humanfriendly, onnx_ir, coloredlogs, onnxscript, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnx-1.18.0 onnx_ir-0.1.6 onnxruntime-1.22.1 onnxscript-0.3.2

# %%
# %cd /content/
# !bash -c "wget -q https://www.dropbox.com/sh/gf3zp00qvdp3row/AABc-QK2BvzEPj-s8nBwCkMna/temp/asvspoof2021/toy_example.tar.gz && \
tar -xzf toy_example.tar.gz"
# Out:
# /content

# %%
# %cd /content/RawGAT-ST-antispoofing
# Colab: single-file inference for RawGAT_ST on a .flac audio
# Requirements
# !pip -q install torch torchaudio soundfile

import os
import math
import numpy as np
import soundfile as sf
import torch
import torch.nn.functional as F
import torchaudio

from model import RawGAT_ST  # uses your uploaded model.py

# ==== User inputs ====
AUDIO_PATH = "/content/toy_example/eval/LA_E_1066571.flac"            # <-- set your .flac path
MODEL_CKPT = "/content/RawGAT-ST-antispoofing/Pre_trained_models/RawGAT_ST_mul/Best_epoch.pth"           # <-- set your trained weights .pth, or leave as None
TARGET_SR  = 16000
FIXED_LEN  = 64600                              # model expects exactly this many samples (pad or crop)

# ==== Minimal model config matching model.py expectations ====
# These defaults are chosen to be consistent with the model’s forward-shape logic.
# If you trained with a different YAML, adjust values here to match your training config.
# d_args = {
#     "in_channels": 1,
#     "out_channels": 70,   # number of Sinc filters; model comments assume 70
#     "first_conv": 129,    # kernel size chosen so that 64600 -> 64472 after conv1d (no padding)
#     # Residual stacks keep channel size at 64 to match GAT input dims used in model.py
#     # Modified filts to match the checkpoint's expected channel sizes (32 instead of 64)
#     "filts": [32, [32, 32], [32, 64], [64, 64]],
# }
d_args = {
    "nb_samp": 64600,
    "out_channels": 70,
    "first_conv": 128,  # no. of filter coefficients
    "in_channels": 1,
    "filts": [32, [32, 32], [32, 64], [64, 64]],
    "blocks": [2, 4],
    "nb_classes": 2,
}

# ==== Utilities ====
def pad_or_crop(x: np.ndarray, max_len: int = FIXED_LEN) -> np.ndarray:
    """Pad by tiling or crop to fixed length, consistent with main.py::pad()."""
    x = x.astype(np.float32)
    x_len = x.shape[0]
    if x_len >= max_len:
        return x[:max_len]
    # tile to reach max_len
    num_repeats = int(max_len / x_len) + 1
    padded = np.tile(x, num_repeats)[:max_len]
    return padded

def load_audio_fixed_length(path: str, target_sr: int = TARGET_SR, fixed_len: int = FIXED_LEN) -> np.ndarray:
    wav, sr = sf.read(path, dtype="float32", always_2d=False)
    if wav.ndim > 1:
        # convert to mono
        wav = np.mean(wav, axis=1).astype(np.float32)
    if sr != target_sr:
        # resample with torchaudio for numerical stability
        wav_t = torch.from_numpy(wav).unsqueeze(0)  # shape [1, n]
        wav_rs = torchaudio.functional.resample(wav_t, orig_freq=sr, new_freq=target_sr)
        wav = wav_rs.squeeze(0).numpy()
    # normalize to prevent clipping extremes
    if np.max(np.abs(wav)) > 0:
        wav = wav / np.max(np.abs(wav))
    return pad_or_crop(wav, fixed_len)

# ==== Build model ====
device = "cuda" if torch.cuda.is_available() else "cpu"
model = RawGAT_ST(d_args, device=device).to(device)
model.eval()

# Optional: load trained checkpoint
if MODEL_CKPT and os.path.isfile(MODEL_CKPT):
    state = torch.load(MODEL_CKPT, map_location=device)
    # both state-dict formats supported
    if isinstance(state, dict) and "state_dict" in state:
        state = state["state_dict"]
    model.load_state_dict(state)
    print(f"Loaded checkpoint: {MODEL_CKPT}")
else:
    if MODEL_CKPT:
        print(f"Warning: checkpoint not found at {MODEL_CKPT}. Proceeding with random weights.")

# ==== Inference on a single .flac ====
assert os.path.isfile(AUDIO_PATH), f"Audio not found: {AUDIO_PATH}"
x = load_audio_fixed_length(AUDIO_PATH, TARGET_SR, FIXED_LEN)  # np.float32 [64600]

# model expects shape [B, T] with T=64600
x_t = torch.from_numpy(x).unsqueeze(0).to(device)  # [1, 64600]

with torch.no_grad():
    logits = model(x_t, Freq_aug=False)            # [1, 2]
    probs  = F.softmax(logits, dim=1).squeeze(0).cpu().numpy()  # [2]

# By convention in your training/eval code: index 1 corresponds to bonafide
prob_spoof     = float(probs[0])
prob_bonafide  = float(probs[1])
pred_label     = "bonafide" if prob_bonafide >= 0.5 else "spoof"

print(f"File: {AUDIO_PATH}")
print(f"Probability — spoof: {prob_spoof:.4f}, bonafide: {prob_bonafide:.4f}")
print(f"Predicted label: {pred_label}")
# Out:
# /content/RawGAT-ST-antispoofing
# Loaded checkpoint: /content/RawGAT-ST-antispoofing/Pre_trained_models/RawGAT_ST_mul/Best_epoch.pth
# File: /content/toy_example/eval/LA_E_1066571.flac
# Probability — spoof: 0.0000, bonafide: 1.0000
# Predicted label: bonafide

# %%
# %cd /content/RawGAT-ST-antispoofing
# --- Patch & export RawGAT_ST to ONNX safely (avoids Tensor==bool) ---

import os, io, re, importlib, json
import torch
import torch.onnx

# 1) Patch model.py to avoid "== True"/"== False" on any variable that could be a Tensor
#    and to keep boolean checks strictly Pythonic.
def patch_file(path, subs):
    with open(path, "r", encoding="utf-8") as f:
        txt = f.read()
    for pat, repl in subs:
        txt_new = re.sub(pat, repl, txt, flags=re.MULTILINE)
        txt = txt_new
    with open(path, "w", encoding="utf-8") as f:
        f.write(txt)

assert os.path.isfile("model.py"), "model.py not found in the current directory."

patches = [
    # In RawGAT_ST.forward: "if (Freq_aug==True):" -> "if Freq_aug:"
    (r"if\s*\(\s*Freq_aug\s*==\s*True\s*\)\s*:", "if Freq_aug:"),
    (r"if\s*\(\s*Freq_aug\s*==\s*False\s*\)\s*:", "if not Freq_aug:"),
    # In CONV.forward: "if (mask==True):" -> "if mask:"
    (r"if\s*\(\s*mask\s*==\s*True\s*\)\s*:", "if mask:"),
    (r"if\s*\(\s*mask\s*==\s*False\s*\)\s*:", "if not mask:"),
]
patch_file("model.py", patches)

# 2) Reload the model class
from importlib import reload
import model as model_mod
reload(model_mod)
from model import RawGAT_ST

# 3) Build model (adjust d_args to match your training config if needed)
d_args = {
    "nb_samp": 64600,
    "out_channels": 70,
    "first_conv": 128,  # no. of filter coefficients
    "in_channels": 1,
    "filts": [32, [32, 32], [32, 64], [64, 64]],
    "blocks": [2, 4],
    "nb_classes": 2,
}

device = "cuda" if torch.cuda.is_available() else "cpu"
model = RawGAT_ST(d_args, device=device).to(device)
model.eval()

# Optional: load your checkpoint
MODEL_CKPT = "/content/RawGAT-ST-antispoofing/Pre_trained_models/RawGAT_ST_mul/Best_epoch.pth"  # set your path or leave None
if MODEL_CKPT and os.path.isfile(MODEL_CKPT):
    state = torch.load(MODEL_CKPT, map_location=device)
    if isinstance(state, dict) and "state_dict" in state:
        state = state["state_dict"]
    model.load_state_dict(state)
    print(f"Loaded checkpoint: {MODEL_CKPT}")

# 4) Sanity forward with a fixed-length dummy input (your training uses 64600 samples)
dummy_input = torch.randn(1, 64600, dtype=torch.float32, device=device)
with torch.no_grad():
    _ = model(dummy_input, Freq_aug=False)
print("Forward pass ok.")

# 5) Export to ONNX
onnx_path = "/content/rawgat_st.onnx"
torch.onnx.export(
    model,
    dummy_input,
    onnx_path,
    export_params=True,
    do_constant_folding=False,   # safer when custom NumPy/Torch mixes exist
    opset_version=13,            # increase only if you need newer ops
    input_names=["input"],
    output_names=["logits"],
    dynamic_axes={"input": {1: "num_samples"}},  # allow variable-length waveforms
    training=torch.onnx.TrainingMode.EVAL,
    verbose=False
)
print(f"Exported ONNX: {onnx_path}")
# Out:
# /content/RawGAT-ST-antispoofing
# Loaded checkpoint: /content/RawGAT-ST-antispoofing/Pre_trained_models/RawGAT_ST_mul/Best_epoch.pth
# Forward pass ok.
# /content/RawGAT-ST-antispoofing/model.py:375: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if Freq_aug:
# /content/RawGAT-ST-antispoofing/model.py:209: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.band_pass[i,:]=Tensor(np.hamming(self.kernel_size))*Tensor(hideal)
# /content/RawGAT-ST-antispoofing/model.py:138: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   _, idx = torch.topk(scores, max(2, int(k*num_nodes)),dim=1)
# /content/RawGAT-ST-antispoofing/model.py:142: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   new_g.append(H[i,idx[i][:int(len(idx[i]))],:])
# Exported ONNX: /content/rawgat_st.onnx

# %%
# %cd /content/
# Colab cell: Inference with exported RawGAT_ST ONNX model
# !pip -q install onnxruntime soundfile torchaudio

import onnxruntime as ort
import numpy as np
import soundfile as sf
import torchaudio
import torch

# ==== User settings ====
ONNX_PATH   = "/content/rawgat_st.onnx"   # exported ONNX model path
AUDIO_PATH  = "/content/toy_example/eval/LA_E_1066571.flac"     # path to .flac file for inference
TARGET_SR   = 16000
FIXED_LEN   = 64600   # must match training/inference padding in your original PyTorch code

# ==== Utility functions ====
def pad_or_crop(x: np.ndarray, max_len: int = FIXED_LEN) -> np.ndarray:
    """Pad by tiling or crop to fixed length."""
    x = x.astype(np.float32)
    x_len = x.shape[0]
    if x_len >= max_len:
        return x[:max_len]
    num_repeats = int(max_len / x_len) + 1
    return np.tile(x, num_repeats)[:max_len]

def load_audio_fixed_length(path: str, target_sr: int, fixed_len: int) -> np.ndarray:
    """Load audio, convert to mono, resample, normalize, and pad/crop."""
    wav, sr = sf.read(path, dtype="float32", always_2d=False)
    if wav.ndim > 1:
        wav = np.mean(wav, axis=1)
    if sr != target_sr:
        wav_t = torch.from_numpy(wav).unsqueeze(0)
        wav_rs = torchaudio.functional.resample(wav_t, orig_freq=sr, new_freq=target_sr)
        wav = wav_rs.squeeze(0).numpy()
    if np.max(np.abs(wav)) > 0:
        wav = wav / np.max(np.abs(wav))
    return pad_or_crop(wav, fixed_len)

# ==== Load ONNX model ====
session = ort.InferenceSession(ONNX_PATH, providers=["CPUExecutionProvider"])
input_name = session.get_inputs()[0].name
output_name = session.get_outputs()[0].name

# ==== Prepare input ====
x = load_audio_fixed_length(AUDIO_PATH, TARGET_SR, FIXED_LEN)
x = np.expand_dims(x, axis=0).astype(np.float32)  # shape [1, 64600]

# ==== Run inference ====
logits = session.run([output_name], {input_name: x})[0]  # shape [1, 2]
probs = torch.softmax(torch.from_numpy(logits), dim=1).numpy()[0]

prob_spoof = float(probs[0])
prob_bonafide = float(probs[1])
pred_label = "bonafide" if prob_bonafide >= 0.5 else "spoof"

print(f"File: {AUDIO_PATH}")
print(f"Probability — spoof: {prob_spoof:.4f}, bonafide: {prob_bonafide:.4f}")
print(f"Predicted label: {pred_label}")
# Out:
# /content
# File: /content/toy_example/eval/LA_E_1066571.flac
# Probability — spoof: 0.0000, bonafide: 1.0000
# Predicted label: bonafide

# %%
# %cd /content/
# !python -m onnxruntime.quantization.preprocess --input rawgat_st.onnx --output rawgat_optimized.onnx --skip_symbolic_shape True
# Out:
# /content

# %%
# Colab cell: static quantization for 1D audio ONNX with correct input rank
# !pip -q install onnx onnxruntime onnxruntime-tools soundfile torchaudio

import os, glob, numpy as np, soundfile as sf, torch, torchaudio, onnx
import onnxruntime as ort
from onnxruntime.quantization import (
    quantize, QuantType, QuantFormat, StaticQuantConfig,
    CalibrationMethod, CalibrationDataReader
)

ONNX_FP32 = "/content/rawgat_optimized.onnx"           # your exported model
ONNX_INT8 = "/content/rawgat_st_int8.onnx"
CALIB_DIR = "/content/toy_example/train_dev"               # folder with a few .flac samples
TARGET_SR  = 16000
FIXED_LEN  = 64600

# 1) Inspect model I/O
sess = ort.InferenceSession(ONNX_FP32, providers=["CPUExecutionProvider"])
inp = sess.get_inputs()[0]
input_name = inp.name
print("Input name:", input_name)
print("Input type:", inp.type)
print("Input shape (may contain None for dynamic):", inp.shape)

# 2) Audio preprocessing that matches your PyTorch inference
def pad_or_crop(x: np.ndarray, L: int) -> np.ndarray:
    x = x.astype(np.float32)
    if x.shape[0] >= L:
        return x[:L]
    reps = int(L / x.shape[0]) + 1
    return np.tile(x, reps)[:L]

def load_audio_fixed_length(path: str, target_sr: int, fixed_len: int) -> np.ndarray:
    wav, sr = sf.read(path, dtype="float32", always_2d=False)
    if wav.ndim > 1:
        wav = np.mean(wav, axis=1)
    if sr != target_sr:
        wav_t = torch.from_numpy(wav).unsqueeze(0)
        wav_rs = torchaudio.functional.resample(wav_t, orig_freq=sr, new_freq=target_sr)
        wav = wav_rs.squeeze(0).numpy()
    m = np.max(np.abs(wav))
    if m > 0:
        wav = wav / m
    return pad_or_crop(wav, fixed_len)

# 3) CalibrationDataReader that yields rank-2 input: [1, num_samples]
class FixedLengthAudioReader(CalibrationDataReader):
    def __init__(self, audio_folder: str, input_name: str, target_sr: int = 16000, fixed_len: int = 64600):
        self.input_name = input_name
        self.files = sorted([p for p in glob.glob(os.path.join(audio_folder, "*.flac"))])
        self.target_sr = target_sr
        self.fixed_len = fixed_len
        self._iter = iter(self.files)

    def get_next(self):
        try:
            p = next(self._iter)
        except StopIteration:
            return None
        x = load_audio_fixed_length(p, self.target_sr, self.fixed_len)      # shape [L]
        x = np.expand_dims(x.astype(np.float32), axis=0)                     # shape [1, L]
        return {self.input_name: x}

# 4) Create reader
reader = FixedLengthAudioReader(CALIB_DIR, input_name, TARGET_SR, FIXED_LEN)

# 5) Static quantization configuration
# conf = StaticQuantConfig(
#     calibration_method=CalibrationMethod.Entropy,  # or MinMax, Percentile
#     activation_type=QuantType.QInt8,
#     weight_type=QuantType.QInt8,
#     quant_format=QuantFormat.QDQ,
#     per_channel=True,
#     # You can restrict ops if needed:
#     # op_types_to_quantize=["Conv", "MatMul", "Gemm"]
# )
conf = StaticQuantConfig(
    calibration_data_reader=reader,
    quant_format=QuantFormat.QDQ,
    calibrate_method=CalibrationMethod.MinMax,
    # calibration_providers='CUDAExecutionProvider',
    # optimize_model=True, # Removed unsupported argument
    activation_type=QuantType.QUInt8,
    weight_type=QuantType.QInt8,
    per_channel=True,
    extra_options={"ActivationSymmetric":False,
                  "WeightSymmetric":True}
)

# 6) Run quantization
quantize(
    model_input=ONNX_FP32,
    model_output=ONNX_INT8,
    quant_config=conf
    # calibration_data_reader=reader
)
print(f"Quantized model saved to {ONNX_INT8}")

# 7) Sanity check a forward pass on the quantized model
qsess = ort.InferenceSession(ONNX_INT8, providers=["CPUExecutionProvider"])
x = np.random.randn(1, FIXED_LEN).astype(np.float32)
_ = qsess.run([qsess.get_outputs()[0].name], {input_name: x})
print("Quantized model inference ok.")
# Out:
# Input name: input
# Input type: tensor(float)
# Input shape (may contain None for dynamic): [1, 'num_samples']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-653186745.py in <cell line: 0>()
#      89
#      90 # 6) Run quantization
# ---> 91 quantize(
#      92     model_input=ONNX_FP32,
#      93     model_output=ONNX_INT8,
#
# /usr/local/lib/python3.11/dist-packages/onnxruntime/quantization/quantize.py in quantize(model_input, model_output, quant_config)
#     897     """
#     898     if isinstance(quant_config, StaticQuantConfig):
# --> 899         quantize_static(
#     900             model_input,
#     901             model_output,
#
# /usr/local/lib/python3.11/dist-packages/onnxruntime/quantization/quantize.py in quantize_static(model_input, model_output, calibration_data_reader, quant_format, op_types_to_quantize, per_channel, reduce_range, activation_type, weight_type, nodes_to_quantize, nodes_to_exclude, use_external_data_format, calibrate_method, calibration_providers, extra_options)
#     732                 calibrator.collect_data(calibration_data_reader)
#     733         else:
# --> 734             calibrator.collect_data(calibration_data_reader)
#     735         tensors_range = calibrator.compute_data()
#     736         if not isinstance(tensors_range, TensorsData):
#
# /usr/local/lib/python3.11/dist-packages/onnxruntime/quantization/calibrate.py in collect_data(self, data_reader)
#     426
#     427         if len(self.intermediate_outputs) == 0 and self.calibrate_tensors_range is None:
# --> 428             raise ValueError("No data is collected.")
#     429
#     430         t = self.compute_data()
#
# ValueError: No data is collected.

# %%
# %cd /content/
# Colab cell: Inference with exported RawGAT_ST ONNX model
# !pip -q install onnxruntime soundfile torchaudio

import onnxruntime as ort
import numpy as np
import soundfile as sf
import torchaudio
import torch

# ==== User settings ====
ONNX_PATH   = "/content/rawgat_st_int8.onnx"   # exported ONNX model path
AUDIO_PATH  = "/content/toy_example/eval/LA_E_1066571.flac"     # path to .flac file for inference
TARGET_SR   = 16000
FIXED_LEN   = 64600   # must match training/inference padding in your original PyTorch code

# ==== Utility functions ====
def pad_or_crop(x: np.ndarray, max_len: int = FIXED_LEN) -> np.ndarray:
    """Pad by tiling or crop to fixed length."""
    x = x.astype(np.float32)
    x_len = x.shape[0]
    if x_len >= max_len:
        return x[:max_len]
    num_repeats = int(max_len / x_len) + 1
    return np.tile(x, num_repeats)[:max_len]

def load_audio_fixed_length(path: str, target_sr: int, fixed_len: int) -> np.ndarray:
    """Load audio, convert to mono, resample, normalize, and pad/crop."""
    wav, sr = sf.read(path, dtype="float32", always_2d=False)
    if wav.ndim > 1:
        wav = np.mean(wav, axis=1)
    if sr != target_sr:
        wav_t = torch.from_numpy(wav).unsqueeze(0)
        wav_rs = torchaudio.functional.resample(wav_t, orig_freq=sr, new_freq=target_sr)
        wav = wav_rs.squeeze(0).numpy()
    if np.max(np.abs(wav)) > 0:
        wav = wav / np.max(np.abs(wav))
    return pad_or_crop(wav, fixed_len)

# ==== Load ONNX model ====
session = ort.InferenceSession(ONNX_PATH, providers=["CPUExecutionProvider"])
input_name = session.get_inputs()[0].name
output_name = session.get_outputs()[0].name

# ==== Prepare input ====
x = load_audio_fixed_length(AUDIO_PATH, TARGET_SR, FIXED_LEN)
x = np.expand_dims(x, axis=0).astype(np.float32)  # shape [1, 64600]

# ==== Run inference ====
logits = session.run([output_name], {input_name: x})[0]  # shape [1, 2]
probs = torch.softmax(torch.from_numpy(logits), dim=1).numpy()[0]

prob_spoof = float(probs[0])
prob_bonafide = float(probs[1])
pred_label = "bonafide" if prob_bonafide >= 0.5 else "spoof"

print(f"File: {AUDIO_PATH}")
print(f"Probability — spoof: {prob_spoof:.4f}, bonafide: {prob_bonafide:.4f}")
print(f"Predicted label: {pred_label}")
# Out:
# /content
# File: /content/toy_example/eval/LA_E_1066571.flac
# Probability — spoof: 0.1298, bonafide: 0.8702
# Predicted label: bonafide

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Colab cell: static quantization for 1D audio ONNX with correct input rank
# !pip -q install onnx onnxruntime onnxruntime-tools soundfile torchaudio

import os, glob, numpy as np, soundfile as sf, torch, torchaudio, onnx
import onnxruntime as ort
from onnxruntime.quantization import (
    quantize, QuantType, QuantFormat, StaticQuantConfig,
    CalibrationMethod, CalibrationDataReader
)

ONNX_FP32 = "/content/rawgat_optimized.onnx"           # your exported model
ONNX_INT8 = "/content/drive/MyDrive/Researches/Anti_spoofing/rawgat-st/rawgat_int8_scheme_8.onnx"
CALIB_DIR = "/content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Calibration_8_eval_150_random"               # folder with a few .flac samples
TARGET_SR  = 16000
FIXED_LEN  = 64600

# 1) Inspect model I/O
sess = ort.InferenceSession(ONNX_FP32, providers=["CPUExecutionProvider"])
inp = sess.get_inputs()[0]
input_name = inp.name
print("Input name:", input_name)
print("Input type:", inp.type)
print("Input shape (may contain None for dynamic):", inp.shape)

# 2) Audio preprocessing that matches your PyTorch inference
def pad_or_crop(x: np.ndarray, L: int) -> np.ndarray:
    x = x.astype(np.float32)
    if x.shape[0] >= L:
        return x[:L]
    reps = int(L / x.shape[0]) + 1
    return np.tile(x, reps)[:L]

def load_audio_fixed_length(path: str, target_sr: int, fixed_len: int) -> np.ndarray:
    wav, sr = sf.read(path, dtype="float32", always_2d=False)
    if wav.ndim > 1:
        wav = np.mean(wav, axis=1)
    if sr != target_sr:
        wav_t = torch.from_numpy(wav).unsqueeze(0)
        wav_rs = torchaudio.functional.resample(wav_t, orig_freq=sr, new_freq=target_sr)
        wav = wav_rs.squeeze(0).numpy()
    m = np.max(np.abs(wav))
    if m > 0:
        wav = wav / m
    return pad_or_crop(wav, fixed_len)

# 3) CalibrationDataReader that yields rank-2 input: [1, num_samples]
class FixedLengthAudioReader(CalibrationDataReader):
    def __init__(self, audio_folder: str, input_name: str, target_sr: int = 16000, fixed_len: int = 64600):
        self.input_name = input_name
        self.files = sorted([p for p in glob.glob(os.path.join(audio_folder, "*.flac"))])
        self.target_sr = target_sr
        self.fixed_len = fixed_len
        self._iter = iter(self.files)

    def get_next(self):
        try:
            p = next(self._iter)
        except StopIteration:
            return None
        x = load_audio_fixed_length(p, self.target_sr, self.fixed_len)      # shape [L]
        x = np.expand_dims(x.astype(np.float32), axis=0)                     # shape [1, L]
        return {self.input_name: x}

# 4) Create reader
reader = FixedLengthAudioReader(CALIB_DIR, input_name, TARGET_SR, FIXED_LEN)

# 5) Static quantization configuration
# conf = StaticQuantConfig(
#     calibration_method=CalibrationMethod.Entropy,  # or MinMax, Percentile
#     activation_type=QuantType.QInt8,
#     weight_type=QuantType.QInt8,
#     quant_format=QuantFormat.QDQ,
#     per_channel=True,
#     # You can restrict ops if needed:
#     # op_types_to_quantize=["Conv", "MatMul", "Gemm"]
# )
conf = StaticQuantConfig(
    calibration_data_reader=reader,
    quant_format=QuantFormat.QDQ,
    calibrate_method=CalibrationMethod.MinMax,
    # calibration_providers='CUDAExecutionProvider',
    # optimize_model=True, # Removed unsupported argument
    activation_type=QuantType.QUInt8,
    weight_type=QuantType.QInt8,
    per_channel=True,
    extra_options={"ActivationSymmetric":False,
                  "WeightSymmetric":True}
)

# 6) Run quantization
quantize(
    model_input=ONNX_FP32,
    model_output=ONNX_INT8,
    quant_config=conf
    # calibration_data_reader=reader
)
print(f"Quantized model saved to {ONNX_INT8}")
# Out:
# Input name: input
# Input type: tensor(float)
# Input shape (may contain None for dynamic): [1, 'num_samples']
# WARNING:root:Axis 1 is out-of-range for weight 'first_bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'GAT_layer1.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'GAT_layer2.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'GAT_layer3.bn.weight' with rank 1
# Quantized model saved to /content/drive/MyDrive/Researches/Anti_spoofing/rawgat-st/rawgat_int8_scheme_8.onnx

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/rawgat_st.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_orignial.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=421, TN=65, FP=0, FN=14
# Accuracy: 0.9720
# FPR: 0.0000   FNR: 0.0322   EER: 0.0161
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_orignial.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/rawgat_int8_scheme_9.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_scheme9.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=435, TN=0, FP=65, FN=0
# Accuracy: 0.8700
# FPR: 1.0000   FNR: 0.0000   EER: 0.5000
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_scheme9.png

# %%
# ============================================
# RawGAT (model.py) — First layer max-over-time per channel, for a folder
# ============================================

# 0) Optional installs
# !pip -q install soundfile scipy matplotlib

import os
import math
import json
import numpy as np
import torch
import soundfile as sf
import matplotlib.pyplot as plt
from scipy.signal import resample
from typing import List, Tuple

from model import RawGAT_ST  # requires model.py in current directory

# 1) Paths
AUDIO_FOLDER       = "/content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Calibration_1_bonafide_100"   # folder with .flac files
CHECKPOINT_PATH    = "/content/RawGAT-ST-antispoofing/Pre_trained_models/RawGAT_ST_mul/Best_epoch.pth"         # your RawGAT weights (.pth) or set to None
SAVE_CSV           = False
CSV_PATH           = "/content/first_layer_channelwise_max_rawgat.csv"

# 2) Options
SAMPLE_RATE        = 16000
BATCH_SIZE_MAX     = 16         # micro-batch size
BUCKET_TOL         = 2.0        # files in a bucket have length within 2x
PER_FILE_MASK      = False      # True = independent freq mask per file when Freq_aug=True
FREQ_AUG_FLAG      = False      # keep False for analysis; set True to enable conv masking
NORMALIZE_PER_FILE = False      # True = L2-normalize each vector before plotting
SHOW_LEGEND        = False      # enable only when few files

# 3) RawGAT d_args (adjust to match your training config)
d_args = {
    "nb_samp": 64600,
    "out_channels": 70,
    "first_conv": 128,  # no. of filter coefficients
    "in_channels": 1,
    "filts": [32, [32, 32], [32, 64], [64, 64]],
    "blocks": [2, 4],
    "nb_classes": 2,
}

# 4) Utilities
def load_audio(path: str, target_sr: int = 16000) -> np.ndarray:
    wav, sr = sf.read(path, dtype="float32", always_2d=False)
    if wav.ndim == 2:
        wav = wav.mean(axis=1)
    if sr != target_sr:
        num = int(len(wav) * float(target_sr) / sr)
        wav = resample(wav, num).astype(np.float32)
    return wav.astype(np.float32)

def list_flacs_with_lengths(folder: str) -> List[Tuple[str, int]]:
    files = [f for f in os.listdir(folder) if f.lower().endswith(".flac")]
    files.sort()
    out = []
    for f in files:
        try:
            info = sf.info(os.path.join(folder, f))
            out.append((f, int(info.frames)))
        except Exception:
            wav = load_audio(os.path.join(folder, f), SAMPLE_RATE)
            out.append((f, len(wav)))
    out.sort(key=lambda x: x[1])
    return out

def conv1d_out_len(L: int, k: int, s: int = 1, p: int = 0, d: int = 1) -> int:
    return math.floor((L + 2*p - d*(k - 1) - 1)/s + 1)

# 5) Model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = RawGAT_ST(d_args, device=device).to(device)
if CHECKPOINT_PATH and os.path.isfile(CHECKPOINT_PATH):
    ckpt = torch.load(CHECKPOINT_PATH, map_location=device)
    state = ckpt.get("state_dict", ckpt)
    model.load_state_dict(state, strict=False)
model.eval()
torch.set_grad_enabled(False)

# Effective kernel of first conv (RawGAT forces odd)
first_conv_cfg = int(d_args["first_conv"])
first_conv_eff = first_conv_cfg if first_conv_cfg % 2 == 1 else first_conv_cfg + 1

# 6) Build length buckets
pairs = list_flacs_with_lengths(AUDIO_FOLDER)
if not pairs:
    raise RuntimeError("No .flac files found in AUDIO_FOLDER")

batches = []
bucket = []
bucket_min = None
for fname, L in pairs:
    if not bucket:
        bucket = [(fname, L)]
        bucket_min = L
        continue
    if len(bucket) < BATCH_SIZE_MAX and L <= bucket_min * BUCKET_TOL:
        bucket.append((fname, L))
    else:
        batches.append(bucket)
        bucket = [(fname, L)]
        bucket_min = L
if bucket:
    batches.append(bucket)

print(f"Total files: {len(pairs)}  |  Buckets: {len(batches)}  |  Device: {device}")

# 7) Run first-layer conv and collect per-file channelwise maxima over time
all_names = []
all_vecs  = []  # each is [C_out]

with torch.no_grad():
    for b_idx, bucket in enumerate(batches, start=1):
        names = [x[0] for x in bucket]
        wavs  = [load_audio(os.path.join(AUDIO_FOLDER, nm), SAMPLE_RATE) for nm in names]
        max_len = max(len(w) for w in wavs)
        padded = [np.pad(w, (0, max_len - len(w))) if len(w) < max_len else w for w in wavs]
        x = torch.from_numpy(np.stack(padded)).unsqueeze(1).to(device)  # [B, 1, T_pad]
        B_local = x.shape[0]

        # Forward first conv; optional independent masking per file
        if PER_FILE_MASK and FREQ_AUG_FLAG:
            ys = []
            for i in range(B_local):
                ys.append(model.conv_time(x[i:i+1], mask=True))   # [1, C_out, T_out_pad]
            y = torch.cat(ys, dim=0)
        else:
            y = model.conv_time(x, mask=bool(FREQ_AUG_FLAG))      # [B, C_out, T_out_pad]

        _, C_out, T_out_pad = y.shape
        T_out_true = [max(0, conv1d_out_len(len(w), first_conv_eff, 1, 0, 1)) for w in wavs]

        for i, nm in enumerate(names):
            Tt = T_out_true[i]
            if Tt > 0:
                m = y[i, :, :Tt].abs().max(dim=1).values          # channelwise max over valid time
            else:
                m = torch.zeros(C_out, device=y.device)
            vec = m.detach().cpu().numpy()
            if NORMALIZE_PER_FILE:
                denom = np.linalg.norm(vec) + 1e-12
                vec = vec / denom
            all_names.append(nm)
            all_vecs.append(vec)

features = np.stack(all_vecs, axis=0)  # [N_files, C_out]
N_files, C_out = features.shape
print(f"Collected features shape: {features.shape}")

# 8) Plot
plt.figure(figsize=(12, 6))
x_axis = np.arange(C_out)
for i in range(N_files):
    plt.scatter(x_axis, features[i], s=15, alpha=0.6)
plt.title("RawGAT-ST first-layer channelwise max over time")
plt.xlabel("Channel index")
plt.ylabel("Max over time of activation")
plt.grid(True)
if SHOW_LEGEND and N_files <= 20:
    plt.legend([os.path.basename(n) for n in all_names], fontsize=8)
plt.show()

# 9) Optional CSV
if SAVE_CSV:
    import csv
    with open(CSV_PATH, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["filename"] + [f"ch_{c}" for c in range(C_out)])
        for nm, row in zip(all_names, features):
            writer.writerow([nm] + list(map(float, row)))
    print(f"Saved CSV to {CSV_PATH}")
# Out:
# Total files: 100  |  Buckets: 7  |  Device: cuda
# Collected features shape: (100, 70)

# %%
# ============================================
# RawGAT (model.py) — First layer max-over-time per channel, for a folder
# ============================================

# 0) Optional installs
# !pip -q install soundfile scipy matplotlib

import os
import math
import json
import numpy as np
import torch
import soundfile as sf
import matplotlib.pyplot as plt
from scipy.signal import resample
from typing import List, Tuple

from model import RawGAT_ST  # requires model.py in current directory

# 1) Paths
AUDIO_FOLDER       = "/content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations"   # folder with .flac files
CHECKPOINT_PATH    = "/content/RawGAT-ST-antispoofing/Pre_trained_models/RawGAT_ST_mul/Best_epoch.pth"         # your RawGAT weights (.pth) or set to None
SAVE_CSV           = False
CSV_PATH           = "/content/first_layer_channelwise_max_rawgat.csv"

# 2) Options
SAMPLE_RATE        = 16000
BATCH_SIZE_MAX     = 16         # micro-batch size
BUCKET_TOL         = 2.0        # files in a bucket have length within 2x
PER_FILE_MASK      = False      # True = independent freq mask per file when Freq_aug=True
FREQ_AUG_FLAG      = False      # keep False for analysis; set True to enable conv masking
NORMALIZE_PER_FILE = False      # True = L2-normalize each vector before plotting
SHOW_LEGEND        = False      # enable only when few files

# 3) RawGAT d_args (adjust to match your training config)
d_args = {
    "nb_samp": 64600,
    "out_channels": 70,
    "first_conv": 128,  # no. of filter coefficients
    "in_channels": 1,
    "filts": [32, [32, 32], [32, 64], [64, 64]],
    "blocks": [2, 4],
    "nb_classes": 2,
}

# 4) Utilities
def load_audio(path: str, target_sr: int = 16000) -> np.ndarray:
    wav, sr = sf.read(path, dtype="float32", always_2d=False)
    if wav.ndim == 2:
        wav = wav.mean(axis=1)
    if sr != target_sr:
        num = int(len(wav) * float(target_sr) / sr)
        wav = resample(wav, num).astype(np.float32)
    return wav.astype(np.float32)

def list_flacs_with_lengths(folder: str) -> List[Tuple[str, int]]:
    files = [f for f in os.listdir(folder) if f.lower().endswith(".flac")]
    files.sort()
    out = []
    for f in files:
        try:
            info = sf.info(os.path.join(folder, f))
            out.append((f, int(info.frames)))
        except Exception:
            wav = load_audio(os.path.join(folder, f), SAMPLE_RATE)
            out.append((f, len(wav)))
    out.sort(key=lambda x: x[1])
    return out

def conv1d_out_len(L: int, k: int, s: int = 1, p: int = 0, d: int = 1) -> int:
    return math.floor((L + 2*p - d*(k - 1) - 1)/s + 1)

# 5) Model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = RawGAT_ST(d_args, device=device).to(device)
if CHECKPOINT_PATH and os.path.isfile(CHECKPOINT_PATH):
    ckpt = torch.load(CHECKPOINT_PATH, map_location=device)
    state = ckpt.get("state_dict", ckpt)
    model.load_state_dict(state, strict=False)
model.eval()
torch.set_grad_enabled(False)

# Effective kernel of first conv (RawGAT forces odd)
first_conv_cfg = int(d_args["first_conv"])
first_conv_eff = first_conv_cfg if first_conv_cfg % 2 == 1 else first_conv_cfg + 1

# 6) Build length buckets
pairs = list_flacs_with_lengths(AUDIO_FOLDER)
if not pairs:
    raise RuntimeError("No .flac files found in AUDIO_FOLDER")

batches = []
bucket = []
bucket_min = None
for fname, L in pairs:
    if not bucket:
        bucket = [(fname, L)]
        bucket_min = L
        continue
    if len(bucket) < BATCH_SIZE_MAX and L <= bucket_min * BUCKET_TOL:
        bucket.append((fname, L))
    else:
        batches.append(bucket)
        bucket = [(fname, L)]
        bucket_min = L
if bucket:
    batches.append(bucket)

print(f"Total files: {len(pairs)}  |  Buckets: {len(batches)}  |  Device: {device}")

# 7) Run first-layer conv and collect per-file channelwise maxima over time
all_names = []
all_vecs  = []  # each is [C_out]

with torch.no_grad():
    for b_idx, bucket in enumerate(batches, start=1):
        names = [x[0] for x in bucket]
        wavs  = [load_audio(os.path.join(AUDIO_FOLDER, nm), SAMPLE_RATE) for nm in names]
        max_len = max(len(w) for w in wavs)
        padded = [np.pad(w, (0, max_len - len(w))) if len(w) < max_len else w for w in wavs]
        x = torch.from_numpy(np.stack(padded)).unsqueeze(1).to(device)  # [B, 1, T_pad]
        B_local = x.shape[0]

        # Forward first conv; optional independent masking per file
        if PER_FILE_MASK and FREQ_AUG_FLAG:
            ys = []
            for i in range(B_local):
                ys.append(model.conv_time(x[i:i+1], mask=True))   # [1, C_out, T_out_pad]
            y = torch.cat(ys, dim=0)
        else:
            y = model.conv_time(x, mask=bool(FREQ_AUG_FLAG))      # [B, C_out, T_out_pad]

        _, C_out, T_out_pad = y.shape
        T_out_true = [max(0, conv1d_out_len(len(w), first_conv_eff, 1, 0, 1)) for w in wavs]

        for i, nm in enumerate(names):
            Tt = T_out_true[i]
            if Tt > 0:
                m = y[i, :, :Tt].abs().max(dim=1).values          # channelwise max over valid time
            else:
                m = torch.zeros(C_out, device=y.device)
            vec = m.detach().cpu().numpy()
            if NORMALIZE_PER_FILE:
                denom = np.linalg.norm(vec) + 1e-12
                vec = vec / denom
            all_names.append(nm)
            all_vecs.append(vec)

features = np.stack(all_vecs, axis=0)  # [N_files, C_out]
N_files, C_out = features.shape
print(f"Collected features shape: {features.shape}")

# 8) Plot
plt.figure(figsize=(12, 6))
x_axis = np.arange(C_out)
for i in range(N_files):
    plt.scatter(x_axis, features[i], s=15, alpha=0.6)
plt.title("RawGAT-ST first-layer channelwise max over time")
plt.xlabel("Channel index")
plt.ylabel("Max over time of activation")
plt.grid(True)
if SHOW_LEGEND and N_files <= 20:
    plt.legend([os.path.basename(n) for n in all_names], fontsize=8)
plt.show()

# 9) Optional CSV
if SAVE_CSV:
    import csv
    with open(CSV_PATH, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["filename"] + [f"ch_{c}" for c in range(C_out)])
        for nm, row in zip(all_names, features):
            writer.writerow([nm] + list(map(float, row)))
    print(f"Saved CSV to {CSV_PATH}")
# Out:
# Total files: 500  |  Buckets: 32  |  Device: cuda
# Collected features shape: (500, 70)

# %%
# ============================================
# RawGAT (model.py) — Calibration data filter via first-layer maxima
# ============================================

# Optional installs
# !pip -q install soundfile scipy matplotlib

import os
import math
import shutil
import numpy as np
import torch
import soundfile as sf
import matplotlib.pyplot as plt
from scipy.signal import resample
from typing import List, Tuple

from model import RawGAT_ST  # requires model.py in the working directory

# 1) Paths
AUDIO_FOLDER   = "/content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations"  # reference set to fit thresholds
CHECKPOINT_PTH = "/content/RawGAT-ST-antispoofing/Pre_trained_models/RawGAT_ST_mul/Best_epoch.pth"               # RawGAT weights (.pth); set None to skip load
NEW_AUDIO      = None                                   # e.g. "/content/new.wav"
NEW_FOLDER     = "/content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Calibration_1_bonafide_100"  # folder to screen
OK_FOLDER      = "/content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Calibration_17_RawGAT"   # where OK files are copied

os.makedirs(OK_FOLDER, exist_ok=True)

# 2) Options
SAMPLE_RATE        = 16000
BATCH_SIZE_MAX     = 16
BUCKET_TOL         = 2.0
PER_FILE_MASK      = False        # True = independent frequency mask per file when freq augmentation is enabled
FREQ_AUG_FLAG      = False        # keep False for analysis
NORMALIZE_PER_FILE = False        # L2-normalize channelwise vector before scoring
SHOW_LEGEND        = False
K_STD_LINE         = 2.0          # overlay mean ± K*std lines on the scatter plot

# Anomaly thresholds
Z_THRESH     = 4.0                # any channel z-score above this flags as outlier
EUCL_PCTL    = 98.0               # Euclidean distance percentile threshold
MAHAL_PCTL   = 98.0               # Mahalanobis distance percentile threshold
MAHAL_RIDGE  = 1e-6               # covariance ridge regularizer

# 3) RawGAT configuration — adjust to match training
d_args = {
    "nb_samp": 64600,
    "out_channels": 70,
    "first_conv": 128,  # no. of filter coefficients
    "in_channels": 1,
    "filts": [32, [32, 32], [32, 64], [64, 64]],
    "blocks": [2, 4],
    "nb_classes": 2,
}

# ---------- Utilities ----------
def load_audio(path: str, target_sr: int = 16000) -> np.ndarray:
    wav, sr = sf.read(path, dtype="float32", always_2d=False)
    if wav.ndim == 2:
        wav = wav.mean(axis=1)
    if sr != target_sr:
        num = int(len(wav) * float(target_sr) / sr)
        wav = resample(wav, num).astype(np.float32)
    return wav.astype(np.float32)

def list_wavs_with_lengths(folder: str) -> List[Tuple[str, int]]:
    files = [f for f in os.listdir(folder) if f.lower().endswith((".flac", ".wav"))]
    files.sort()
    out = []
    for f in files:
        fpath = os.path.join(folder, f)
        try:
            info = sf.info(fpath)
            out.append((f, int(info.frames)))
        except Exception:
            wav = load_audio(fpath, SAMPLE_RATE)
            out.append((f, len(wav)))
    out.sort(key=lambda x: x[1])
    return out

def conv1d_out_len(L: int, k: int, s: int = 1, p: int = 0, d: int = 1) -> int:
    return math.floor((L + 2*p - d*(k - 1) - 1)/s + 1)

def compute_first_layer(model, x, freq_aug_flag: bool):
    return model.conv_time(x, mask=freq_aug_flag)

def channelwise_max_vector(y_sample: torch.Tensor, T_true: int, use_abs: bool = True):
    if T_true <= 0:
        return torch.zeros(y_sample.shape[0], device=y_sample.device)
    z = y_sample[:, :T_true]
    if use_abs:
        z = z.abs()
    return z.max(dim=1).values

def l2_normalize(v: np.ndarray, eps: float = 1e-12):
    n = np.linalg.norm(v)
    return v / (n + eps)

def mahalanobis(x: np.ndarray, mean: np.ndarray, cov_inv: np.ndarray) -> float:
    d = x - mean
    return float(d.T @ cov_inv @ d) ** 0.5

def cov_inverse(X: np.ndarray, ridge: float = 1e-6):
    mu = X.mean(axis=0, keepdims=True)
    Z = X - mu
    C = (Z.T @ Z) / max(1, X.shape[0] - 1)  # unbiased covariance
    C += ridge * np.eye(C.shape[0], dtype=C.dtype)
    return np.linalg.pinv(C)

# ---------- Load model ----------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = RawGAT_ST(d_args, device=device).to(device)
if CHECKPOINT_PTH and os.path.isfile(CHECKPOINT_PTH):
    ckpt = torch.load(CHECKPOINT_PTH, map_location=device)
    state = ckpt.get("state_dict", ckpt)
    model.load_state_dict(state, strict=False)
model.eval()
torch.set_grad_enabled(False)

# Effective first conv kernel size
first_conv_cfg = int(d_args["first_conv"])
first_conv_eff = first_conv_cfg if first_conv_cfg % 2 == 1 else first_conv_cfg + 1

# ---------- Build reference feature matrix ----------
pairs = list_wavs_with_lengths(AUDIO_FOLDER)
if not pairs:
    raise RuntimeError("No .flac or .wav files found in AUDIO_FOLDER")

# Bucketing by length to limit padding
batches, bucket, bucket_min = [], [], None
for fname, L in pairs:
    if not bucket:
        bucket, bucket_min = [(fname, L)], L
        continue
    if len(bucket) < BATCH_SIZE_MAX and L <= bucket_min * BUCKET_TOL:
        bucket.append((fname, L))
    else:
        batches.append(bucket)
        bucket, bucket_min = [(fname, L)], L
if bucket:
    batches.append(bucket)

print(f"Reference files: {len(pairs)}  |  Buckets: {len(batches)}  |  Device: {device}")

file_names_ref, feats_ref = [], []

with torch.no_grad():
    for bucket in batches:
        names = [x[0] for x in bucket]
        wavs  = [load_audio(os.path.join(AUDIO_FOLDER, nm), SAMPLE_RATE) for nm in names]
        max_len = max(len(w) for w in wavs)
        padded = [np.pad(w, (0, max_len - len(w))) if len(w) < max_len else w for w in wavs]
        x = torch.from_numpy(np.stack(padded)).unsqueeze(1).to(device)  # [B,1,T]
        B_local = x.shape[0]

        if PER_FILE_MASK and FREQ_AUG_FLAG:
            ys = []
            for i in range(B_local):
                ys.append(compute_first_layer(model, x[i:i+1], True))
            y = torch.cat(ys, dim=0)
        else:
            y = compute_first_layer(model, x, bool(FREQ_AUG_FLAG))  # [B,C_out,T_out]

        _, C_out, _ = y.shape
        T_out_true = [max(0, conv1d_out_len(len(w), first_conv_eff, 1, 0, 1)) for w in wavs]

        for i, nm in enumerate(names):
            vec = channelwise_max_vector(y[i], T_out_true[i], use_abs=True).detach().cpu().numpy()
            if NORMALIZE_PER_FILE:
                vec = l2_normalize(vec)
            file_names_ref.append(nm)
            feats_ref.append(vec)

features = np.stack(feats_ref, axis=0)  # [N_ref, C_out]
N_ref, C_out = features.shape
print(f"Reference feature matrix: {features.shape}")

# ---------- Reference statistics and thresholds ----------
mu = features.mean(axis=0)             # [C_out]
sigma = features.std(axis=0, ddof=1)   # [C_out]
sigma = np.maximum(sigma, 1e-12)

# Euclidean threshold
ref_eucl = np.linalg.norm(features - mu[None, :], axis=1)
eucl_thresh = float(np.percentile(ref_eucl, EUCL_PCTL))

# Mahalanobis threshold
cov_inv = cov_inverse(features, ridge=MAHAL_RIDGE)
ref_mahal = np.array([mahalanobis(x, mu, cov_inv) for x in features])
mahal_thresh = float(np.percentile(ref_mahal, MAHAL_PCTL))

print(f"Euclidean threshold (pctl {EUCL_PCTL}): {eucl_thresh:.6f}")
print(f"Mahalanobis threshold (pctl {MAHAL_PCTL}): {mahal_thresh:.6f}")
print(f"Channelwise z-score threshold: {Z_THRESH:.2f}")

# ---------- Visualization of reference set ----------
plt.figure(figsize=(12, 6))
x_axis = np.arange(C_out)
for i in range(N_ref):
    plt.scatter(x_axis, features[i], s=15, alpha=0.5)
plt.plot(x_axis, mu, linewidth=2.0, label="mean")
if K_STD_LINE and K_STD_LINE > 0:
    upper = mu + K_STD_LINE * sigma
    lower = np.clip(mu - K_STD_LINE * sigma, a_min=0, a_max=None)
    plt.plot(x_axis, upper, linewidth=1.5, label=f"mean + {K_STD_LINE}·std")
    plt.plot(x_axis, lower, linewidth=1.5, label=f"mean - {K_STD_LINE}·std (clipped)")
plt.title("RawGAT first-layer channelwise maxima — reference scatter and mean±k·std")
plt.xlabel("Channel index")
plt.ylabel("Max over time of activation")
plt.grid(True)
if SHOW_LEGEND:
    plt.legend()
plt.show()

# ---------- Scoring helpers ----------
def score_vector(vec: np.ndarray):
    v = l2_normalize(vec) if NORMALIZE_PER_FILE else vec.copy()
    z = (v - mu) / sigma
    z_flag = bool(np.any(z > Z_THRESH))
    eucl = float(np.linalg.norm(v - mu))
    mahal = float(mahalanobis(v, mu, cov_inv))
    return {
        "z_any_gt_thresh": z_flag,
        "euclidean": eucl,
        "euclidean_is_outlier": bool(eucl > eucl_thresh),
        "mahalanobis": mahal,
        "mahalanobis_is_outlier": bool(mahal > mahal_thresh),
    }

def extract_vec_for_path(p: str) -> np.ndarray:
    wav = load_audio(p, SAMPLE_RATE)
    T_in = len(wav)
    x = torch.from_numpy(wav).unsqueeze(0).unsqueeze(1).to(device)  # [1,1,T]
    y = compute_first_layer(model, x, bool(FREQ_AUG_FLAG))         # [1,C_out,T_out]
    T_true = max(0, conv1d_out_len(T_in, first_conv_eff, 1, 0, 1))
    vec = channelwise_max_vector(y[0], T_true, use_abs=True).detach().cpu().numpy()
    if NORMALIZE_PER_FILE:
        vec = l2_normalize(vec)
    return vec

# ---------- Build list of new items to screen ----------
new_paths = []
if isinstance(NEW_AUDIO, str) and os.path.isfile(NEW_AUDIO):
    new_paths.append(NEW_AUDIO)
if isinstance(NEW_FOLDER, str) and os.path.isdir(NEW_FOLDER):
    new_paths.extend([os.path.join(NEW_FOLDER, f)
                      for f in os.listdir(NEW_FOLDER)
                      if f.lower().endswith((".flac", ".wav"))])

# ---------- Screen and copy OK files ----------
if new_paths:
    print(f"\nScreening {len(new_paths)} file(s) from NEW_AUDIO/NEW_FOLDER")
    kept, rejected = 0, 0
    for p in sorted(new_paths):
        try:
            vec = extract_vec_for_path(p)
            dec = score_vector(vec)
            is_outlier = dec["z_any_gt_thresh"] or dec["euclidean_is_outlier"] or dec["mahalanobis_is_outlier"]
            status = "OUTLIER" if is_outlier else "OK"
            print(f"- {os.path.basename(p)} -> {status} | "
                  f"z_any_gt={dec['z_any_gt_thresh']}  eucl={dec['euclidean']:.4f} "
                  # f"({'>': dec['euclidean_is_outlier']} thr={eucl_thresh:.4f})  "
                  f"({'>' if dec['euclidean_is_outlier'] else ''} thr={eucl_thresh:.4f})"
                  # f"mahal={dec['mahalanobis']:.4f} ({'>': dec['mahalanobis_is_outlier']} thr={mahal_thresh:.4f})")
                  f"mahal={dec['mahalanobis']:.4f} ({'>' if dec['mahalanobis_is_outlier'] else ''} thr={mahal_thresh:.4f})")
            if not is_outlier:
                shutil.copy2(p, os.path.join(OK_FOLDER, os.path.basename(p)))
                kept += 1
            else:
                rejected += 1
        except Exception as e:
            print(f"  Error processing {p}: {e}")
    print(f"\nCompleted. Kept: {kept}  Rejected: {rejected}  Copied OK files to: {OK_FOLDER}")
else:
    print("\nNo NEW_AUDIO or NEW_FOLDER provided. Only reference analysis was performed.")
# Out:
# Reference files: 500  |  Buckets: 32  |  Device: cuda
# Reference feature matrix: (500, 70)
# Euclidean threshold (pctl 98.0): 0.421074
# Mahalanobis threshold (pctl 98.0): 13.772526
# Channelwise z-score threshold: 4.00
# Screening 100 file(s) from NEW_AUDIO/NEW_FOLDER
# - LA_D_1129909.flac -> OK | z_any_gt=False  eucl=0.2493 ( thr=0.4211)mahal=9.5757 ( thr=13.7725)
# - LA_D_1234829.flac -> OK | z_any_gt=False  eucl=0.1491 ( thr=0.4211)mahal=6.6477 ( thr=13.7725)
# - LA_D_1253089.flac -> OK | z_any_gt=False  eucl=0.1831 ( thr=0.4211)mahal=9.4002 ( thr=13.7725)
# - LA_D_1274098.flac -> OK | z_any_gt=False  eucl=0.1245 ( thr=0.4211)mahal=7.8873 ( thr=13.7725)
# - LA_D_1306387.flac -> OK | z_any_gt=False  eucl=0.1612 ( thr=0.4211)mahal=5.8934 ( thr=13.7725)
# - LA_D_1317890.flac -> OK | z_any_gt=False  eucl=0.1487 ( thr=0.4211)mahal=7.0754 ( thr=13.7725)
# - LA_D_1335445.flac -> OK | z_any_gt=False  eucl=0.1077 ( thr=0.4211)mahal=5.9507 ( thr=13.7725)
# - LA_D_1353894.flac -> OK | z_any_gt=False  eucl=0.2386 ( thr=0.4211)mahal=6.3531 ( thr=13.7725)
# - LA_D_1475288.flac -> OK | z_any_gt=False  eucl=0.1918 ( thr=0.4211)mahal=9.7781 ( thr=13.7725)
# - LA_D_1565390.flac -> OK | z_any_gt=False  eucl=0.1122 ( thr=0.4211)mahal=5.2492 ( thr=13.7725)
# - LA_D_1710320.flac -> OK | z_any_gt=False  eucl=0.1767 ( thr=0.4211)mahal=11.4252 ( thr=13.7725)
# - LA_D_1773726.flac -> OK | z_any_gt=False  eucl=0.1929 ( thr=0.4211)mahal=8.4489 ( thr=13.7725)
# - LA_D_1829406.flac -> OK | z_any_gt=False  eucl=0.1503 ( thr=0.4211)mahal=9.7026 ( thr=13.7725)
# - LA_D_1842990.flac -> OK | z_any_gt=False  eucl=0.2479 ( thr=0.4211)mahal=7.2788 ( thr=13.7725)
# - LA_D_1888215.flac -> OUTLIER | z_any_gt=True  eucl=0.2418 ( thr=0.4211)mahal=12.9434 ( thr=13.7725)
# - LA_D_2053527.flac -> OK | z_any_gt=False  eucl=0.1346 ( thr=0.4211)mahal=6.5111 ( thr=13.7725)
# - LA_D_2302613.flac -> OUTLIER | z_any_gt=True  eucl=0.2375 ( thr=0.4211)mahal=11.7618 ( thr=13.7725)
# - LA_D_2338525.flac -> OUTLIER | z_any_gt=True  eucl=0.2690 ( thr=0.4211)mahal=10.0216 ( thr=13.7725)
# - LA_D_2365147.flac -> OK | z_any_gt=False  eucl=0.1443 ( thr=0.4211)mahal=8.3992 ( thr=13.7725)
# - LA_D_2393663.flac -> OK | z_any_gt=False  eucl=0.1556 ( thr=0.4211)mahal=7.0677 ( thr=13.7725)
# - LA_D_2763260.flac -> OUTLIER | z_any_gt=True  eucl=0.1926 ( thr=0.4211)mahal=15.0732 (> thr=13.7725)
# - LA_D_2842063.flac -> OK | z_any_gt=False  eucl=0.1206 ( thr=0.4211)mahal=5.6097 ( thr=13.7725)
# - LA_D_2977057.flac -> OK | z_any_gt=False  eucl=0.2043 ( thr=0.4211)mahal=12.1660 ( thr=13.7725)
# - LA_D_3005942.flac -> OK | z_any_gt=False  eucl=0.1094 ( thr=0.4211)mahal=6.5311 ( thr=13.7725)
# - LA_D_3264952.flac -> OK | z_any_gt=False  eucl=0.2041 ( thr=0.4211)mahal=11.3071 ( thr=13.7725)
# - LA_D_3440131.flac -> OK | z_any_gt=False  eucl=0.1356 ( thr=0.4211)mahal=5.7267 ( thr=13.7725)
# - LA_D_3476544.flac -> OK | z_any_gt=False  eucl=0.1184 ( thr=0.4211)mahal=8.7838 ( thr=13.7725)
# - LA_D_3483451.flac -> OK | z_any_gt=False  eucl=0.2052 ( thr=0.4211)mahal=11.3879 ( thr=13.7725)
# - LA_D_3577801.flac -> OK | z_any_gt=False  eucl=0.1435 ( thr=0.4211)mahal=5.1158 ( thr=13.7725)
# - LA_D_3631905.flac -> OK | z_any_gt=False  eucl=0.1409 ( thr=0.4211)mahal=8.4789 ( thr=13.7725)
# - LA_D_3652642.flac -> OK | z_any_gt=False  eucl=0.1566 ( thr=0.4211)mahal=7.4903 ( thr=13.7725)
# - LA_D_3731175.flac -> OK | z_any_gt=False  eucl=0.1317 ( thr=0.4211)mahal=6.8834 ( thr=13.7725)
# - LA_D_3882050.flac -> OK | z_any_gt=False  eucl=0.1961 ( thr=0.4211)mahal=9.3076 ( thr=13.7725)
# - LA_D_3933506.flac -> OK | z_any_gt=False  eucl=0.1648 ( thr=0.4211)mahal=6.9598 ( thr=13.7725)
# - LA_D_3940913.flac -> OK | z_any_gt=False  eucl=0.1308 ( thr=0.4211)mahal=6.3263 ( thr=13.7725)
# - LA_D_4026264.flac -> OK | z_any_gt=False  eucl=0.1483 ( thr=0.4211)mahal=7.1505 ( thr=13.7725)
# - LA_D_4063159.flac -> OK | z_any_gt=False  eucl=0.1168 ( thr=0.4211)mahal=5.9122 ( thr=13.7725)
# - LA_D_4149974.flac -> OK | z_any_gt=False  eucl=0.2541 ( thr=0.4211)mahal=9.7824 ( thr=13.7725)
# - LA_D_4274975.flac -> OK | z_any_gt=False  eucl=0.2122 ( thr=0.4211)mahal=5.1588 ( thr=13.7725)
# - LA_D_4309711.flac -> OK | z_any_gt=False  eucl=0.1279 ( thr=0.4211)mahal=7.5422 ( thr=13.7725)
# - LA_D_4401633.flac -> OK | z_any_gt=False  eucl=0.1667 ( thr=0.4211)mahal=7.2851 ( thr=13.7725)
# - LA_D_4420975.flac -> OUTLIER | z_any_gt=True  eucl=0.2350 ( thr=0.4211)mahal=12.2041 ( thr=13.7725)
# - LA_D_4621778.flac -> OK | z_any_gt=False  eucl=0.1290 ( thr=0.4211)mahal=7.1952 ( thr=13.7725)
# - LA_D_4757475.flac -> OK | z_any_gt=False  eucl=0.1484 ( thr=0.4211)mahal=6.3557 ( thr=13.7725)
# - LA_D_4789764.flac -> OK | z_any_gt=False  eucl=0.1820 ( thr=0.4211)mahal=9.2830 ( thr=13.7725)
# - LA_D_4803902.flac -> OK | z_any_gt=False  eucl=0.1745 ( thr=0.4211)mahal=5.6829 ( thr=13.7725)
# - LA_D_4834228.flac -> OK | z_any_gt=False  eucl=0.1348 ( thr=0.4211)mahal=5.5410 ( thr=13.7725)
# - LA_D_4890059.flac -> OK | z_any_gt=False  eucl=0.0922 ( thr=0.4211)mahal=8.3984 ( thr=13.7725)
# - LA_D_4948709.flac -> OUTLIER | z_any_gt=True  eucl=0.2171 ( thr=0.4211)mahal=9.5174 ( thr=13.7725)
# - LA_D_5475950.flac -> OK | z_any_gt=False  eucl=0.1901 ( thr=0.4211)mahal=7.9475 ( thr=13.7725)
# - LA_D_5547400.flac -> OK | z_any_gt=False  eucl=0.1202 ( thr=0.4211)mahal=7.1284 ( thr=13.7725)
# - LA_D_5679718.flac -> OK | z_any_gt=False  eucl=0.1637 ( thr=0.4211)mahal=12.1350 ( thr=13.7725)
# - LA_D_5701193.flac -> OK | z_any_gt=False  eucl=0.1695 ( thr=0.4211)mahal=8.5726 ( thr=13.7725)
# - LA_D_5738969.flac -> OK | z_any_gt=False  eucl=0.1672 ( thr=0.4211)mahal=9.1967 ( thr=13.7725)
# - LA_D_5929116.flac -> OK | z_any_gt=False  eucl=0.1241 ( thr=0.4211)mahal=8.7760 ( thr=13.7725)
# - LA_D_6084606.flac -> OK | z_any_gt=False  eucl=0.1580 ( thr=0.4211)mahal=7.9859 ( thr=13.7725)
# - LA_D_6085002.flac -> OK | z_any_gt=False  eucl=0.1730 ( thr=0.4211)mahal=9.6357 ( thr=13.7725)
# - LA_D_6289915.flac -> OK | z_any_gt=False  eucl=0.1096 ( thr=0.4211)mahal=7.4295 ( thr=13.7725)
# - LA_D_6303389.flac -> OK | z_any_gt=False  eucl=0.1173 ( thr=0.4211)mahal=6.9050 ( thr=13.7725)
# - LA_D_6308295.flac -> OK | z_any_gt=False  eucl=0.1812 ( thr=0.4211)mahal=10.1193 ( thr=13.7725)
# - LA_D_6343761.flac -> OK | z_any_gt=False  eucl=0.1247 ( thr=0.4211)mahal=7.5205 ( thr=13.7725)
# - LA_D_6439730.flac -> OK | z_any_gt=False  eucl=0.0789 ( thr=0.4211)mahal=6.8181 ( thr=13.7725)
# - LA_D_6631537.flac -> OK | z_any_gt=False  eucl=0.2531 ( thr=0.4211)mahal=10.5107 ( thr=13.7725)
# - LA_D_6710328.flac -> OK | z_any_gt=False  eucl=0.1272 ( thr=0.4211)mahal=5.9556 ( thr=13.7725)
# - LA_D_6780824.flac -> OK | z_any_gt=False  eucl=0.1174 ( thr=0.4211)mahal=7.7909 ( thr=13.7725)
# - LA_D_6795666.flac -> OK | z_any_gt=False  eucl=0.1717 ( thr=0.4211)mahal=10.3560 ( thr=13.7725)
# - LA_D_6818564.flac -> OK | z_any_gt=False  eucl=0.1216 ( thr=0.4211)mahal=7.0364 ( thr=13.7725)
# - LA_D_6908091.flac -> OK | z_any_gt=False  eucl=0.1573 ( thr=0.4211)mahal=8.1510 ( thr=13.7725)
# - LA_D_6963411.flac -> OK | z_any_gt=False  eucl=0.1342 ( thr=0.4211)mahal=6.6748 ( thr=13.7725)
# - LA_D_7025552.flac -> OUTLIER | z_any_gt=True  eucl=0.2486 ( thr=0.4211)mahal=13.0846 ( thr=13.7725)
# - LA_D_7152817.flac -> OK | z_any_gt=False  eucl=0.1499 ( thr=0.4211)mahal=7.6340 ( thr=13.7725)
# - LA_D_7184320.flac -> OUTLIER | z_any_gt=True  eucl=0.2352 ( thr=0.4211)mahal=12.0778 ( thr=13.7725)
# - LA_D_7203605.flac -> OK | z_any_gt=False  eucl=0.1312 ( thr=0.4211)mahal=5.3975 ( thr=13.7725)
# - LA_D_7253146.flac -> OUTLIER | z_any_gt=True  eucl=0.2090 ( thr=0.4211)mahal=8.7282 ( thr=13.7725)
# - LA_D_7341689.flac -> OK | z_any_gt=False  eucl=0.1506 ( thr=0.4211)mahal=9.6684 ( thr=13.7725)
# - LA_D_7622198.flac -> OK | z_any_gt=False  eucl=0.1695 ( thr=0.4211)mahal=8.4632 ( thr=13.7725)
# - LA_D_7731909.flac -> OK | z_any_gt=False  eucl=0.1275 ( thr=0.4211)mahal=6.3231 ( thr=13.7725)
# - LA_D_7769284.flac -> OK | z_any_gt=False  eucl=0.2062 ( thr=0.4211)mahal=6.5458 ( thr=13.7725)
# - LA_D_7900736.flac -> OK | z_any_gt=False  eucl=0.1661 ( thr=0.4211)mahal=6.5176 ( thr=13.7725)
# - LA_D_7932604.flac -> OK | z_any_gt=False  eucl=0.2151 ( thr=0.4211)mahal=9.9716 ( thr=13.7725)
# - LA_D_8316995.flac -> OK | z_any_gt=False  eucl=0.1713 ( thr=0.4211)mahal=8.8484 ( thr=13.7725)
# - LA_D_8342132.flac -> OK | z_any_gt=False  eucl=0.1488 ( thr=0.4211)mahal=5.5836 ( thr=13.7725)
# - LA_D_8393123.flac -> OK | z_any_gt=False  eucl=0.2273 ( thr=0.4211)mahal=13.0281 ( thr=13.7725)
# - LA_D_8476547.flac -> OK | z_any_gt=False  eucl=0.1856 ( thr=0.4211)mahal=10.5189 ( thr=13.7725)
# - LA_D_8556149.flac -> OK | z_any_gt=False  eucl=0.2247 ( thr=0.4211)mahal=9.1063 ( thr=13.7725)
# - LA_D_8623607.flac -> OK | z_any_gt=False  eucl=0.1328 ( thr=0.4211)mahal=7.4081 ( thr=13.7725)
# - LA_D_8691545.flac -> OK | z_any_gt=False  eucl=0.1778 ( thr=0.4211)mahal=8.9938 ( thr=13.7725)
# - LA_D_8988223.flac -> OK | z_any_gt=False  eucl=0.1194 ( thr=0.4211)mahal=5.9763 ( thr=13.7725)
# - LA_D_9027095.flac -> OK | z_any_gt=False  eucl=0.1417 ( thr=0.4211)mahal=6.7995 ( thr=13.7725)
# - LA_D_9133444.flac -> OK | z_any_gt=False  eucl=0.1571 ( thr=0.4211)mahal=5.8856 ( thr=13.7725)
# - LA_D_9137331.flac -> OK | z_any_gt=False  eucl=0.1347 ( thr=0.4211)mahal=6.6527 ( thr=13.7725)
# - LA_D_9148460.flac -> OK | z_any_gt=False  eucl=0.1517 ( thr=0.4211)mahal=5.2345 ( thr=13.7725)
# - LA_D_9183395.flac -> OK | z_any_gt=False  eucl=0.1710 ( thr=0.4211)mahal=7.1241 ( thr=13.7725)
# - LA_D_9300277.flac -> OK | z_any_gt=False  eucl=0.2004 ( thr=0.4211)mahal=7.4966 ( thr=13.7725)
# - LA_D_9386892.flac -> OK | z_any_gt=False  eucl=0.2075 ( thr=0.4211)mahal=8.8786 ( thr=13.7725)
# - LA_D_9610405.flac -> OK | z_any_gt=False  eucl=0.2212 ( thr=0.4211)mahal=7.9969 ( thr=13.7725)
# - LA_D_9723493.flac -> OK | z_any_gt=False  eucl=0.1523 ( thr=0.4211)mahal=5.1778 ( thr=13.7725)
# - LA_D_9726894.flac -> OK | z_any_gt=False  eucl=0.1230 ( thr=0.4211)mahal=7.9935 ( thr=13.7725)
# - LA_D_9764499.flac -> OUTLIER | z_any_gt=True  eucl=0.2652 ( thr=0.4211)mahal=14.4551 (> thr=13.7725)
# - LA_D_9842587.flac -> OUTLIER | z_any_gt=False  eucl=0.2789 ( thr=0.4211)mahal=15.2617 (> thr=13.7725)
#
# Completed. Kept: 89  Rejected: 11  Copied OK files to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Calibration_17_RawGAT

# %%
# Colab cell: static quantization for 1D audio ONNX with correct input rank
# !pip -q install onnx onnxruntime onnxruntime-tools soundfile torchaudio

import os, glob, numpy as np, soundfile as sf, torch, torchaudio, onnx
import onnxruntime as ort
from onnxruntime.quantization import (
    quantize, QuantType, QuantFormat, StaticQuantConfig,
    CalibrationMethod, CalibrationDataReader
)

ONNX_FP32 = "/content/rawgat_optimized.onnx"           # your exported model
ONNX_INT8 = "/content/rawgat_int8_scheme_17.onnx"
CALIB_DIR = "/content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Calibration_17_RawGAT"               # folder with a few .flac samples
TARGET_SR  = 16000
FIXED_LEN  = 64600

# 1) Inspect model I/O
sess = ort.InferenceSession(ONNX_FP32, providers=["CPUExecutionProvider"])
inp = sess.get_inputs()[0]
input_name = inp.name
print("Input name:", input_name)
print("Input type:", inp.type)
print("Input shape (may contain None for dynamic):", inp.shape)

# 2) Audio preprocessing that matches your PyTorch inference
def pad_or_crop(x: np.ndarray, L: int) -> np.ndarray:
    x = x.astype(np.float32)
    if x.shape[0] >= L:
        return x[:L]
    reps = int(L / x.shape[0]) + 1
    return np.tile(x, reps)[:L]

def load_audio_fixed_length(path: str, target_sr: int, fixed_len: int) -> np.ndarray:
    wav, sr = sf.read(path, dtype="float32", always_2d=False)
    if wav.ndim > 1:
        wav = np.mean(wav, axis=1)
    if sr != target_sr:
        wav_t = torch.from_numpy(wav).unsqueeze(0)
        wav_rs = torchaudio.functional.resample(wav_t, orig_freq=sr, new_freq=target_sr)
        wav = wav_rs.squeeze(0).numpy()
    m = np.max(np.abs(wav))
    if m > 0:
        wav = wav / m
    return pad_or_crop(wav, fixed_len)

# 3) CalibrationDataReader that yields rank-2 input: [1, num_samples]
class FixedLengthAudioReader(CalibrationDataReader):
    def __init__(self, audio_folder: str, input_name: str, target_sr: int = 16000, fixed_len: int = 64600):
        self.input_name = input_name
        self.files = sorted([p for p in glob.glob(os.path.join(audio_folder, "*.flac"))])
        self.target_sr = target_sr
        self.fixed_len = fixed_len
        self._iter = iter(self.files)

    def get_next(self):
        try:
            p = next(self._iter)
        except StopIteration:
            return None
        x = load_audio_fixed_length(p, self.target_sr, self.fixed_len)      # shape [L]
        x = np.expand_dims(x.astype(np.float32), axis=0)                     # shape [1, L]
        return {self.input_name: x}

# 4) Create reader
reader = FixedLengthAudioReader(CALIB_DIR, input_name, TARGET_SR, FIXED_LEN)

# 5) Static quantization configuration
# conf = StaticQuantConfig(
#     calibration_method=CalibrationMethod.Entropy,  # or MinMax, Percentile
#     activation_type=QuantType.QInt8,
#     weight_type=QuantType.QInt8,
#     quant_format=QuantFormat.QDQ,
#     per_channel=True,
#     # You can restrict ops if needed:
#     # op_types_to_quantize=["Conv", "MatMul", "Gemm"]
# )
conf = StaticQuantConfig(
    calibration_data_reader=reader,
    quant_format=QuantFormat.QDQ,
    calibrate_method=CalibrationMethod.MinMax,
    # calibration_providers='CUDAExecutionProvider',
    # optimize_model=True, # Removed unsupported argument
    activation_type=QuantType.QUInt8,
    weight_type=QuantType.QInt8,
    per_channel=True,
    extra_options={"ActivationSymmetric":False,
                  "WeightSymmetric":True}
)

# 6) Run quantization
quantize(
    model_input=ONNX_FP32,
    model_output=ONNX_INT8,
    quant_config=conf
    # calibration_data_reader=reader
)
print(f"Quantized model saved to {ONNX_INT8}")
# Out:
# Input name: input
# Input type: tensor(float)
# Input shape (may contain None for dynamic): [1, 'num_samples']
# WARNING:root:Axis 1 is out-of-range for weight 'first_bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'GAT_layer1.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'GAT_layer2.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'GAT_layer3.bn.weight' with rank 1
# Quantized model saved to /content/rawgat_int8_scheme_17.onnx

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/rawgat_int8_scheme_17.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_scheme17.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=413, TN=65, FP=0, FN=22
# Accuracy: 0.9560
# FPR: 0.0000   FNR: 0.0506   EER: 0.0253
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_scheme17.png

# %%
# Colab: download and unzip a file
import os

# 1) Set the URL of the zip file
zip_url = "https://owncloud.fraunhofer.de/index.php/s/JZgXh0JEAF0elxa/download"   # <-- replace with your link
zip_path = "/content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/in_the_wild.zip"                          # where to save
extract_dir = "/content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets"                      # target folder

# 2) Download with wget
# !wget -O "$zip_path" "$zip_url"

# 3) Make sure target dir exists
os.makedirs(extract_dir, exist_ok=True)

# 4) Unzip
# !unzip -o "$zip_path" -d "$extract_dir"

print(f"Unzipped to: {extract_dir}")
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22472.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21437.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1451.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9082.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/20810.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4210.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12376.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2772.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22039.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9847.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/15569.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/8969.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21759.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19010.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19318.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/5514.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/20657.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12380.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27769.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7749.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22876.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27549.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16735.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13675.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21334.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21625.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1034.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7090.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22575.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3114.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30398.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/15891.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24001.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4524.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4085.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1163.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27161.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/11268.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1652.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/29535.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12408.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3263.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18038.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7110.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13070.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/11210.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/29392.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30462.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18136.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/20940.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3916.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24066.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19744.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/28004.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24230.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14216.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/23065.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17334.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/253.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13942.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12545.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25109.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27295.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21487.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13444.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/15017.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25471.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7900.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27715.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/23965.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14237.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26444.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/15826.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17015.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31548.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17758.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/11379.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/8825.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/20732.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14137.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1240.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16987.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21170.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/15436.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26197.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3690.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10139.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30640.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9725.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4550.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30749.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26866.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1036.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/8213.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10736.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25273.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19852.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/28085.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21053.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/29907.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12791.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/724.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/23302.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16878.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31608.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27087.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14131.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12261.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26414.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31749.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/15859.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31450.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/23063.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/28246.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24863.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/5645.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26383.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19049.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25308.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2149.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/15319.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/6912.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30499.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27331.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30038.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16969.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14083.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19957.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19944.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/23013.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14408.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3956.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14114.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3247.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4513.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/323.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/8443.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/29685.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/655.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10007.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30529.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1928.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25587.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12166.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2819.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19216.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21746.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10221.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19342.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/717.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19506.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19432.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21826.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/5016.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12931.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17095.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14923.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9024.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12061.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/6531.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/8396.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10696.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12525.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7730.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/128.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14101.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13415.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21519.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1734.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14958.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14319.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/28521.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9924.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18383.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30577.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21231.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1211.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12260.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16245.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1099.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27630.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1233.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7796.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/23843.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/15009.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9652.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14371.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/703.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21248.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18775.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30318.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14601.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21670.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/29104.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9759.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/6351.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25118.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7361.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25992.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17097.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19196.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24254.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/595.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26543.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24516.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/6924.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31025.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12542.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31157.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17900.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/6864.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24083.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30851.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24892.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7924.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17662.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9748.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/6160.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18883.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10507.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16891.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22573.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25628.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14629.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/20268.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10213.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31067.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27945.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19913.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1256.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24213.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/8794.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/20870.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13918.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4992.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16338.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/15663.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/56.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17320.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27274.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19920.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/28855.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/20.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16027.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19222.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25410.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12473.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/961.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17832.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2881.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4113.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30507.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27818.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/11487.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14770.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9549.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24631.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22906.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/5915.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/23199.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4846.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9653.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31733.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13802.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10178.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2664.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1180.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12041.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16235.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22117.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/28204.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24311.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2532.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31732.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2655.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31623.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1274.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/28669.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/11942.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18772.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10522.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13653.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30333.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/29794.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16886.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12883.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4528.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12472.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14528.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22254.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4043.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22874.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26987.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/11385.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/841.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/695.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30486.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7296.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25578.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16877.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13145.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/20383.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/11662.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17409.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9990.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/29229.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10385.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9044.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/20056.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26423.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9005.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/608.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/5378.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21062.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14802.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3216.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2312.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7373.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27086.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25962.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10144.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24698.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31704.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/6958.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4955.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24599.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14369.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/23982.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/501.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16073.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3684.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/11454.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/15730.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31287.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12281.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21369.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/6269.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2257.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25389.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18720.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17867.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16026.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2381.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27787.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26211.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/895.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9042.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9893.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10386.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/8129.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16419.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12144.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7142.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31739.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7903.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31768.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30942.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14079.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12572.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4530.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/28761.wav
# ...
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27422.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21790.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7195.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22352.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27014.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/23342.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27635.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13453.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7959.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16296.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24930.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17215.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/5173.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3598.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/23148.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22846.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/29717.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27098.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/29361.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/20805.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27553.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26287.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9396.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13596.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26677.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/15165.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3310.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/14758.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/5320.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4360.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7799.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/5013.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26658.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1759.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13003.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/23770.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26848.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10683.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12962.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/11303.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3522.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/8336.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10765.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3413.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19005.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/8823.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25121.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19737.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/8371.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9202.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1614.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26608.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17175.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/432.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/5189.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9262.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/9803.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/15472.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/40.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16720.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16345.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2385.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/11839.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1542.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18387.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2344.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/803.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/11640.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25711.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7279.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1959.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13397.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16632.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25483.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31578.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/28605.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/6128.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2759.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/8503.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/30626.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/10606.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/513.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/21007.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12798.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31534.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7513.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/8877.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22665.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/3036.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/6837.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18610.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2399.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18295.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/5169.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/759.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2447.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19141.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18186.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/1435.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/31642.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/22893.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18852.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/4006.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/16331.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17262.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/2879.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/13585.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/18691.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/26849.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/28760.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/12455.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19144.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/25006.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/6484.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/19257.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/24636.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/7644.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/27148.wav
#   inflating: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets/release_in_the_wild/17947.wav
# Unzipped to: /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/In_the_Wild_Datasets

# %%
# Colab: Copy 500 random files from one folder to another
import os
import random
import shutil

# 1) Set paths
src_folder = "/content/in_the_wild_extracted/release_in_the_wild"   # <-- replace with your source folder
dst_folder = "/content/in_the_wild_extracted/wild_subset"      # <-- destination folder
N_COPY = 500

# 2) Ensure destination exists
os.makedirs(dst_folder, exist_ok=True)

# 3) List all files in source (you can filter extensions if needed)
all_files = [f for f in os.listdir(src_folder) if os.path.isfile(os.path.join(src_folder, f))]
print(f"Found {len(all_files)} files in source folder.")

# 4) Select up to 500 randomly (or sequentially if you prefer)
selected_files = random.sample(all_files, min(N_COPY, len(all_files)))

# 5) Copy
for fname in selected_files:
    shutil.copy2(os.path.join(src_folder, fname), os.path.join(dst_folder, fname))

print(f"Copied {len(selected_files)} files to {dst_folder}")
# Out:
# Found 31781 files in source folder.
# Copied 500 files to /content/in_the_wild_extracted/wild_subset

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat_itw.py \
    --onnx_model_path /content/rawgat_int8_scheme_17.onnx \
    --audio_folder /content/in_the_wild_extracted/wild_subset \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_scheme17_itw.png \
    --meta_csv /content/in_the_wild_extracted/meta.csv
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=180, TN=22, FP=292, FN=6
# Accuracy: 0.4040
# FPR: 0.9299   FNR: 0.0323   EER: 0.4811
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_scheme17_itw.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat_itw.py \
    --onnx_model_path /content/rawgat_st.onnx \
    --audio_folder /content/in_the_wild_extracted/wild_subset \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_original_itw.png \
    --meta_csv /content/in_the_wild_extracted/meta.csv
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=181, TN=40, FP=274, FN=5
# Accuracy: 0.4420
# FPR: 0.8726   FNR: 0.0269   EER: 0.4497
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_original_itw.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/rawgat_int8_scheme_17.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_set1 \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_re_eval_1.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=435, TN=43, FP=3, FN=19
# Accuracy: 0.9560
# FPR: 0.0652   FNR: 0.0419   EER: 0.0535
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_re_eval_1.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/rawgat_int8_scheme_17.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_set2 \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_re_eval_2.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=415, TN=56, FP=1, FN=28
# Accuracy: 0.9420
# FPR: 0.0175   FNR: 0.0632   EER: 0.0404
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_re_eval_2.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/rawgat_int8_scheme_17.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_set3 \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_re_eval_3.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=418, TN=53, FP=1, FN=28
# Accuracy: 0.9420
# FPR: 0.0185   FNR: 0.0628   EER: 0.0406
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_re_eval_3.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/rawgat_int8_scheme_17.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_set4 \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_re_eval_4.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=422, TN=62, FP=0, FN=16
# Accuracy: 0.9680
# FPR: 0.0000   FNR: 0.0365   EER: 0.0183
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_re_eval_4.png

# %%
## Quantized Model Parameters

# %cd /content/
import onnx
import onnx.helper
import numpy as np

# Load the ONNX model
model = onnx.load("rawgat_st.onnx")

# Iterate through initializers (which store the weights)
total_params = 0
total_bytes = 0

for tensor in model.graph.initializer:
    # Number of parameters
    num_params = 1
    for dim in tensor.dims:
        num_params *= dim

    # Data type size (in bytes)
    # Use onnx.helper.tensor_dtype_to_np_dtype to get the numpy dtype
    # Then access the itemsize attribute
    dtype = onnx.helper.tensor_dtype_to_np_dtype(tensor.data_type)
    dtype_size = dtype.itemsize

    # Accumulate size
    size_bytes = num_params * dtype_size
    total_params += num_params
    total_bytes += size_bytes

    print(f"{tensor.name}: {num_params} params, {size_bytes/1024:.2f} KB")

print(f"\nTotal parameters: {total_params}")
print(f"Total weights size: {total_bytes / (1024 * 1024):.2f} MB")
# Out:
# /content
# first_bn.weight: 1 params, 0.00 KB
# first_bn.bias: 1 params, 0.00 KB
# first_bn.running_mean: 1 params, 0.00 KB
# first_bn.running_var: 1 params, 0.00 KB
# encoder1.0.0.conv_1.weight: 192 params, 0.75 KB
# encoder1.0.0.conv_1.bias: 32 params, 0.12 KB
# encoder1.0.0.bn2.weight: 32 params, 0.12 KB
# encoder1.0.0.bn2.bias: 32 params, 0.12 KB
# encoder1.0.0.bn2.running_mean: 32 params, 0.12 KB
# encoder1.0.0.bn2.running_var: 32 params, 0.12 KB
# encoder1.0.0.conv2.weight: 6144 params, 24.00 KB
# encoder1.0.0.conv2.bias: 32 params, 0.12 KB
# encoder1.1.0.conv1.weight: 6144 params, 24.00 KB
# encoder1.1.0.conv1.bias: 32 params, 0.12 KB
# encoder1.1.0.bn2.weight: 32 params, 0.12 KB
# encoder1.1.0.bn2.bias: 32 params, 0.12 KB
# encoder1.1.0.bn2.running_mean: 32 params, 0.12 KB
# encoder1.1.0.bn2.running_var: 32 params, 0.12 KB
# encoder1.1.0.conv2.weight: 6144 params, 24.00 KB
# encoder1.1.0.conv2.bias: 32 params, 0.12 KB
# encoder1.2.0.conv1.weight: 12288 params, 48.00 KB
# encoder1.2.0.conv1.bias: 64 params, 0.25 KB
# encoder1.2.0.bn2.weight: 64 params, 0.25 KB
# encoder1.2.0.bn2.bias: 64 params, 0.25 KB
# encoder1.2.0.bn2.running_mean: 64 params, 0.25 KB
# encoder1.2.0.bn2.running_var: 64 params, 0.25 KB
# encoder1.2.0.conv2.weight: 24576 params, 96.00 KB
# encoder1.2.0.conv2.bias: 64 params, 0.25 KB
# encoder1.2.0.conv_downsample.weight: 6144 params, 24.00 KB
# encoder1.2.0.conv_downsample.bias: 64 params, 0.25 KB
# encoder1.3.0.conv1.weight: 24576 params, 96.00 KB
# encoder1.3.0.conv1.bias: 64 params, 0.25 KB
# encoder1.3.0.bn2.weight: 64 params, 0.25 KB
# encoder1.3.0.bn2.bias: 64 params, 0.25 KB
# encoder1.3.0.bn2.running_mean: 64 params, 0.25 KB
# encoder1.3.0.bn2.running_var: 64 params, 0.25 KB
# encoder1.3.0.conv2.weight: 24576 params, 96.00 KB
# encoder1.3.0.conv2.bias: 64 params, 0.25 KB
# encoder1.4.0.conv1.weight: 24576 params, 96.00 KB
# encoder1.4.0.conv1.bias: 64 params, 0.25 KB
# encoder1.4.0.bn2.weight: 64 params, 0.25 KB
# encoder1.4.0.bn2.bias: 64 params, 0.25 KB
# encoder1.4.0.bn2.running_mean: 64 params, 0.25 KB
# encoder1.4.0.bn2.running_var: 64 params, 0.25 KB
# encoder1.4.0.conv2.weight: 24576 params, 96.00 KB
# encoder1.4.0.conv2.bias: 64 params, 0.25 KB
# encoder1.5.0.conv1.weight: 24576 params, 96.00 KB
# encoder1.5.0.conv1.bias: 64 params, 0.25 KB
# encoder1.5.0.bn2.weight: 64 params, 0.25 KB
# encoder1.5.0.bn2.bias: 64 params, 0.25 KB
# encoder1.5.0.bn2.running_mean: 64 params, 0.25 KB
# encoder1.5.0.bn2.running_var: 64 params, 0.25 KB
# encoder1.5.0.conv2.weight: 24576 params, 96.00 KB
# encoder1.5.0.conv2.bias: 64 params, 0.25 KB
# encoder2.0.0.conv_1.weight: 192 params, 0.75 KB
# encoder2.0.0.conv_1.bias: 32 params, 0.12 KB
# encoder2.0.0.bn2.weight: 32 params, 0.12 KB
# encoder2.0.0.bn2.bias: 32 params, 0.12 KB
# encoder2.0.0.bn2.running_mean: 32 params, 0.12 KB
# encoder2.0.0.bn2.running_var: 32 params, 0.12 KB
# encoder2.0.0.conv2.weight: 6144 params, 24.00 KB
# encoder2.0.0.conv2.bias: 32 params, 0.12 KB
# encoder2.1.0.conv1.weight: 6144 params, 24.00 KB
# encoder2.1.0.conv1.bias: 32 params, 0.12 KB
# encoder2.1.0.bn2.weight: 32 params, 0.12 KB
# encoder2.1.0.bn2.bias: 32 params, 0.12 KB
# encoder2.1.0.bn2.running_mean: 32 params, 0.12 KB
# encoder2.1.0.bn2.running_var: 32 params, 0.12 KB
# encoder2.1.0.conv2.weight: 6144 params, 24.00 KB
# encoder2.1.0.conv2.bias: 32 params, 0.12 KB
# encoder2.2.0.conv1.weight: 12288 params, 48.00 KB
# encoder2.2.0.conv1.bias: 64 params, 0.25 KB
# encoder2.2.0.bn2.weight: 64 params, 0.25 KB
# encoder2.2.0.bn2.bias: 64 params, 0.25 KB
# encoder2.2.0.bn2.running_mean: 64 params, 0.25 KB
# encoder2.2.0.bn2.running_var: 64 params, 0.25 KB
# encoder2.2.0.conv2.weight: 24576 params, 96.00 KB
# encoder2.2.0.conv2.bias: 64 params, 0.25 KB
# encoder2.2.0.conv_downsample.weight: 6144 params, 24.00 KB
# encoder2.2.0.conv_downsample.bias: 64 params, 0.25 KB
# encoder2.3.0.conv1.weight: 24576 params, 96.00 KB
# encoder2.3.0.conv1.bias: 64 params, 0.25 KB
# encoder2.3.0.bn2.weight: 64 params, 0.25 KB
# encoder2.3.0.bn2.bias: 64 params, 0.25 KB
# encoder2.3.0.bn2.running_mean: 64 params, 0.25 KB
# encoder2.3.0.bn2.running_var: 64 params, 0.25 KB
# encoder2.3.0.conv2.weight: 24576 params, 96.00 KB
# encoder2.3.0.conv2.bias: 64 params, 0.25 KB
# encoder2.4.0.conv1.weight: 24576 params, 96.00 KB
# encoder2.4.0.conv1.bias: 64 params, 0.25 KB
# encoder2.4.0.bn2.weight: 64 params, 0.25 KB
# encoder2.4.0.bn2.bias: 64 params, 0.25 KB
# encoder2.4.0.bn2.running_mean: 64 params, 0.25 KB
# encoder2.4.0.bn2.running_var: 64 params, 0.25 KB
# encoder2.4.0.conv2.weight: 24576 params, 96.00 KB
# encoder2.4.0.conv2.bias: 64 params, 0.25 KB
# encoder2.5.0.conv1.weight: 24576 params, 96.00 KB
# encoder2.5.0.conv1.bias: 64 params, 0.25 KB
# encoder2.5.0.bn2.weight: 64 params, 0.25 KB
# encoder2.5.0.bn2.bias: 64 params, 0.25 KB
# encoder2.5.0.bn2.running_mean: 64 params, 0.25 KB
# encoder2.5.0.bn2.running_var: 64 params, 0.25 KB
# encoder2.5.0.conv2.weight: 24576 params, 96.00 KB
# encoder2.5.0.conv2.bias: 64 params, 0.25 KB
# GAT_layer1.att_weight: 32 params, 0.12 KB
# GAT_layer1.att_proj.weight: 2048 params, 8.00 KB
# GAT_layer1.att_proj.bias: 32 params, 0.12 KB
# GAT_layer1.proj_with_att.weight: 2048 params, 8.00 KB
# GAT_layer1.proj_with_att.bias: 32 params, 0.12 KB
# GAT_layer1.proj_without_att.weight: 2048 params, 8.00 KB
# GAT_layer1.bn.weight: 32 params, 0.12 KB
# GAT_layer1.bn.bias: 32 params, 0.12 KB
# GAT_layer1.bn.running_mean: 32 params, 0.12 KB
# GAT_layer1.bn.running_var: 32 params, 0.12 KB
# pool1.proj.weight: 32 params, 0.12 KB
# pool1.proj.bias: 1 params, 0.00 KB
# GAT_layer2.att_weight: 32 params, 0.12 KB
# GAT_layer2.att_proj.weight: 2048 params, 8.00 KB
# GAT_layer2.att_proj.bias: 32 params, 0.12 KB
# GAT_layer2.proj_with_att.weight: 2048 params, 8.00 KB
# GAT_layer2.proj_with_att.bias: 32 params, 0.12 KB
# GAT_layer2.proj_without_att.weight: 2048 params, 8.00 KB
# GAT_layer2.bn.weight: 32 params, 0.12 KB
# GAT_layer2.bn.bias: 32 params, 0.12 KB
# GAT_layer2.bn.running_mean: 32 params, 0.12 KB
# GAT_layer2.bn.running_var: 32 params, 0.12 KB
# pool2.proj.weight: 32 params, 0.12 KB
# pool2.proj.bias: 1 params, 0.00 KB
# GAT_layer3.att_weight: 16 params, 0.06 KB
# GAT_layer3.att_proj.weight: 512 params, 2.00 KB
# GAT_layer3.att_proj.bias: 16 params, 0.06 KB
# GAT_layer3.proj_with_att.weight: 512 params, 2.00 KB
# GAT_layer3.proj_with_att.bias: 16 params, 0.06 KB
# GAT_layer3.proj_without_att.weight: 512 params, 2.00 KB
# GAT_layer3.bn.weight: 16 params, 0.06 KB
# GAT_layer3.bn.bias: 16 params, 0.06 KB
# GAT_layer3.bn.running_mean: 16 params, 0.06 KB
# GAT_layer3.bn.running_var: 16 params, 0.06 KB
# pool3.proj.weight: 16 params, 0.06 KB
# pool3.proj.bias: 1 params, 0.00 KB
# proj1.weight: 168 params, 0.66 KB
# proj1.bias: 12 params, 0.05 KB
# proj2.weight: 276 params, 1.08 KB
# proj2.bias: 12 params, 0.05 KB
# proj.weight: 16 params, 0.06 KB
# proj.bias: 1 params, 0.00 KB
# proj_node.weight: 14 params, 0.05 KB
# proj_node.bias: 2 params, 0.01 KB
#
# Total parameters: 437116
# Total weights size: 1.67 MB

# %%
## Quantized Model Parameters

# %cd /content/
import onnx
import onnx.helper
import numpy as np

# Load the ONNX model
model = onnx.load("rawgat_int8_scheme_17.onnx")

# Iterate through initializers (which store the weights)
total_params = 0
total_bytes = 0

for tensor in model.graph.initializer:
    # Number of parameters
    num_params = 1
    for dim in tensor.dims:
        num_params *= dim

    # Data type size (in bytes)
    # Use onnx.helper.tensor_dtype_to_np_dtype to get the numpy dtype
    # Then access the itemsize attribute
    dtype = onnx.helper.tensor_dtype_to_np_dtype(tensor.data_type)
    dtype_size = dtype.itemsize

    # Accumulate size
    size_bytes = num_params * dtype_size
    total_params += num_params
    total_bytes += size_bytes

    print(f"{tensor.name}: {num_params} params, {size_bytes/1024:.2f} KB")

print(f"\nTotal parameters: {total_params}")
print(f"Total weights size: {total_bytes / (1024 * 1024):.2f} MB")
# Out:
# /content
# first_bn.running_mean: 1 params, 0.00 KB
# first_bn.running_var: 1 params, 0.00 KB
# /GAT_layer3/Constant_9_output_0: 1 params, 0.01 KB
# /GAT_layer2/ConstantOfShape_output_0: 4 params, 0.03 KB
# /GAT_layer3/Concat_2_output_0: 3 params, 0.02 KB
# /pool3/Constant_4_output_0: 1 params, 0.01 KB
# /Concat_2_output_0: 3 params, 0.02 KB
# /Constant_8_output_0: 1 params, 0.01 KB
# /GAT_layer3/Where_output_0: 4 params, 0.03 KB
# /conv_time/Constant_342_output_0: 1 params, 0.01 KB
# /GAT_layer3/Unsqueeze_7_output_0: 1 params, 0.01 KB
# /pool2/Unsqueeze_2_output_0: 1 params, 0.01 KB
# /pool3/Constant_output_0: 1 params, 0.01 KB
# /GAT_layer1/Concat_2_output_0: 3 params, 0.02 KB
# /GAT_layer1/Concat_1_output_0: 2 params, 0.02 KB
# /pool2/Reshape_output_0: 1 params, 0.01 KB
# /GAT_layer2/Mul_output_0: 4 params, 0.03 KB
# /Concat_output_0: 3 params, 0.02 KB
# GAT_layer3.bn.running_var: 16 params, 0.06 KB
# /GAT_layer3/Constant_1_output_0: 1 params, 0.01 KB
# GAT_layer3.bn.running_mean: 16 params, 0.06 KB
# /conv_time/Constant_24_output_0: 1 params, 0.01 KB
# /GAT_layer3/Unsqueeze_5_output_0: 1 params, 0.01 KB
# /GAT_layer1/Where_output_0: 4 params, 0.03 KB
# /GAT_layer3/Concat_1_output_0: 2 params, 0.02 KB
# /pool2/Unsqueeze_1_output_0: 1 params, 0.01 KB
# /pool1/Reshape_output_0: 1 params, 0.01 KB
# /GAT_layer3/Constant_8_output_0: 1 params, 0.01 KB
# /pool3/Unsqueeze_2_output_0: 1 params, 0.01 KB
# /pool3/Reshape_output_0: 1 params, 0.01 KB
# GAT_layer1.bn.running_mean: 32 params, 0.12 KB
# GAT_layer1.bn.running_var: 32 params, 0.12 KB
# /pool1/Unsqueeze_2_output_0: 1 params, 0.01 KB
# GAT_layer2.bn.running_mean: 32 params, 0.12 KB
# GAT_layer2.bn.running_var: 32 params, 0.12 KB
# gemm_input_shape: 2 params, 0.02 KB
# gemm_output_shape: 3 params, 0.02 KB
# gemm_input_shape_token_21: 2 params, 0.02 KB
# gemm_output_reshape_token_26_new_shape: 3 params, 0.02 KB
# gemm_input_shape_token_27: 2 params, 0.02 KB
# gemm_output_shape_token_30: 3 params, 0.02 KB
# gemm_input_shape_token_33: 2 params, 0.02 KB
# gemm_output_shape_token_36: 4 params, 0.03 KB
# gemm_input_shape_token_39: 2 params, 0.02 KB
# gemm_output_shape_token_42: 3 params, 0.02 KB
# gemm_input_shape_token_45: 2 params, 0.02 KB
# gemm_output_shape_token_48: 4 params, 0.03 KB
# gemm_input_shape_token_51: 2 params, 0.02 KB
# gemm_output_shape_token_54: 3 params, 0.02 KB
# /Reshape_output_0_zero_point: 1 params, 0.00 KB
# /Reshape_output_0_scale: 1 params, 0.00 KB
# /conv_time/Conv_output_0_zero_point: 1 params, 0.00 KB
# /conv_time/Conv_output_0_scale: 1 params, 0.00 KB
# /conv_time/Reshape_70_output_0_zero_point: 70 params, 0.07 KB
# /conv_time/Reshape_70_output_0_scale: 70 params, 0.27 KB
# /conv_time/Reshape_70_output_0_quantized: 9030 params, 8.82 KB
# /MaxPool_output_0_zero_point: 1 params, 0.00 KB
# /MaxPool_output_0_scale: 1 params, 0.00 KB
# first_bn.weight_zero_point: 1 params, 0.00 KB
# first_bn.weight_scale: 1 params, 0.00 KB
# first_bn.weight_quantized: 1 params, 0.00 KB
# /first_bn/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /first_bn/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# /selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder1/encoder1.0/encoder1.0.0/bn2/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.0/encoder1.0.0/bn2/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# ConvBnFusion_W_encoder1.0.0.conv_1.weight_zero_point: 32 params, 0.03 KB
# ConvBnFusion_W_encoder1.0.0.conv_1.weight_scale: 32 params, 0.12 KB
# ConvBnFusion_W_encoder1.0.0.conv_1.weight_quantized: 192 params, 0.19 KB
# /encoder1/encoder1.0/encoder1.0.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.0/encoder1.0.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder1/encoder1.0/encoder1.0.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.0/encoder1.0.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder1.0.0.conv2.weight_zero_point: 32 params, 0.03 KB
# encoder1.0.0.conv2.weight_scale: 32 params, 0.12 KB
# encoder1.0.0.conv2.weight_quantized: 6144 params, 6.00 KB
# /encoder1/encoder1.0/encoder1.0.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.0/encoder1.0.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder1/encoder1.1/encoder1.1.0/bn2/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.1/encoder1.1.0/bn2/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# ConvBnFusion_W_encoder1.1.0.conv1.weight_zero_point: 32 params, 0.03 KB
# ConvBnFusion_W_encoder1.1.0.conv1.weight_scale: 32 params, 0.12 KB
# ConvBnFusion_W_encoder1.1.0.conv1.weight_quantized: 6144 params, 6.00 KB
# /encoder1/encoder1.1/encoder1.1.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.1/encoder1.1.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder1/encoder1.1/encoder1.1.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.1/encoder1.1.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder1.1.0.conv2.weight_zero_point: 32 params, 0.03 KB
# encoder1.1.0.conv2.weight_scale: 32 params, 0.12 KB
# encoder1.1.0.conv2.weight_quantized: 6144 params, 6.00 KB
# /encoder1/encoder1.1/encoder1.1.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.1/encoder1.1.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder1/encoder1.2/encoder1.2.0/conv_downsample/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.2/encoder1.2.0/conv_downsample/Conv_output_0_scale: 1 params, 0.00 KB
# encoder1.2.0.conv_downsample.weight_zero_point: 64 params, 0.06 KB
# encoder1.2.0.conv_downsample.weight_scale: 64 params, 0.25 KB
# encoder1.2.0.conv_downsample.weight_quantized: 6144 params, 6.00 KB
# /encoder1/encoder1.2/encoder1.2.0/bn2/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.2/encoder1.2.0/bn2/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# ConvBnFusion_W_encoder1.2.0.conv1.weight_zero_point: 64 params, 0.06 KB
# ConvBnFusion_W_encoder1.2.0.conv1.weight_scale: 64 params, 0.25 KB
# ConvBnFusion_W_encoder1.2.0.conv1.weight_quantized: 12288 params, 12.00 KB
# /encoder1/encoder1.2/encoder1.2.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.2/encoder1.2.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder1/encoder1.2/encoder1.2.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.2/encoder1.2.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder1.2.0.conv2.weight_zero_point: 64 params, 0.06 KB
# encoder1.2.0.conv2.weight_scale: 64 params, 0.25 KB
# encoder1.2.0.conv2.weight_quantized: 24576 params, 24.00 KB
# /encoder1/encoder1.2/encoder1.2.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.2/encoder1.2.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder1/encoder1.3/encoder1.3.0/bn2/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.3/encoder1.3.0/bn2/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# ConvBnFusion_W_encoder1.3.0.conv1.weight_zero_point: 64 params, 0.06 KB
# ConvBnFusion_W_encoder1.3.0.conv1.weight_scale: 64 params, 0.25 KB
# ConvBnFusion_W_encoder1.3.0.conv1.weight_quantized: 24576 params, 24.00 KB
# /encoder1/encoder1.3/encoder1.3.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.3/encoder1.3.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder1/encoder1.3/encoder1.3.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.3/encoder1.3.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder1.3.0.conv2.weight_zero_point: 64 params, 0.06 KB
# encoder1.3.0.conv2.weight_scale: 64 params, 0.25 KB
# encoder1.3.0.conv2.weight_quantized: 24576 params, 24.00 KB
# /encoder1/encoder1.3/encoder1.3.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.3/encoder1.3.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder1/encoder1.4/encoder1.4.0/bn2/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.4/encoder1.4.0/bn2/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# ConvBnFusion_W_encoder1.4.0.conv1.weight_zero_point: 64 params, 0.06 KB
# ConvBnFusion_W_encoder1.4.0.conv1.weight_scale: 64 params, 0.25 KB
# ConvBnFusion_W_encoder1.4.0.conv1.weight_quantized: 24576 params, 24.00 KB
# /encoder1/encoder1.4/encoder1.4.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.4/encoder1.4.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder1/encoder1.4/encoder1.4.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.4/encoder1.4.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder1.4.0.conv2.weight_zero_point: 64 params, 0.06 KB
# encoder1.4.0.conv2.weight_scale: 64 params, 0.25 KB
# encoder1.4.0.conv2.weight_quantized: 24576 params, 24.00 KB
# /encoder1/encoder1.4/encoder1.4.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.4/encoder1.4.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder1/encoder1.5/encoder1.5.0/bn2/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.5/encoder1.5.0/bn2/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# ConvBnFusion_W_encoder1.5.0.conv1.weight_zero_point: 64 params, 0.06 KB
# ConvBnFusion_W_encoder1.5.0.conv1.weight_scale: 64 params, 0.25 KB
# ConvBnFusion_W_encoder1.5.0.conv1.weight_quantized: 24576 params, 24.00 KB
# /encoder1/encoder1.5/encoder1.5.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.5/encoder1.5.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder1/encoder1.5/encoder1.5.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.5/encoder1.5.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder1.5.0.conv2.weight_zero_point: 64 params, 0.06 KB
# encoder1.5.0.conv2.weight_scale: 64 params, 0.25 KB
# encoder1.5.0.conv2.weight_quantized: 24576 params, 24.00 KB
# /encoder1/encoder1.5/encoder1.5.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder1/encoder1.5/encoder1.5.0/Add_output_0_scale: 1 params, 0.00 KB
# /GAT_layer1/Expand_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer1/Expand_output_0_scale: 1 params, 0.00 KB
# /GAT_layer1/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer1/Transpose_output_0_scale: 1 params, 0.00 KB
# /GAT_layer1/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer1/Mul_1_output_0_scale: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_49_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_49_scale: 1 params, 0.00 KB
# /GAT_layer1/att_proj/Transpose_output_0_zero_point: 32 params, 0.03 KB
# /GAT_layer1/att_proj/Transpose_output_0_scale: 32 params, 0.12 KB
# /GAT_layer1/att_proj/Transpose_output_0_quantized: 2048 params, 2.00 KB
# /GAT_layer1/Tanh_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer1/Tanh_output_0_scale: 1 params, 0.00 KB
# GAT_layer1.att_weight_zero_point: 1 params, 0.00 KB
# GAT_layer1.att_weight_scale: 1 params, 0.00 KB
# GAT_layer1.att_weight_quantized: 32 params, 0.03 KB
# /GAT_layer1/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer1/MatMul_output_0_scale: 1 params, 0.00 KB
# /GAT_layer1/Softmax_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer1/Softmax_output_0_scale: 1 params, 0.00 KB
# /Transpose_output_0_zero_point: 1 params, 0.00 KB
# /Transpose_output_0_scale: 1 params, 0.00 KB
# /GAT_layer1/MatMul_1_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer1/MatMul_1_output_0_scale: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_55_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_55_scale: 1 params, 0.00 KB
# /GAT_layer1/proj_with_att/Transpose_output_0_zero_point: 32 params, 0.03 KB
# /GAT_layer1/proj_with_att/Transpose_output_0_scale: 32 params, 0.12 KB
# /GAT_layer1/proj_with_att/Transpose_output_0_quantized: 2048 params, 2.00 KB
# gemm_output_reshape_arg_token_43_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_43_scale: 1 params, 0.00 KB
# /GAT_layer1/proj_without_att/Transpose_output_0_zero_point: 32 params, 0.03 KB
# /GAT_layer1/proj_without_att/Transpose_output_0_scale: 32 params, 0.12 KB
# /GAT_layer1/proj_without_att/Transpose_output_0_quantized: 2048 params, 2.00 KB
# /GAT_layer1/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer1/Add_output_0_scale: 1 params, 0.00 KB
# GAT_layer1.bn.weight_zero_point: 1 params, 0.00 KB
# GAT_layer1.bn.weight_scale: 1 params, 0.00 KB
# GAT_layer1.bn.weight_quantized: 32 params, 0.03 KB
# /GAT_layer1/bn/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer1/bn/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# gemm_input_reshape_arg_zero_point: 1 params, 0.00 KB
# gemm_input_reshape_arg_scale: 1 params, 0.00 KB
# gemm_output_reshape_arg_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_scale: 1 params, 0.00 KB
# /pool1/proj/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /pool1/proj/Transpose_output_0_scale: 1 params, 0.00 KB
# /pool1/proj/Transpose_output_0_quantized: 32 params, 0.03 KB
# /pool1/sigmoid/Sigmoid_output_0_zero_point: 1 params, 0.00 KB
# /pool1/sigmoid/Sigmoid_output_0_scale: 1 params, 0.00 KB
# /GAT_layer1/act/Selu_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer1/act/Selu_output_0_scale: 1 params, 0.00 KB
# /pool1/Mul_output_0_zero_point: 1 params, 0.00 KB
# /pool1/Mul_output_0_scale: 1 params, 0.00 KB
# /pool1/Concat_output_0_zero_point: 1 params, 0.00 KB
# /pool1/Concat_output_0_scale: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_25_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_25_scale: 1 params, 0.00 KB
# /proj1/Transpose_output_0_zero_point: 12 params, 0.01 KB
# /proj1/Transpose_output_0_scale: 12 params, 0.05 KB
# /proj1/Transpose_output_0_quantized: 168 params, 0.16 KB
# /encoder2/encoder2.0/encoder2.0.0/bn2/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.0/encoder2.0.0/bn2/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# ConvBnFusion_W_encoder2.0.0.conv_1.weight_zero_point: 32 params, 0.03 KB
# ConvBnFusion_W_encoder2.0.0.conv_1.weight_scale: 32 params, 0.12 KB
# ConvBnFusion_W_encoder2.0.0.conv_1.weight_quantized: 192 params, 0.19 KB
# /encoder2/encoder2.0/encoder2.0.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.0/encoder2.0.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder2/encoder2.0/encoder2.0.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.0/encoder2.0.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder2.0.0.conv2.weight_zero_point: 32 params, 0.03 KB
# encoder2.0.0.conv2.weight_scale: 32 params, 0.12 KB
# encoder2.0.0.conv2.weight_quantized: 6144 params, 6.00 KB
# /encoder2/encoder2.0/encoder2.0.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.0/encoder2.0.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder2/encoder2.1/encoder2.1.0/bn2/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.1/encoder2.1.0/bn2/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# ConvBnFusion_W_encoder2.1.0.conv1.weight_zero_point: 32 params, 0.03 KB
# ConvBnFusion_W_encoder2.1.0.conv1.weight_scale: 32 params, 0.12 KB
# ConvBnFusion_W_encoder2.1.0.conv1.weight_quantized: 6144 params, 6.00 KB
# /encoder2/encoder2.1/encoder2.1.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.1/encoder2.1.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder2/encoder2.1/encoder2.1.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.1/encoder2.1.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder2.1.0.conv2.weight_zero_point: 32 params, 0.03 KB
# encoder2.1.0.conv2.weight_scale: 32 params, 0.12 KB
# encoder2.1.0.conv2.weight_quantized: 6144 params, 6.00 KB
# /encoder2/encoder2.1/encoder2.1.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.1/encoder2.1.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder2/encoder2.2/encoder2.2.0/conv_downsample/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.2/encoder2.2.0/conv_downsample/Conv_output_0_scale: 1 params, 0.00 KB
# encoder2.2.0.conv_downsample.weight_zero_point: 64 params, 0.06 KB
# encoder2.2.0.conv_downsample.weight_scale: 64 params, 0.25 KB
# encoder2.2.0.conv_downsample.weight_quantized: 6144 params, 6.00 KB
# /encoder2/encoder2.2/encoder2.2.0/bn2/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.2/encoder2.2.0/bn2/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# ConvBnFusion_W_encoder2.2.0.conv1.weight_zero_point: 64 params, 0.06 KB
# ConvBnFusion_W_encoder2.2.0.conv1.weight_scale: 64 params, 0.25 KB
# ConvBnFusion_W_encoder2.2.0.conv1.weight_quantized: 12288 params, 12.00 KB
# /encoder2/encoder2.2/encoder2.2.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.2/encoder2.2.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder2/encoder2.2/encoder2.2.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.2/encoder2.2.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder2.2.0.conv2.weight_zero_point: 64 params, 0.06 KB
# encoder2.2.0.conv2.weight_scale: 64 params, 0.25 KB
# encoder2.2.0.conv2.weight_quantized: 24576 params, 24.00 KB
# /encoder2/encoder2.2/encoder2.2.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.2/encoder2.2.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder2/encoder2.3/encoder2.3.0/bn2/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.3/encoder2.3.0/bn2/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# ConvBnFusion_W_encoder2.3.0.conv1.weight_zero_point: 64 params, 0.06 KB
# ConvBnFusion_W_encoder2.3.0.conv1.weight_scale: 64 params, 0.25 KB
# ConvBnFusion_W_encoder2.3.0.conv1.weight_quantized: 24576 params, 24.00 KB
# /encoder2/encoder2.3/encoder2.3.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.3/encoder2.3.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder2/encoder2.3/encoder2.3.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.3/encoder2.3.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder2.3.0.conv2.weight_zero_point: 64 params, 0.06 KB
# encoder2.3.0.conv2.weight_scale: 64 params, 0.25 KB
# encoder2.3.0.conv2.weight_quantized: 24576 params, 24.00 KB
# /encoder2/encoder2.3/encoder2.3.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.3/encoder2.3.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder2/encoder2.4/encoder2.4.0/bn2/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.4/encoder2.4.0/bn2/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# ConvBnFusion_W_encoder2.4.0.conv1.weight_zero_point: 64 params, 0.06 KB
# ConvBnFusion_W_encoder2.4.0.conv1.weight_scale: 64 params, 0.25 KB
# ConvBnFusion_W_encoder2.4.0.conv1.weight_quantized: 24576 params, 24.00 KB
# /encoder2/encoder2.4/encoder2.4.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.4/encoder2.4.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder2/encoder2.4/encoder2.4.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.4/encoder2.4.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder2.4.0.conv2.weight_zero_point: 64 params, 0.06 KB
# encoder2.4.0.conv2.weight_scale: 64 params, 0.25 KB
# encoder2.4.0.conv2.weight_quantized: 24576 params, 24.00 KB
# /encoder2/encoder2.4/encoder2.4.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.4/encoder2.4.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder2/encoder2.5/encoder2.5.0/bn2/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.5/encoder2.5.0/bn2/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# ConvBnFusion_W_encoder2.5.0.conv1.weight_zero_point: 64 params, 0.06 KB
# ConvBnFusion_W_encoder2.5.0.conv1.weight_scale: 64 params, 0.25 KB
# ConvBnFusion_W_encoder2.5.0.conv1.weight_quantized: 24576 params, 24.00 KB
# /encoder2/encoder2.5/encoder2.5.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.5/encoder2.5.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder2/encoder2.5/encoder2.5.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.5/encoder2.5.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder2.5.0.conv2.weight_zero_point: 64 params, 0.06 KB
# encoder2.5.0.conv2.weight_scale: 64 params, 0.25 KB
# encoder2.5.0.conv2.weight_quantized: 24576 params, 24.00 KB
# /encoder2/encoder2.5/encoder2.5.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder2/encoder2.5/encoder2.5.0/Add_output_0_scale: 1 params, 0.00 KB
# /Transpose_2_output_0_zero_point: 1 params, 0.00 KB
# /Transpose_2_output_0_scale: 1 params, 0.00 KB
# /GAT_layer2/proj_without_att/Transpose_output_0_zero_point: 32 params, 0.03 KB
# /GAT_layer2/proj_without_att/Transpose_output_0_scale: 32 params, 0.12 KB
# /GAT_layer2/proj_without_att/Transpose_output_0_quantized: 2048 params, 2.00 KB
# /GAT_layer2/proj_without_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/proj_without_att/MatMul_output_0_scale: 1 params, 0.00 KB
# GAT_layer2.proj_with_att.bias_zero_point: 1 params, 0.00 KB
# GAT_layer2.proj_with_att.bias_scale: 1 params, 0.00 KB
# GAT_layer2.proj_with_att.bias_quantized: 32 params, 0.03 KB
# /GAT_layer2/proj_without_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/proj_without_att/Add_output_0_scale: 1 params, 0.00 KB
# /GAT_layer2/Expand_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/Expand_output_0_scale: 1 params, 0.00 KB
# /GAT_layer2/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/Transpose_output_0_scale: 1 params, 0.00 KB
# /GAT_layer2/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/Mul_1_output_0_scale: 1 params, 0.00 KB
# /GAT_layer2/att_proj/Transpose_output_0_zero_point: 32 params, 0.03 KB
# /GAT_layer2/att_proj/Transpose_output_0_scale: 32 params, 0.12 KB
# /GAT_layer2/att_proj/Transpose_output_0_quantized: 2048 params, 2.00 KB
# /GAT_layer2/att_proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/att_proj/MatMul_output_0_scale: 1 params, 0.00 KB
# GAT_layer2.att_proj.bias_zero_point: 1 params, 0.00 KB
# GAT_layer2.att_proj.bias_scale: 1 params, 0.00 KB
# GAT_layer2.att_proj.bias_quantized: 32 params, 0.03 KB
# /GAT_layer2/att_proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/att_proj/Add_output_0_scale: 1 params, 0.00 KB
# /GAT_layer2/Tanh_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/Tanh_output_0_scale: 1 params, 0.00 KB
# GAT_layer2.att_weight_zero_point: 1 params, 0.00 KB
# GAT_layer2.att_weight_scale: 1 params, 0.00 KB
# GAT_layer2.att_weight_quantized: 32 params, 0.03 KB
# /GAT_layer2/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/MatMul_output_0_scale: 1 params, 0.00 KB
# /GAT_layer2/Softmax_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/Softmax_output_0_scale: 1 params, 0.00 KB
# /GAT_layer2/MatMul_1_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/MatMul_1_output_0_scale: 1 params, 0.00 KB
# /GAT_layer2/proj_with_att/Transpose_output_0_zero_point: 32 params, 0.03 KB
# /GAT_layer2/proj_with_att/Transpose_output_0_scale: 32 params, 0.12 KB
# /GAT_layer2/proj_with_att/Transpose_output_0_quantized: 2048 params, 2.00 KB
# /GAT_layer2/proj_with_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/proj_with_att/MatMul_output_0_scale: 1 params, 0.00 KB
# /GAT_layer2/proj_with_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/proj_with_att/Add_output_0_scale: 1 params, 0.00 KB
# /GAT_layer2/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/Add_output_0_scale: 1 params, 0.00 KB
# GAT_layer2.bn.weight_zero_point: 1 params, 0.00 KB
# GAT_layer2.bn.weight_scale: 1 params, 0.00 KB
# GAT_layer2.bn.weight_quantized: 32 params, 0.03 KB
# /GAT_layer2/bn/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/bn/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# /GAT_layer2/act/Selu_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer2/act/Selu_output_0_scale: 1 params, 0.00 KB
# /pool2/proj/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /pool2/proj/Transpose_output_0_scale: 1 params, 0.00 KB
# /pool2/proj/Transpose_output_0_quantized: 32 params, 0.03 KB
# /pool2/proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /pool2/proj/MatMul_output_0_scale: 1 params, 0.00 KB
# pool2.proj.bias_zero_point: 1 params, 0.00 KB
# pool2.proj.bias_scale: 1 params, 0.00 KB
# pool2.proj.bias_quantized: 1 params, 0.00 KB
# /pool2/proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /pool2/proj/Add_output_0_scale: 1 params, 0.00 KB
# /pool2/sigmoid/Sigmoid_output_0_zero_point: 1 params, 0.00 KB
# /pool2/sigmoid/Sigmoid_output_0_scale: 1 params, 0.00 KB
# /pool2/Mul_output_0_zero_point: 1 params, 0.00 KB
# /pool2/Mul_output_0_scale: 1 params, 0.00 KB
# /pool2/Concat_output_0_zero_point: 1 params, 0.00 KB
# /pool2/Concat_output_0_scale: 1 params, 0.00 KB
# /proj2/Transpose_output_0_zero_point: 12 params, 0.01 KB
# /proj2/Transpose_output_0_scale: 12 params, 0.05 KB
# /proj2/Transpose_output_0_quantized: 276 params, 0.27 KB
# /proj2/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /proj2/MatMul_output_0_scale: 1 params, 0.00 KB
# proj2.bias_zero_point: 1 params, 0.00 KB
# proj2.bias_scale: 1 params, 0.00 KB
# proj2.bias_quantized: 12 params, 0.01 KB
# /proj2/Add_output_0_zero_point: 1 params, 0.00 KB
# /proj2/Add_output_0_scale: 1 params, 0.00 KB
# /Mul_output_0_zero_point: 1 params, 0.00 KB
# /Mul_output_0_scale: 1 params, 0.00 KB
# /GAT_layer3/proj_without_att/Transpose_output_0_zero_point: 16 params, 0.02 KB
# /GAT_layer3/proj_without_att/Transpose_output_0_scale: 16 params, 0.06 KB
# /GAT_layer3/proj_without_att/Transpose_output_0_quantized: 512 params, 0.50 KB
# /GAT_layer3/proj_without_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/proj_without_att/MatMul_output_0_scale: 1 params, 0.00 KB
# GAT_layer3.proj_with_att.bias_zero_point: 1 params, 0.00 KB
# GAT_layer3.proj_with_att.bias_scale: 1 params, 0.00 KB
# GAT_layer3.proj_with_att.bias_quantized: 16 params, 0.02 KB
# /GAT_layer3/proj_without_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/proj_without_att/Add_output_0_scale: 1 params, 0.00 KB
# /GAT_layer3/Expand_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/Expand_output_0_scale: 1 params, 0.00 KB
# /GAT_layer3/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/Transpose_output_0_scale: 1 params, 0.00 KB
# /GAT_layer3/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/Mul_1_output_0_scale: 1 params, 0.00 KB
# /GAT_layer3/att_proj/Transpose_output_0_zero_point: 16 params, 0.02 KB
# /GAT_layer3/att_proj/Transpose_output_0_scale: 16 params, 0.06 KB
# /GAT_layer3/att_proj/Transpose_output_0_quantized: 512 params, 0.50 KB
# /GAT_layer3/att_proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/att_proj/MatMul_output_0_scale: 1 params, 0.00 KB
# GAT_layer3.att_proj.bias_zero_point: 1 params, 0.00 KB
# GAT_layer3.att_proj.bias_scale: 1 params, 0.00 KB
# GAT_layer3.att_proj.bias_quantized: 16 params, 0.02 KB
# /GAT_layer3/att_proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/att_proj/Add_output_0_scale: 1 params, 0.00 KB
# /GAT_layer3/Tanh_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/Tanh_output_0_scale: 1 params, 0.00 KB
# GAT_layer3.att_weight_zero_point: 1 params, 0.00 KB
# GAT_layer3.att_weight_scale: 1 params, 0.00 KB
# GAT_layer3.att_weight_quantized: 16 params, 0.02 KB
# /GAT_layer3/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/MatMul_output_0_scale: 1 params, 0.00 KB
# /GAT_layer3/Softmax_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/Softmax_output_0_scale: 1 params, 0.00 KB
# /GAT_layer3/MatMul_1_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/MatMul_1_output_0_scale: 1 params, 0.00 KB
# /GAT_layer3/proj_with_att/Transpose_output_0_zero_point: 16 params, 0.02 KB
# /GAT_layer3/proj_with_att/Transpose_output_0_scale: 16 params, 0.06 KB
# /GAT_layer3/proj_with_att/Transpose_output_0_quantized: 512 params, 0.50 KB
# /GAT_layer3/proj_with_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/proj_with_att/MatMul_output_0_scale: 1 params, 0.00 KB
# /GAT_layer3/proj_with_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/proj_with_att/Add_output_0_scale: 1 params, 0.00 KB
# /GAT_layer3/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/Add_output_0_scale: 1 params, 0.00 KB
# GAT_layer3.bn.weight_zero_point: 1 params, 0.00 KB
# GAT_layer3.bn.weight_scale: 1 params, 0.00 KB
# GAT_layer3.bn.weight_quantized: 16 params, 0.02 KB
# /GAT_layer3/bn/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/bn/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# gemm_input_reshape_arg_token_28_zero_point: 1 params, 0.00 KB
# gemm_input_reshape_arg_token_28_scale: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_31_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_31_scale: 1 params, 0.00 KB
# /pool3/proj/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /pool3/proj/Transpose_output_0_scale: 1 params, 0.00 KB
# /pool3/proj/Transpose_output_0_quantized: 16 params, 0.02 KB
# /pool3/sigmoid/Sigmoid_output_0_zero_point: 1 params, 0.00 KB
# /pool3/sigmoid/Sigmoid_output_0_scale: 1 params, 0.00 KB
# /GAT_layer3/act/Selu_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer3/act/Selu_output_0_scale: 1 params, 0.00 KB
# /pool3/Mul_output_0_zero_point: 1 params, 0.00 KB
# /pool3/Mul_output_0_scale: 1 params, 0.00 KB
# /pool3/Concat_output_0_zero_point: 1 params, 0.00 KB
# /pool3/Concat_output_0_scale: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_37_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_37_scale: 1 params, 0.00 KB
# /proj/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /proj/Transpose_output_0_scale: 1 params, 0.00 KB
# /proj/Transpose_output_0_quantized: 16 params, 0.02 KB
# /Flatten_output_0_zero_point: 1 params, 0.00 KB
# /Flatten_output_0_scale: 1 params, 0.00 KB
# logits_zero_point: 1 params, 0.00 KB
# logits_scale: 1 params, 0.00 KB
# proj_node.weight_zero_point: 2 params, 0.00 KB
# proj_node.weight_scale: 2 params, 0.01 KB
# proj_node.weight_quantized: 14 params, 0.01 KB
# first_bn.bias_quantized: 1 params, 0.00 KB
# first_bn.bias_quantized_scale: 1 params, 0.00 KB
# first_bn.bias_quantized_zero_point: 1 params, 0.00 KB
# ConvBnFusion_BN_B_encoder1.0.0.bn2.bias_quantized: 32 params, 0.12 KB
# ConvBnFusion_BN_B_encoder1.0.0.bn2.bias_quantized_scale: 32 params, 0.12 KB
# ConvBnFusion_BN_B_encoder1.0.0.bn2.bias_quantized_zero_point: 32 params, 0.12 KB
# encoder1.0.0.conv2.bias_quantized: 32 params, 0.12 KB
# encoder1.0.0.conv2.bias_quantized_scale: 32 params, 0.12 KB
# encoder1.0.0.conv2.bias_quantized_zero_point: 32 params, 0.12 KB
# ConvBnFusion_BN_B_encoder1.1.0.bn2.bias_quantized: 32 params, 0.12 KB
# ConvBnFusion_BN_B_encoder1.1.0.bn2.bias_quantized_scale: 32 params, 0.12 KB
# ConvBnFusion_BN_B_encoder1.1.0.bn2.bias_quantized_zero_point: 32 params, 0.12 KB
# encoder1.1.0.conv2.bias_quantized: 32 params, 0.12 KB
# encoder1.1.0.conv2.bias_quantized_scale: 32 params, 0.12 KB
# encoder1.1.0.conv2.bias_quantized_zero_point: 32 params, 0.12 KB
# encoder1.2.0.conv_downsample.bias_quantized: 64 params, 0.25 KB
# encoder1.2.0.conv_downsample.bias_quantized_scale: 64 params, 0.25 KB
# encoder1.2.0.conv_downsample.bias_quantized_zero_point: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder1.2.0.bn2.bias_quantized: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder1.2.0.bn2.bias_quantized_scale: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder1.2.0.bn2.bias_quantized_zero_point: 64 params, 0.25 KB
# encoder1.2.0.conv2.bias_quantized: 64 params, 0.25 KB
# encoder1.2.0.conv2.bias_quantized_scale: 64 params, 0.25 KB
# encoder1.2.0.conv2.bias_quantized_zero_point: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder1.3.0.bn2.bias_quantized: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder1.3.0.bn2.bias_quantized_scale: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder1.3.0.bn2.bias_quantized_zero_point: 64 params, 0.25 KB
# encoder1.3.0.conv2.bias_quantized: 64 params, 0.25 KB
# encoder1.3.0.conv2.bias_quantized_scale: 64 params, 0.25 KB
# encoder1.3.0.conv2.bias_quantized_zero_point: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder1.4.0.bn2.bias_quantized: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder1.4.0.bn2.bias_quantized_scale: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder1.4.0.bn2.bias_quantized_zero_point: 64 params, 0.25 KB
# encoder1.4.0.conv2.bias_quantized: 64 params, 0.25 KB
# encoder1.4.0.conv2.bias_quantized_scale: 64 params, 0.25 KB
# encoder1.4.0.conv2.bias_quantized_zero_point: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder1.5.0.bn2.bias_quantized: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder1.5.0.bn2.bias_quantized_scale: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder1.5.0.bn2.bias_quantized_zero_point: 64 params, 0.25 KB
# encoder1.5.0.conv2.bias_quantized: 64 params, 0.25 KB
# encoder1.5.0.conv2.bias_quantized_scale: 64 params, 0.25 KB
# encoder1.5.0.conv2.bias_quantized_zero_point: 64 params, 0.25 KB
# GAT_layer1.att_proj.bias_quantized: 32 params, 0.12 KB
# GAT_layer1.att_proj.bias_quantized_scale: 32 params, 0.12 KB
# GAT_layer1.att_proj.bias_quantized_zero_point: 32 params, 0.12 KB
# GAT_layer1.proj_with_att.bias_quantized: 32 params, 0.12 KB
# GAT_layer1.proj_with_att.bias_quantized_scale: 32 params, 0.12 KB
# GAT_layer1.proj_with_att.bias_quantized_zero_point: 32 params, 0.12 KB
# GAT_layer1.proj_with_att.bias0_quantized: 32 params, 0.12 KB
# GAT_layer1.proj_with_att.bias0_quantized_scale: 32 params, 0.12 KB
# GAT_layer1.proj_with_att.bias0_quantized_zero_point: 32 params, 0.12 KB
# GAT_layer1.bn.bias_quantized: 32 params, 0.12 KB
# GAT_layer1.bn.bias_quantized_scale: 1 params, 0.00 KB
# GAT_layer1.bn.bias_quantized_zero_point: 1 params, 0.00 KB
# pool1.proj.bias_quantized: 1 params, 0.00 KB
# pool1.proj.bias_quantized_scale: 1 params, 0.00 KB
# pool1.proj.bias_quantized_zero_point: 1 params, 0.00 KB
# proj1.bias_quantized: 12 params, 0.05 KB
# proj1.bias_quantized_scale: 12 params, 0.05 KB
# proj1.bias_quantized_zero_point: 12 params, 0.05 KB
# ConvBnFusion_BN_B_encoder2.0.0.bn2.bias_quantized: 32 params, 0.12 KB
# ConvBnFusion_BN_B_encoder2.0.0.bn2.bias_quantized_scale: 32 params, 0.12 KB
# ConvBnFusion_BN_B_encoder2.0.0.bn2.bias_quantized_zero_point: 32 params, 0.12 KB
# encoder2.0.0.conv2.bias_quantized: 32 params, 0.12 KB
# encoder2.0.0.conv2.bias_quantized_scale: 32 params, 0.12 KB
# encoder2.0.0.conv2.bias_quantized_zero_point: 32 params, 0.12 KB
# ConvBnFusion_BN_B_encoder2.1.0.bn2.bias_quantized: 32 params, 0.12 KB
# ConvBnFusion_BN_B_encoder2.1.0.bn2.bias_quantized_scale: 32 params, 0.12 KB
# ConvBnFusion_BN_B_encoder2.1.0.bn2.bias_quantized_zero_point: 32 params, 0.12 KB
# encoder2.1.0.conv2.bias_quantized: 32 params, 0.12 KB
# encoder2.1.0.conv2.bias_quantized_scale: 32 params, 0.12 KB
# encoder2.1.0.conv2.bias_quantized_zero_point: 32 params, 0.12 KB
# encoder2.2.0.conv_downsample.bias_quantized: 64 params, 0.25 KB
# encoder2.2.0.conv_downsample.bias_quantized_scale: 64 params, 0.25 KB
# encoder2.2.0.conv_downsample.bias_quantized_zero_point: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder2.2.0.bn2.bias_quantized: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder2.2.0.bn2.bias_quantized_scale: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder2.2.0.bn2.bias_quantized_zero_point: 64 params, 0.25 KB
# encoder2.2.0.conv2.bias_quantized: 64 params, 0.25 KB
# encoder2.2.0.conv2.bias_quantized_scale: 64 params, 0.25 KB
# encoder2.2.0.conv2.bias_quantized_zero_point: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder2.3.0.bn2.bias_quantized: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder2.3.0.bn2.bias_quantized_scale: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder2.3.0.bn2.bias_quantized_zero_point: 64 params, 0.25 KB
# encoder2.3.0.conv2.bias_quantized: 64 params, 0.25 KB
# encoder2.3.0.conv2.bias_quantized_scale: 64 params, 0.25 KB
# encoder2.3.0.conv2.bias_quantized_zero_point: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder2.4.0.bn2.bias_quantized: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder2.4.0.bn2.bias_quantized_scale: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder2.4.0.bn2.bias_quantized_zero_point: 64 params, 0.25 KB
# encoder2.4.0.conv2.bias_quantized: 64 params, 0.25 KB
# encoder2.4.0.conv2.bias_quantized_scale: 64 params, 0.25 KB
# encoder2.4.0.conv2.bias_quantized_zero_point: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder2.5.0.bn2.bias_quantized: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder2.5.0.bn2.bias_quantized_scale: 64 params, 0.25 KB
# ConvBnFusion_BN_B_encoder2.5.0.bn2.bias_quantized_zero_point: 64 params, 0.25 KB
# encoder2.5.0.conv2.bias_quantized: 64 params, 0.25 KB
# encoder2.5.0.conv2.bias_quantized_scale: 64 params, 0.25 KB
# encoder2.5.0.conv2.bias_quantized_zero_point: 64 params, 0.25 KB
# GAT_layer2.bn.bias_quantized: 32 params, 0.12 KB
# GAT_layer2.bn.bias_quantized_scale: 1 params, 0.00 KB
# GAT_layer2.bn.bias_quantized_zero_point: 1 params, 0.00 KB
# GAT_layer3.bn.bias_quantized: 16 params, 0.06 KB
# GAT_layer3.bn.bias_quantized_scale: 1 params, 0.00 KB
# GAT_layer3.bn.bias_quantized_zero_point: 1 params, 0.00 KB
# pool3.proj.bias_quantized: 1 params, 0.00 KB
# pool3.proj.bias_quantized_scale: 1 params, 0.00 KB
# pool3.proj.bias_quantized_zero_point: 1 params, 0.00 KB
# proj.bias_quantized: 1 params, 0.00 KB
# proj.bias_quantized_scale: 1 params, 0.00 KB
# proj.bias_quantized_zero_point: 1 params, 0.00 KB
# proj_node.bias_quantized: 2 params, 0.01 KB
# proj_node.bias_quantized_scale: 2 params, 0.01 KB
# proj_node.bias_quantized_zero_point: 2 params, 0.01 KB
#
# Total parameters: 450524
# Total weights size: 0.45 MB

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/rawgat_st.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_set1 \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_original_eval_1.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=444, TN=45, FP=1, FN=10
# Accuracy: 0.9780
# FPR: 0.0217   FNR: 0.0220   EER: 0.0219
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_original_eval_1.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/rawgat_st.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_set2 \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_original_eval_2.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=427, TN=57, FP=0, FN=16
# Accuracy: 0.9680
# FPR: 0.0000   FNR: 0.0361   EER: 0.0181
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_original_eval_2.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/rawgat_st.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_set3 \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_original_eval_3.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=432, TN=54, FP=0, FN=14
# Accuracy: 0.9720
# FPR: 0.0000   FNR: 0.0314   EER: 0.0157
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_original_eval_3.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/rawgat_st.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_set4 \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_original_eval_4.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=427, TN=62, FP=0, FN=11
# Accuracy: 0.9780
# FPR: 0.0000   FNR: 0.0251   EER: 0.0126
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_original_eval_4.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/drive/MyDrive/Researches/Anti_spoofing/rawgat-st/rawgat_int8_scheme_1.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_1.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=377, TN=65, FP=0, FN=58
# Accuracy: 0.8840
# FPR: 0.0000   FNR: 0.1333   EER: 0.0667
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_1.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/drive/MyDrive/Researches/Anti_spoofing/rawgat-st/rawgat_int8_scheme_2.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_2.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=435, TN=0, FP=65, FN=0
# Accuracy: 0.8700
# FPR: 1.0000   FNR: 0.0000   EER: 0.5000
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_2.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/drive/MyDrive/Researches/Anti_spoofing/rawgat-st/rawgat_int8_scheme_3.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_3.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=422, TN=31, FP=34, FN=13
# Accuracy: 0.9060
# FPR: 0.5231   FNR: 0.0299   EER: 0.2765
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_3.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/drive/MyDrive/Researches/Anti_spoofing/rawgat-st/rawgat_int8_scheme_4.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_4.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=435, TN=0, FP=65, FN=0
# Accuracy: 0.8700
# FPR: 1.0000   FNR: 0.0000   EER: 0.5000
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_4.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/drive/MyDrive/Researches/Anti_spoofing/rawgat-st/rawgat_int8_scheme_5.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_5.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=435, TN=0, FP=65, FN=0
# Accuracy: 0.8700
# FPR: 1.0000   FNR: 0.0000   EER: 0.5000
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_5.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/drive/MyDrive/Researches/Anti_spoofing/rawgat-st/rawgat_int8_scheme_6.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_6.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=435, TN=0, FP=65, FN=0
# Accuracy: 0.8700
# FPR: 1.0000   FNR: 0.0000   EER: 0.5000
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_6.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/drive/MyDrive/Researches/Anti_spoofing/rawgat-st/rawgat_int8_scheme_7.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_7.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=407, TN=27, FP=38, FN=28
# Accuracy: 0.8680
# FPR: 0.5846   FNR: 0.0644   EER: 0.3245
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_7.png

# %%
# %cd /content/RawGAT-ST-antispoofing/
# !python evaluate_rawgat.py \
    --onnx_model_path /content/drive/MyDrive/Researches/Anti_spoofing/rawgat-st/rawgat_int8_scheme_8.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_8.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/RawGAT-ST-antispoofing
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=430, TN=9, FP=56, FN=5
# Accuracy: 0.8780
# FPR: 0.8615   FNR: 0.0115   EER: 0.4365
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/rawgat_int8_scheme_8.png

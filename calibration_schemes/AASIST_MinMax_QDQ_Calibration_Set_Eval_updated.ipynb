# %% [markdown]
# <a href="https://colab.research.google.com/github/KhangVGU/embedded_anti_spoofing_stm32/blob/main/calibration_schemes/AASIST_MinMax_QDQ_Calibration_Set_Eval_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Researches/Anti_spoofing
# !git clone https://github.com/clovaai/aasist.git
# Out:
# /content/drive/MyDrive/Researches/Anti spoofing
# Cloning into 'aasist'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 38 (delta 9), reused 3 (delta 3), pack-reused 16 (from 1)
# Receiving objects: 100% (38/38), 1.43 MiB | 29.22 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
# %cd /content/drive/MyDrive/Researches/Anti_spoofing/aasist
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/Researches/Anti_spoofing/aasist
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (2.6.0+cu124)
# Collecting torchcontrib (from -r requirements.txt (line 2))
#   Downloading torchcontrib-0.0.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (0.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.6.0->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.6.0->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.6.0->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.6.0->-r requirements.txt (line 1))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.6.0->-r requirements.txt (line 1))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.6.0->-r requirements.txt (line 1))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.6.0->-r requirements.txt (line 1))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.6.0->-r requirements.txt (line 1))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.6.0->-r requirements.txt (line 1))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.6.0->-r requirements.txt (line 1))
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.6.0->-r requirements.txt (line 1))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.6.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile->-r requirements.txt (line 4)) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 4)) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.6.0->-r requirements.txt (line 1)) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 121.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 16.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.9 MB/s eta 0:00:00
# Building wheels for collected packages: torchcontrib
#   Building wheel for torchcontrib (setup.py) ... done
#   Created wheel for torchcontrib: filename=torchcontrib-0.0.2-py3-none-any.whl size=7516 sha256=5e71f79eb8fb243aaea6656a5f4aa8845d394f1c50ff75906b41f0c40122cd01
#   Stored in directory: /root/.cache/pip/wheels/f1/87/f6/b3c995670297d282da49c39ea210c39fc8089c27f453bc1c42
# Successfully built torchcontrib
# Installing collected packages: torchcontrib, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 torchcontrib-0.0.2

# %%
from google.colab import drive
import os

# 1. Mount Google Drive
# drive.mount('/content/drive')

# 2. Change this to your target folder inside Google Drive
# Example: MyDrive/MyProject
target_folder = '/content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_eval'

# 3. Change this to your ZIP file name (must be in target_folder)
zip_filename = 'eval.zip'

# Navigate to the target folder
os.chdir(target_folder)

# 4. Unzip the file
# !unzip -o "{zip_filename}"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: eval/LA_E_9452493.flac
#   inflating: eval/LA_E_9452505.flac
#   inflating: eval/LA_E_9452579.flac
#   inflating: eval/LA_E_9452660.flac
#   inflating: eval/LA_E_9452672.flac
#   inflating: eval/LA_E_9452673.flac
#   inflating: eval/LA_E_9452703.flac
#   inflating: eval/LA_E_9452794.flac
#   inflating: eval/LA_E_9452810.flac
#   inflating: eval/LA_E_9452918.flac
#   inflating: eval/LA_E_9452979.flac
#   inflating: eval/LA_E_9452980.flac
#   inflating: eval/LA_E_9453205.flac
#   inflating: eval/LA_E_9453229.flac
#   inflating: eval/LA_E_9608364.flac
#   inflating: eval/LA_E_9608685.flac
#   inflating: eval/LA_E_9608841.flac
#   inflating: eval/LA_E_9609006.flac
#   inflating: eval/LA_E_9609175.flac
#   inflating: eval/LA_E_9609179.flac
# ...
#   inflating: eval/LA_E_A4704011.flac
#   inflating: eval/LA_E_A4707130.flac
#   inflating: eval/LA_E_A4707964.flac
#   inflating: eval/LA_E_A4712026.flac
#   inflating: eval/LA_E_A4713889.flac
#   inflating: eval/LA_E_A4717284.flac
#   inflating: eval/LA_E_A4717497.flac
#   inflating: eval/LA_E_A4720897.flac
#   inflating: eval/LA_E_A4722070.flac
#   inflating: eval/LA_E_A4727672.flac
#   inflating: eval/LA_E_A4748816.flac
#   inflating: eval/LA_E_A4759484.flac
#   inflating: eval/LA_E_A4791598.flac
#   inflating: eval/LA_E_A4798522.flac
#   inflating: eval/LA_E_A4801136.flac
#   inflating: eval/LA_E_A4850706.flac
#   inflating: eval/LA_E_A4877678.flac
#   inflating: eval/LA_E_A4901704.flac
#   inflating: eval/LA_E_A4919423.flac
#   inflating: eval/LA_E_A4922158.flac
#   inflating: eval/LA_E_A4969008.flac
#   inflating: eval/LA_E_A4969429.flac
#   inflating: eval/LA_E_A4969775.flac
#   inflating: eval/LA_E_A4994837.flac
#   inflating: eval/LA_E_A5037636.flac
#   inflating: eval/LA_E_A5038290.flac
#   inflating: eval/LA_E_A5038438.flac
#   inflating: eval/LA_E_A5052570.flac
#   inflating: eval/LA_E_A5065809.flac
#   inflating: eval/LA_E_A5069362.flac
#   inflating: eval/LA_E_A5080077.flac
#   inflating: eval/LA_E_A5090657.flac
#   inflating: eval/LA_E_A5097897.flac
#   inflating: eval/LA_E_A5117382.flac
#   inflating: eval/LA_E_A5122263.flac
#   inflating: eval/LA_E_A5124438.flac
#   inflating: eval/LA_E_A5206867.flac
#   inflating: eval/LA_E_A5208875.flac
#   inflating: eval/LA_E_A5209228.flac
#   inflating: eval/LA_E_A5227434.flac
#   inflating: eval/LA_E_A5239949.flac
#   inflating: eval/LA_E_A5247656.flac
#   inflating: eval/LA_E_A5271858.flac
#   inflating: eval/LA_E_A5304363.flac
#   inflating: eval/LA_E_A5384841.flac
#   inflating: eval/LA_E_A5390276.flac
#   inflating: eval/LA_E_A5459864.flac
#   inflating: eval/LA_E_A5462934.flac
#   inflating: eval/LA_E_A5464563.flac
#   inflating: eval/LA_E_A5467066.flac
#   inflating: eval/LA_E_A5475189.flac
#   inflating: eval/LA_E_A5518426.flac
#   inflating: eval/LA_E_A5523997.flac
#   inflating: eval/LA_E_A5555947.flac
#   inflating: eval/LA_E_A5584172.flac
#   inflating: eval/LA_E_A5591943.flac
#   inflating: eval/LA_E_A5641333.flac
#   inflating: eval/LA_E_A5646760.flac
#   inflating: eval/LA_E_A5683769.flac
#   inflating: eval/LA_E_A5705432.flac
#   inflating: eval/LA_E_A5740231.flac
#   inflating: eval/LA_E_A5742757.flac
#   inflating: eval/LA_E_A5746825.flac
#   inflating: eval/LA_E_A5752283.flac
#   inflating: eval/LA_E_A5759463.flac
#   inflating: eval/LA_E_A5764619.flac
#   inflating: eval/LA_E_A5779272.flac
#   inflating: eval/LA_E_A5815457.flac
#   inflating: eval/LA_E_A5820641.flac
#   inflating: eval/LA_E_A5835629.flac
#   inflating: eval/LA_E_A5839270.flac
#   inflating: eval/LA_E_A5854979.flac
#   inflating: eval/LA_E_A5861351.flac
#   inflating: eval/LA_E_A5863027.flac
#   inflating: eval/LA_E_A5890944.flac
#   inflating: eval/LA_E_A5901043.flac
#   inflating: eval/LA_E_A5902299.flac
#   inflating: eval/LA_E_A5912013.flac
#   inflating: eval/LA_E_A5938161.flac
#   inflating: eval/LA_E_A5939507.flac
#   inflating: eval/LA_E_A5939534.flac
#   inflating: eval/LA_E_A5952468.flac
#   inflating: eval/LA_E_A5956752.flac
#   inflating: eval/LA_E_A5982169.flac
#   inflating: eval/LA_E_A5998686.flac
#   inflating: eval/LA_E_A6003322.flac
#   inflating: eval/LA_E_A6019368.flac
#   inflating: eval/LA_E_A6030971.flac
#   inflating: eval/LA_E_A6066016.flac
#   inflating: eval/LA_E_A6067886.flac
#   inflating: eval/LA_E_A6081776.flac
#   inflating: eval/LA_E_A6082825.flac
#   inflating: eval/LA_E_A6082924.flac
#   inflating: eval/LA_E_A6084667.flac
#   inflating: eval/LA_E_A6131259.flac
#   inflating: eval/LA_E_A6136654.flac
#   inflating: eval/LA_E_A6138183.flac
#   inflating: eval/LA_E_A6140229.flac
#   inflating: eval/LA_E_A6151518.flac
#   inflating: eval/LA_E_A6156462.flac
#   inflating: eval/LA_E_A6157632.flac
#   inflating: eval/LA_E_A6161186.flac
#   inflating: eval/LA_E_A6168904.flac
#   inflating: eval/LA_E_A6211829.flac
#   inflating: eval/LA_E_A6236286.flac
#   inflating: eval/LA_E_A6256166.flac
#   inflating: eval/LA_E_A6262999.flac
#   inflating: eval/LA_E_A6278681.flac
#   inflating: eval/LA_E_A6283872.flac
#   inflating: eval/LA_E_A6298434.flac
#   inflating: eval/LA_E_A6299358.flac
#   inflating: eval/LA_E_A6308549.flac
#   inflating: eval/LA_E_A6315891.flac
#   inflating: eval/LA_E_A6317736.flac
#   inflating: eval/LA_E_A6371783.flac
#   inflating: eval/LA_E_A6399397.flac
#   inflating: eval/LA_E_A6419571.flac
#   inflating: eval/LA_E_A6428663.flac
#   inflating: eval/LA_E_A6438857.flac
#   inflating: eval/LA_E_A6442982.flac
#   inflating: eval/LA_E_A6455734.flac
#   inflating: eval/LA_E_A6467075.flac
#   inflating: eval/LA_E_A6479043.flac
#   inflating: eval/LA_E_A6479863.flac
#   inflating: eval/LA_E_A6508387.flac
#   inflating: eval/LA_E_A6514235.flac
#   inflating: eval/LA_E_A6514798.flac
#   inflating: eval/LA_E_A6517068.flac
#   inflating: eval/LA_E_A6533314.flac
#   inflating: eval/LA_E_A6536184.flac
#   inflating: eval/LA_E_A6542679.flac
#   inflating: eval/LA_E_A6548293.flac
#   inflating: eval/LA_E_A6562971.flac
#   inflating: eval/LA_E_A6565965.flac
#   inflating: eval/LA_E_A6588986.flac
#   inflating: eval/LA_E_A6602358.flac
#   inflating: eval/LA_E_A6631075.flac
#   inflating: eval/LA_E_A6646147.flac
#   inflating: eval/LA_E_A6650474.flac
#   inflating: eval/LA_E_A6663116.flac
#   inflating: eval/LA_E_A6677949.flac
#   inflating: eval/LA_E_A6681433.flac
#   inflating: eval/LA_E_A6684049.flac
#   inflating: eval/LA_E_A6691385.flac
#   inflating: eval/LA_E_A6703766.flac
#   inflating: eval/LA_E_A6711472.flac
#   inflating: eval/LA_E_A6716830.flac
#   inflating: eval/LA_E_A6728526.flac
#   inflating: eval/LA_E_A6741138.flac
#   inflating: eval/LA_E_A6744935.flac
#   inflating: eval/LA_E_A6756990.flac
#   inflating: eval/LA_E_A6795707.flac
#   inflating: eval/LA_E_A6798483.flac
#   inflating: eval/LA_E_A6801198.flac
#   inflating: eval/LA_E_A6801379.flac
#   inflating: eval/LA_E_A6819813.flac
#   inflating: eval/LA_E_A6842353.flac
#   inflating: eval/LA_E_A6842395.flac
#   inflating: eval/LA_E_A6845132.flac
#   inflating: eval/LA_E_A6854846.flac
#   inflating: eval/LA_E_A6887259.flac
#   inflating: eval/LA_E_A6894935.flac
#   inflating: eval/LA_E_A6924100.flac
#   inflating: eval/LA_E_A6957322.flac
#   inflating: eval/LA_E_A6963337.flac
#   inflating: eval/LA_E_A6976406.flac
#   inflating: eval/LA_E_A6986555.flac
#   inflating: eval/LA_E_A6995425.flac
#   inflating: eval/LA_E_A7005142.flac
#   inflating: eval/LA_E_A7032162.flac
#   inflating: eval/LA_E_A7036528.flac
#   inflating: eval/LA_E_A7054590.flac
#   inflating: eval/LA_E_A7065441.flac
#   inflating: eval/LA_E_A7069053.flac
#   inflating: eval/LA_E_A7089762.flac
#   inflating: eval/LA_E_A7103478.flac
#   inflating: eval/LA_E_A7145264.flac
#   inflating: eval/LA_E_A7146309.flac
#   inflating: eval/LA_E_A7162720.flac
#   inflating: eval/LA_E_A7208817.flac
#   inflating: eval/LA_E_A7210101.flac
#   inflating: eval/LA_E_A7216041.flac
#   inflating: eval/LA_E_A7227229.flac
#   inflating: eval/LA_E_A7238447.flac
#   inflating: eval/LA_E_A7273228.flac
#   inflating: eval/LA_E_A7299292.flac
#   inflating: eval/LA_E_A7328076.flac
#   inflating: eval/LA_E_A7343806.flac
#   inflating: eval/LA_E_A7344026.flac
#   inflating: eval/LA_E_A7344985.flac
#   inflating: eval/LA_E_A7350428.flac
#   inflating: eval/LA_E_A7353069.flac
#   inflating: eval/LA_E_A7361812.flac
#   inflating: eval/LA_E_A7384060.flac
#   inflating: eval/LA_E_A7385173.flac
#   inflating: eval/LA_E_A7406609.flac
#   inflating: eval/LA_E_A7444716.flac
#   inflating: eval/LA_E_A7454132.flac
#   inflating: eval/LA_E_A7455161.flac
#   inflating: eval/LA_E_A7501718.flac
#   inflating: eval/LA_E_A7504228.flac
#   inflating: eval/LA_E_A7506556.flac
#   inflating: eval/LA_E_A7509220.flac
#   inflating: eval/LA_E_A7511208.flac
#   inflating: eval/LA_E_A7522472.flac
#   inflating: eval/LA_E_A7542238.flac
#   inflating: eval/LA_E_A7554553.flac
#   inflating: eval/LA_E_A7559134.flac
#   inflating: eval/LA_E_A7570344.flac
#   inflating: eval/LA_E_A7588072.flac
#   inflating: eval/LA_E_A7589780.flac
#   inflating: eval/LA_E_A7620458.flac
#   inflating: eval/LA_E_A7626807.flac
#   inflating: eval/LA_E_A7643994.flac
#   inflating: eval/LA_E_A7658339.flac
#   inflating: eval/LA_E_A7662019.flac
#   inflating: eval/LA_E_A7665790.flac
#   inflating: eval/LA_E_A7666759.flac
#   inflating: eval/LA_E_A7695856.flac
#   inflating: eval/LA_E_A7714540.flac
#   inflating: eval/LA_E_A7735424.flac
#   inflating: eval/LA_E_A7781578.flac
#   inflating: eval/LA_E_A7782002.flac
#   inflating: eval/LA_E_A7785728.flac
#   inflating: eval/LA_E_A7811753.flac
#   inflating: eval/LA_E_A7814135.flac
#   inflating: eval/LA_E_A7814286.flac
#   inflating: eval/LA_E_A7830058.flac
#   inflating: eval/LA_E_A7831194.flac
#   inflating: eval/LA_E_A7865122.flac
#   inflating: eval/LA_E_A7869414.flac
#   inflating: eval/LA_E_A7870154.flac
#   inflating: eval/LA_E_A7882315.flac
#   inflating: eval/LA_E_A7888496.flac
#   inflating: eval/LA_E_A7915419.flac
#   inflating: eval/LA_E_A7929078.flac
#   inflating: eval/LA_E_A7931622.flac
#   inflating: eval/LA_E_A7935803.flac
#   inflating: eval/LA_E_A7961119.flac
#   inflating: eval/LA_E_A7965023.flac
#   inflating: eval/LA_E_A7969490.flac
#   inflating: eval/LA_E_A7975193.flac
#   inflating: eval/LA_E_A7992084.flac
#   inflating: eval/LA_E_A8009345.flac
#   inflating: eval/LA_E_A8011520.flac
#   inflating: eval/LA_E_A8013850.flac
#   inflating: eval/LA_E_A8023214.flac
#   inflating: eval/LA_E_A8034727.flac
#   inflating: eval/LA_E_A8042701.flac
#   inflating: eval/LA_E_A8076326.flac
#   inflating: eval/LA_E_A8093886.flac
#   inflating: eval/LA_E_A8100239.flac
#   inflating: eval/LA_E_A8132158.flac
#   inflating: eval/LA_E_A8136322.flac
#   inflating: eval/LA_E_A8158713.flac
#   inflating: eval/LA_E_A8161790.flac
#   inflating: eval/LA_E_A8179954.flac
#   inflating: eval/LA_E_A8182193.flac
#   inflating: eval/LA_E_A8189181.flac
#   inflating: eval/LA_E_A8192912.flac
#   inflating: eval/LA_E_A8228964.flac
#   inflating: eval/LA_E_A8239552.flac
#   inflating: eval/LA_E_A8256043.flac
#   inflating: eval/LA_E_A8283071.flac
#   inflating: eval/LA_E_A8288389.flac
#   inflating: eval/LA_E_A8288456.flac
#   inflating: eval/LA_E_A8299065.flac
#   inflating: eval/LA_E_A8309685.flac
#   inflating: eval/LA_E_A8311618.flac
#   inflating: eval/LA_E_A8331933.flac
#   inflating: eval/LA_E_A8341026.flac
#   inflating: eval/LA_E_A8382737.flac
#   inflating: eval/LA_E_A8390905.flac
#   inflating: eval/LA_E_A8428454.flac
#   inflating: eval/LA_E_A8437596.flac
#   inflating: eval/LA_E_A8439465.flac
#   inflating: eval/LA_E_A8444324.flac
#   inflating: eval/LA_E_A8460072.flac
#   inflating: eval/LA_E_A8489144.flac
#   inflating: eval/LA_E_A8497664.flac
#   inflating: eval/LA_E_A8502724.flac
#   inflating: eval/LA_E_A8512745.flac
#   inflating: eval/LA_E_A8520532.flac
#   inflating: eval/LA_E_A8525661.flac
#   inflating: eval/LA_E_A8533788.flac
#   inflating: eval/LA_E_A8533861.flac
#   inflating: eval/LA_E_A8557047.flac
#   inflating: eval/LA_E_A8557348.flac
#   inflating: eval/LA_E_A8566051.flac
#   inflating: eval/LA_E_A8574000.flac
#   inflating: eval/LA_E_A8599621.flac
#   inflating: eval/LA_E_A8603666.flac
#   inflating: eval/LA_E_A8612771.flac
#   inflating: eval/LA_E_A8628133.flac
#   inflating: eval/LA_E_A8639383.flac
#   inflating: eval/LA_E_A8639897.flac
#   inflating: eval/LA_E_A8643969.flac
#   inflating: eval/LA_E_A8650561.flac
#   inflating: eval/LA_E_A8691184.flac
#   inflating: eval/LA_E_A8704258.flac
#   inflating: eval/LA_E_A8731251.flac
#   inflating: eval/LA_E_A8746471.flac
#   inflating: eval/LA_E_A8763189.flac
#   inflating: eval/LA_E_A8796096.flac
#   inflating: eval/LA_E_A8796242.flac
#   inflating: eval/LA_E_A8804831.flac
#   inflating: eval/LA_E_A8817156.flac
#   inflating: eval/LA_E_A8820512.flac
#   inflating: eval/LA_E_A8832569.flac
#   inflating: eval/LA_E_A8848010.flac
#   inflating: eval/LA_E_A8871185.flac
#   inflating: eval/LA_E_A8882063.flac
#   inflating: eval/LA_E_A8885354.flac
#   inflating: eval/LA_E_A8897121.flac
#   inflating: eval/LA_E_A8910908.flac
#   inflating: eval/LA_E_A8936529.flac
#   inflating: eval/LA_E_A8940970.flac
#   inflating: eval/LA_E_A8942083.flac
#   inflating: eval/LA_E_A8945195.flac
#   inflating: eval/LA_E_A8945198.flac
#   inflating: eval/LA_E_A8960118.flac
#   inflating: eval/LA_E_A8961129.flac
#   inflating: eval/LA_E_A8963027.flac
#   inflating: eval/LA_E_A8968933.flac
#   inflating: eval/LA_E_A8972377.flac
#   inflating: eval/LA_E_A8972701.flac
#   inflating: eval/LA_E_A9002777.flac
#   inflating: eval/LA_E_A9015000.flac
#   inflating: eval/LA_E_A9015457.flac
#   inflating: eval/LA_E_A9024376.flac
#   inflating: eval/LA_E_A9038375.flac
#   inflating: eval/LA_E_A9046210.flac
#   inflating: eval/LA_E_A9058515.flac
#   inflating: eval/LA_E_A9103743.flac
#   inflating: eval/LA_E_A9136617.flac
#   inflating: eval/LA_E_A9137383.flac
#   inflating: eval/LA_E_A9143306.flac
#   inflating: eval/LA_E_A9150661.flac
#   inflating: eval/LA_E_A9162657.flac
#   inflating: eval/LA_E_A9175975.flac
#   inflating: eval/LA_E_A9184573.flac
#   inflating: eval/LA_E_A9210248.flac
#   inflating: eval/LA_E_A9211497.flac
#   inflating: eval/LA_E_A9217821.flac
#   inflating: eval/LA_E_A9233994.flac
#   inflating: eval/LA_E_A9236430.flac
#   inflating: eval/LA_E_A9236736.flac
#   inflating: eval/LA_E_A9244386.flac
#   inflating: eval/LA_E_A9262197.flac
#   inflating: eval/LA_E_A9276815.flac
#   inflating: eval/LA_E_A9290365.flac
#   inflating: eval/LA_E_A9316550.flac
#   inflating: eval/LA_E_A9327727.flac
#   inflating: eval/LA_E_A9344861.flac
#   inflating: eval/LA_E_A9352992.flac
#   inflating: eval/LA_E_A9369469.flac
#   inflating: eval/LA_E_A9386932.flac
#   inflating: eval/LA_E_A9406597.flac
#   inflating: eval/LA_E_A9407859.flac
#   inflating: eval/LA_E_A9414340.flac
#   inflating: eval/LA_E_A9425880.flac
#   inflating: eval/LA_E_A9426249.flac
#   inflating: eval/LA_E_A9429276.flac
#   inflating: eval/LA_E_A9431669.flac
#   inflating: eval/LA_E_A9435429.flac
#   inflating: eval/LA_E_A9471582.flac
#   inflating: eval/LA_E_A9472289.flac
#   inflating: eval/LA_E_A9477785.flac
#   inflating: eval/LA_E_A9500389.flac
#   inflating: eval/LA_E_A9509852.flac
#   inflating: eval/LA_E_A9515193.flac
#   inflating: eval/LA_E_A9527561.flac
#   inflating: eval/LA_E_A9529647.flac
#   inflating: eval/LA_E_A9538728.flac
#   inflating: eval/LA_E_A9555184.flac
#   inflating: eval/LA_E_A9569588.flac
#   inflating: eval/LA_E_A9585735.flac
#   inflating: eval/LA_E_A9592918.flac
#   inflating: eval/LA_E_A9598155.flac
#   inflating: eval/LA_E_A9618297.flac
#   inflating: eval/LA_E_A9618678.flac
#   inflating: eval/LA_E_A9646908.flac
#   inflating: eval/LA_E_A9665991.flac
#   inflating: eval/LA_E_A9679505.flac
#   inflating: eval/LA_E_A9686199.flac
#   inflating: eval/LA_E_A9687807.flac
#   inflating: eval/LA_E_A9693501.flac
#   inflating: eval/LA_E_A9712403.flac
#   inflating: eval/LA_E_A9760674.flac
#   inflating: eval/LA_E_A9776482.flac
#   inflating: eval/LA_E_A9803663.flac
#   inflating: eval/LA_E_A9827503.flac
#   inflating: eval/LA_E_A9829952.flac
#   inflating: eval/LA_E_A9831653.flac
#   inflating: eval/LA_E_A9847831.flac
#   inflating: eval/LA_E_A9864327.flac
#   inflating: eval/LA_E_A9884360.flac
#   inflating: eval/LA_E_A9898607.flac
#   inflating: eval/LA_E_A9903225.flac
#   inflating: eval/LA_E_A9917416.flac
#   inflating: eval/LA_E_A9921939.flac
#   inflating: eval/LA_E_A9929223.flac
#   inflating: eval/LA_E_A9929520.flac
#   inflating: eval/LA_E_A9936942.flac
#   inflating: eval/LA_E_A9940557.flac
#   inflating: eval/LA_E_A9965149.flac
#   inflating: eval/LA_E_A9967055.flac
#   inflating: eval/LA_E_A9970430.flac
#   inflating: eval/LA_E_A9975938.flac
#   inflating: eval/LA_E_A9997819.flac

# %%
# !pip install --upgrade onnx onnxscript
# Out:
# Collecting onnx
#   Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting onnxscript
#   Downloading onnxscript-0.3.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.11/dist-packages (from onnx) (5.29.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.11/dist-packages (from onnx) (4.14.1)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.11/dist-packages (from onnxscript) (0.5.3)
# Collecting onnx_ir<2,>=0.1.3 (from onnxscript)
#   Downloading onnx_ir-0.1.6-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxscript) (25.0)
# Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 105.3 MB/s eta 0:00:00
# Downloading onnxscript-0.3.2-py3-none-any.whl (667 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 667.4/667.4 kB 41.5 MB/s eta 0:00:00
# Downloading onnx_ir-0.1.6-py3-none-any.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 10.7 MB/s eta 0:00:00
# Installing collected packages: onnx, onnx_ir, onnxscript
# Successfully installed onnx-1.18.0 onnx_ir-0.1.6 onnxscript-0.3.2

# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA version:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Torch version: 2.6.0+cu124
# CUDA version: 12.4
# CUDA available: True

# %% [markdown]
# Export to ONNX Model

# %%
# %cd /content/drive/MyDrive/Researches/Anti spoofing/aasist
# import sys
import torch.onnx
from torch import nn
import json

# PROJECT_ROOT = "/content/aasist"
# if PROJECT_ROOT not in sys.path:
#     sys.path.insert(0, PROJECT_ROOT)

# print(f"✅ Added {PROJECT_ROOT} to sys.path")

# ────────────────────────────────────────────────────────────────────────────
# 2.  LOAD MODEL (+ required `d_args`)
# ────────────────────────────────────────────────────────────────────────────
from AASIST import Model

with open("./config/AASIST.conf", 'r') as f:
  cfg = json.load(f)
  d_args = cfg['model_config']

device = "cuda"
model  = Model(d_args).to(device)
model.load_state_dict(torch.load("./models/weights/AASIST.pth", map_location=device))
model.eval()

# Create dummy input
dummy_input = torch.randn(1, 16000, dtype=torch.float32).to(device)

 # Export to ONNX
torch.onnx.export(
    model,
    dummy_input,
    "./aasist.onnx",
    do_constant_folding=True, # whether to execute constant folding for optimization
    export_params=True,
    opset_version=13,
    input_names=["input"],
    output_names=["embedding", "logits"],
    dynamic_axes={"input": {1: "num_samples"}},
    verbose=False
)
print(f"Model successfully exported")
# Out:
# /content/drive/MyDrive/Researches/Anti spoofing/aasist
# /content/drive/MyDrive/Researches/Anti spoofing/aasist/AASIST.py:393: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if mask:
# /content/drive/MyDrive/Researches/Anti spoofing/aasist/AASIST.py:315: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   n_nodes = max(int(n_nodes * k), 1)
# Model successfully exported

# %%
# !pip install --upgrade onnxruntime
# Out:
# Collecting onnxruntime
#   Downloading onnxruntime-1.22.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.13.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime) (1.3.0)
# Downloading onnxruntime-1.22.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 108.1 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.0 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.22.1

# %%
# !pip install --upgrade soundfile scipy
# Out:
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.16.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from soundfile) (2.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)

# %% [markdown]
# Inference using ONNX Runtime

# %%
# !python inference_onnx.py \
  --onnx_model_path     aasist.onnx \
  --audio_path     LA/ASVspoof2019_LA_eval/flac/LA_E_6163791.flac
# Out:
# Output:          [[ 10.660248 -11.066106]]
# Predicted class:      Spoof

# %% [markdown]
# Download subset for evaluation

# %%
# %cd /content/drive/MyDrive/Researches/Anti spoofing/aasist
# !bash -c "wget -q https://www.dropbox.com/sh/gf3zp00qvdp3row/AABc-QK2BvzEPj-s8nBwCkMna/temp/asvspoof2021/toy_example.tar.gz && \
tar -xzf toy_example.tar.gz"
# Out:
# /content/drive/MyDrive/Researches/Anti spoofing/aasist

# %% [markdown]
# ONNX Model Optimization

# %%
# %cd /content/drive/MyDrive/Researches/Anti spoofing/aasist
# !python -m onnxruntime.quantization.preprocess --input aasist.onnx --output aasist_optimized.onnx --skip_symbolic_shape True
# Out:
# /content/drive/MyDrive/Researches/Anti spoofing/aasist

# %% [markdown]
# ONNX Model Quantization

# %%
# %cd /content/aasist
import os
import numpy as np
import onnxruntime
from onnxruntime.quantization import QuantFormat, QuantType, StaticQuantConfig, CalibrationMethod, CalibrationDataReader, quantize
import soundfile as sf
from scipy.signal import resample

# Paths
input_model_path = 'aasist_optimized.onnx'
output_model_path = 'aasist_quantized.onnx'
calibration_dataset_path = '/content/aasist/toy_example/eval'  # folder with audio files

# Load audio with same preprocessing as inference script
def _preprocess_audio(file_path: str, target_sr: int = 16000) -> np.ndarray:
    wav, sr = sf.read(file_path)

    # Resample if needed
    if sr != target_sr:
        num = int(len(wav) * float(target_sr) / sr)
        wav = resample(wav, num)

    # Collapse to mono
    if wav.ndim > 1:
        wav = wav.mean(axis=1)

    # Normalize to [-1, 1]
    # max_val = np.max(np.abs(wav))
    # if max_val > 0:
    #     wav = wav / max_val

    return wav.astype(np.float32)[None, :]  # shape (1, num_samples)

class AudioDataReader(CalibrationDataReader):
    def __init__(self, calibration_folder: str, model_path: str):
        self.enum_data = None
        self.audio_files = [os.path.join(calibration_folder, f)
                            for f in os.listdir(calibration_folder)
                            if f.lower().endswith(('.wav', '.flac'))]
        self.input_name = onnxruntime.InferenceSession(model_path).get_inputs()[0].name
        self.audio_data_list = [_preprocess_audio(f) for f in self.audio_files]
        self.datasize = len(self.audio_data_list)

    def get_next(self):
        if self.enum_data is None:
            self.enum_data = iter(
                [{self.input_name: audio} for audio in self.audio_data_list]
            )
        return next(self.enum_data, None)

    def rewind(self):
        self.enum_data = None

# Instantiate DataReader
dr = AudioDataReader(calibration_dataset_path, input_model_path)

# Define quantization configuration
conf = StaticQuantConfig(
    calibration_data_reader=dr,
    quant_format=QuantFormat.QDQ,
    calibrate_method=CalibrationMethod.MinMax,
    # calibration_providers='CUDAExecutionProvider',
    # optimize_model=True, # Removed unsupported argument
    activation_type=QuantType.QUInt8,
    weight_type=QuantType.QInt8,
    per_channel=True,
    extra_options={"ActivationSymmetric":False,
                  "WeightSymmetric":True}
)

# Run quantization
quantize(input_model_path, output_model_path, conf)
print(f"Quantized model saved to {output_model_path}")
# Out:
# /content/aasist
# WARNING:root:Axis 1 is out-of-range for weight 'first_bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'GAT_layer_S.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'GAT_layer_T.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'HtrgGAT_layer_ST21.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'HtrgGAT_layer_ST11.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'HtrgGAT_layer_ST22.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'HtrgGAT_layer_ST12.bn.weight' with rank 1
# Quantized model saved to aasist_quantized.onnx

# %%
# !python inference_onnx.py \
  --onnx_model_path     aasist_quantized.onnx \
  --audio_path     LA/ASVspoof2019_LA_eval/flac/LA_E_6163791.flac
# Out:
# Output:          [[ 5.658438 -5.452677]]
# Predicted class:      Spoof

# %%
# %cd /content/aasist/
# !python evaluate_onnx_folder.py \
    --onnx_model_path aasist.onnx \
    --audio_folder /content/aasist/calibration/Evaluation_100_unique_to_all_calibrations \
    --protocol_path /content/aasist/toy_example/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/aasist
# /usr/local/lib/python3.11/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:121: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# File                           Predicted  True       Result
# ------------------------------------------------------------
# LA_E_1009694.flac              spoof      spoof      ✔️
# LA_E_1042916.flac              spoof      spoof      ✔️
# LA_E_1095914.flac              spoof      spoof      ✔️
# LA_E_1200013.flac              bonafide   spoof      ❌
# LA_E_1280322.flac              spoof      spoof      ✔️
# LA_E_1359749.flac              spoof      spoof      ✔️
# LA_E_1536534.flac              bonafide   spoof      ❌
# LA_E_1628984.flac              spoof      spoof      ✔️
# LA_E_1637982.flac              spoof      spoof      ✔️
# LA_E_1681669.flac              spoof      spoof      ✔️
# LA_E_1809034.flac              spoof      spoof      ✔️
# LA_E_1824425.flac              spoof      spoof      ✔️
# LA_E_1899765.flac              bonafide   spoof      ❌
# LA_E_1953876.flac              spoof      spoof      ✔️
# LA_E_1970875.flac              bonafide   spoof      ❌
# LA_E_2043577.flac              bonafide   bonafide   ✔️
# LA_E_2100696.flac              spoof      spoof      ✔️
# LA_E_2118411.flac              spoof      spoof      ✔️
# LA_E_2340025.flac              bonafide   bonafide   ✔️
# LA_E_2511893.flac              spoof      spoof      ✔️
# LA_E_2527029.flac              spoof      spoof      ✔️
# LA_E_2527558.flac              spoof      spoof      ✔️
# LA_E_2614701.flac              spoof      spoof      ✔️
# LA_E_2646807.flac              bonafide   spoof      ❌
# LA_E_2660777.flac              spoof      spoof      ✔️
# LA_E_2701214.flac              bonafide   spoof      ❌
# LA_E_2930394.flac              bonafide   bonafide   ✔️
# LA_E_3031870.flac              bonafide   spoof      ❌
# LA_E_3062688.flac              spoof      spoof      ✔️
# LA_E_3209766.flac              bonafide   bonafide   ✔️
# LA_E_3280144.flac              spoof      spoof      ✔️
# LA_E_9040303.flac              bonafide   spoof      ❌
# LA_E_9349602.flac              bonafide   spoof      ❌
# LA_E_9409255.flac              spoof      spoof      ✔️
# LA_E_9419406.flac              bonafide   spoof      ❌
# LA_E_9512879.flac              bonafide   bonafide   ✔️
# LA_E_9541353.flac              spoof      spoof      ✔️
# LA_E_9593895.flac              bonafide   spoof      ❌
# LA_E_9818839.flac              spoof      spoof      ✔️
# LA_E_9887619.flac              spoof      spoof      ✔️
# LA_E_9924280.flac              bonafide   spoof      ❌
# LA_E_9941554.flac              spoof      spoof      ✔️
#
# ------------------------------------------------------------
# Evaluated 100 files.
# Accuracy: 0.8100

# %%
# %cd /content/aasist/
# !python evaluate_onnx_folder.py \
    --onnx_model_path aasist_quantized_scheme_6.onnx \
    --audio_folder /content/aasist/calibration/Evaluation_100_unique_to_all_calibrations \
    --protocol_path /content/aasist/toy_example/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/aasist
# /usr/local/lib/python3.11/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:121: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# File                           Predicted  True       Result
# ------------------------------------------------------------
# LA_E_1009694.flac              spoof      spoof      ✔️
# LA_E_1042916.flac              spoof      spoof      ✔️
# LA_E_1095914.flac              bonafide   spoof      ❌
# LA_E_1200013.flac              bonafide   spoof      ❌
# LA_E_1280322.flac              spoof      spoof      ✔️
# LA_E_1359749.flac              spoof      spoof      ✔️
# LA_E_1536534.flac              bonafide   spoof      ❌
# LA_E_1628984.flac              spoof      spoof      ✔️
# LA_E_1637982.flac              spoof      spoof      ✔️
# LA_E_1681669.flac              bonafide   spoof      ❌
# LA_E_1809034.flac              bonafide   spoof      ❌
# LA_E_1824425.flac              spoof      spoof      ✔️
# LA_E_1899765.flac              bonafide   spoof      ❌
# LA_E_1953876.flac              bonafide   spoof      ❌
# LA_E_1970875.flac              bonafide   spoof      ❌
# LA_E_2043577.flac              bonafide   bonafide   ✔️
# LA_E_2100696.flac              bonafide   spoof      ❌
# LA_E_2118411.flac              bonafide   spoof      ❌
# LA_E_2340025.flac              bonafide   bonafide   ✔️
# LA_E_2511893.flac              bonafide   spoof      ❌
# LA_E_2527029.flac              bonafide   spoof      ❌
# LA_E_2527558.flac              bonafide   spoof      ❌
# LA_E_2614701.flac              bonafide   spoof      ❌
# LA_E_2646807.flac              bonafide   spoof      ❌
# LA_E_2660777.flac              spoof      spoof      ✔️
# LA_E_2701214.flac              bonafide   spoof      ❌
# LA_E_2930394.flac              bonafide   bonafide   ✔️
# LA_E_3031870.flac              bonafide   spoof      ❌
# LA_E_3062688.flac              spoof      spoof      ✔️
# LA_E_3209766.flac              bonafide   bonafide   ✔️
# LA_E_3280144.flac              spoof      spoof      ✔️
# LA_E_3332056.flac              bonafide   spoof      ❌
# LA_E_3548794.flac              bonafide   spoof      ❌
# LA_E_3586112.flac              spoof      spoof      ✔️
# LA_E_3623412.flac              spoof      spoof      ✔️
# LA_E_3948138.flac              bonafide   spoof      ❌
# LA_E_3963282.flac              spoof      spoof      ✔️
# LA_E_9818839.flac              spoof      spoof      ✔️
# LA_E_9887619.flac              bonafide   spoof      ❌
# LA_E_9924280.flac              bonafide   spoof      ❌
# LA_E_9941554.flac              bonafide   spoof      ❌
#
# ------------------------------------------------------------
# Evaluated 100 files.
# Accuracy: 0.4700

# %%
# !python run_qdq_debug.py --float_model aasist_optimized.onnx --qdq_model aasist_quantized.onnx --calibrate_dataset /content/aasist/toy_example/train_dev
# Out:
# ------------------------------------------------
#
# Comparing weights of float model vs qdq model.....
# Cross model error of '/HtrgGAT_layer_ST11/proj_without_attM/Add_output_0': -0.38624536023493117
#
# Cross model error of '/HtrgGAT_layer_ST21/proj_without_attM/Add_output_0': 2.387760956000457
#
# Cross model error of '/conv_time/Constant_output_0': 45.080863750788495
#
# Cross model error of 'GAT_layer_S.att_proj.bias': 21.388631933606973
#
# Cross model error of 'GAT_layer_S.att_weight': 45.07301767073577
#
# Cross model error of 'GAT_layer_S.bn.bias': 34.38883244132761
#
# Cross model error of 'GAT_layer_S.bn.weight': 52.09230094365765
#
# Cross model error of 'GAT_layer_S.proj_with_att.bias': 4.3972808889134297e-07
#
# Cross model error of 'GAT_layer_S.proj_without_att.bias': -5.8672289840406715e-08
#
# Cross model error of 'GAT_layer_T.att_proj.bias': 3.0023089370831855
#
# Cross model error of 'GAT_layer_T.att_weight': 45.649438968237945
#
# Cross model error of 'GAT_layer_T.bn.bias': 33.743983935268716
#
# Cross model error of 'GAT_layer_T.bn.weight': 52.91180551808945
#
# Cross model error of 'GAT_layer_T.proj_with_att.bias': 0.5068640784943447
#
# Cross model error of 'GAT_layer_T.proj_without_att.bias': 0.5670850704115148
#
# Cross model error of 'HtrgGAT_layer_ST11.att_proj.bias': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST11.att_projM.bias': -0.03379299756408107
#
# Cross model error of 'HtrgGAT_layer_ST11.att_weight11': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST11.att_weight12': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST11.att_weight22': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST11.att_weightM': 48.0173540539197
#
# Cross model error of 'HtrgGAT_layer_ST11.bn.bias': 56.04932249947132
#
# Cross model error of 'HtrgGAT_layer_ST11.bn.weight': 51.203736643308055
#
# Cross model error of 'HtrgGAT_layer_ST11.proj_type1.bias': 2.3805049811685772
#
# Cross model error of 'HtrgGAT_layer_ST11.proj_type2.bias': 81.13074689683498
#
# Cross model error of 'HtrgGAT_layer_ST11.proj_with_att.bias': 0.9864311210119128
#
# Cross model error of 'HtrgGAT_layer_ST11.proj_with_attM.bias': 4.34334960888001
#
# Cross model error of 'HtrgGAT_layer_ST11.proj_without_att.bias': 0.775709245924795
#
# Cross model error of 'HtrgGAT_layer_ST12.att_proj.bias': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST12.att_projM.bias': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST12.att_weight11': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST12.att_weight12': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST12.att_weight22': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST12.att_weightM': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST12.bn.bias': 59.94039065974795
#
# Cross model error of 'HtrgGAT_layer_ST12.bn.weight': 51.97139893309051
#
# Cross model error of 'HtrgGAT_layer_ST12.proj_type1.bias': 4.167361290304481
#
# Cross model error of 'HtrgGAT_layer_ST12.proj_type2.bias': 5.302336468381349
#
# Cross model error of 'HtrgGAT_layer_ST12.proj_with_att.bias': 1.0535106657351203
#
# Cross model error of 'HtrgGAT_layer_ST12.proj_with_attM.bias': 3.006466074290372
#
# Cross model error of 'HtrgGAT_layer_ST12.proj_without_att.bias': 2.478042009851516
#
# Cross model error of 'HtrgGAT_layer_ST12.proj_without_attM.bias': 2.8168592172002143
#
# Cross model error of 'HtrgGAT_layer_ST21.att_proj.bias': -2.816813134833192
#
# Cross model error of 'HtrgGAT_layer_ST21.att_projM.bias': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST21.att_weight11': 52.65975893260571
#
# Cross model error of 'HtrgGAT_layer_ST21.att_weight12': 48.173855707588054
#
# Cross model error of 'HtrgGAT_layer_ST21.att_weight22': 52.33781233549945
#
# Cross model error of 'HtrgGAT_layer_ST21.att_weightM': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST21.bn.bias': 57.53582615984744
#
# Cross model error of 'HtrgGAT_layer_ST21.bn.weight': 51.81916382487564
#
# Cross model error of 'HtrgGAT_layer_ST21.proj_type1.bias': 6.511504953961379
#
# Cross model error of 'HtrgGAT_layer_ST21.proj_type2.bias': 81.64441059095839
#
# Cross model error of 'HtrgGAT_layer_ST21.proj_with_att.bias': 0.449069666790231
#
# Cross model error of 'HtrgGAT_layer_ST21.proj_with_attM.bias': 4.661936126728159
#
# Cross model error of 'HtrgGAT_layer_ST21.proj_without_att.bias': 0.4811346841189496
#
# Cross model error of 'HtrgGAT_layer_ST22.att_proj.bias': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST22.att_projM.bias': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST22.att_weight11': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST22.att_weight12': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST22.att_weight22': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST22.att_weightM': 0.0
#
# Cross model error of 'HtrgGAT_layer_ST22.bn.bias': 58.1019203443182
#
# Cross model error of 'HtrgGAT_layer_ST22.bn.weight': 52.208662711812906
#
# Cross model error of 'HtrgGAT_layer_ST22.proj_type1.bias': 3.842591099037352
#
# Cross model error of 'HtrgGAT_layer_ST22.proj_type2.bias': 4.975970347420768
#
# Cross model error of 'HtrgGAT_layer_ST22.proj_with_att.bias': 0.6866542533057453
#
# Cross model error of 'HtrgGAT_layer_ST22.proj_with_attM.bias': -1.7842998529079555
#
# Cross model error of 'HtrgGAT_layer_ST22.proj_without_att.bias': -2.2116391297103175
#
# Cross model error of 'HtrgGAT_layer_ST22.proj_without_attM.bias': 2.361788223971732
#
# Cross model error of 'encoder.0.0.conv2.bias': 62.99329336242721
#
# Cross model error of 'encoder.0.0.conv2.weight': 46.85685174515263
#
# Cross model error of 'encoder.0.0.conv_downsample.bias': 71.68144425789716
#
# Cross model error of 'encoder.0.0.conv_downsample.weight': 52.46581885242951
#
# Cross model error of 'encoder.1.0.conv2.bias': 64.11491083830201
#
# Cross model error of 'encoder.1.0.conv2.weight': 46.49101170985439
#
# Cross model error of 'encoder.2.0.conv2.bias': 65.84553314009733
#
# Cross model error of 'encoder.2.0.conv2.weight': 45.24120008908665
#
# Cross model error of 'encoder.2.0.conv_downsample.bias': 60.20037343896642
#
# Cross model error of 'encoder.2.0.conv_downsample.weight': 47.17238503956543
#
# Cross model error of 'encoder.3.0.conv2.bias': 63.69809439307036
#
# Cross model error of 'encoder.3.0.conv2.weight': 44.683732101212776
#
# Cross model error of 'encoder.4.0.conv2.bias': 69.4539359442316
#
# Cross model error of 'encoder.4.0.conv2.weight': 44.90932254111976
#
# Cross model error of 'encoder.5.0.conv2.bias': 71.68934264983892
#
# Cross model error of 'encoder.5.0.conv2.weight': 44.66910033009569
#
# Cross model error of 'first_bn.bias': 100.25176657571124
#
# Cross model error of 'first_bn.weight': 312.80333188016687
#
# Cross model error of 'master1': 2.047197115454754
#
# Cross model error of 'master2': 5.388974021404889
#
# Cross model error of 'onnx::Conv_3298': 50.3126193590753
#
# Cross model error of 'onnx::Conv_3299': 48.66887520922913
#
# Cross model error of 'onnx::Conv_3301': 46.03833501326916
#
# Cross model error of 'onnx::Conv_3302': 70.001429287934
#
# Cross model error of 'onnx::Conv_3304': 46.165076715438275
#
# Cross model error of 'onnx::Conv_3305': 75.23246666167383
#
# Cross model error of 'onnx::Conv_3307': 44.83082671340996
#
# Cross model error of 'onnx::Conv_3308': 78.06819281231905
#
# Cross model error of 'onnx::Conv_3310': 44.7894096406243
#
# Cross model error of 'onnx::Conv_3311': 77.94328430152432
#
# Cross model error of 'onnx::Conv_3313': 44.63534502825532
#
# Cross model error of 'onnx::Conv_3314': 88.77963725451548
#
# Cross model error of 'onnx::MatMul_3322': 47.511340663853446
#
# Cross model error of 'onnx::MatMul_3323': 46.51692778485866
#
# Cross model error of 'onnx::MatMul_3324': 47.184518765614456
#
# Cross model error of 'onnx::MatMul_3332': 45.6947821309665
#
# Cross model error of 'onnx::MatMul_3343': 47.11810138026483
#
# Cross model error of 'onnx::MatMul_3344': 47.20848002331859
#
# Cross model error of 'onnx::MatMul_3345': 47.13385568183145
#
# Cross model error of 'onnx::MatMul_3347': 46.883327274608924
#
# Cross model error of 'onnx::MatMul_3351': 47.2124723471017
#
# Cross model error of 'onnx::MatMul_3352': 47.326418132933405
#
# Cross model error of 'onnx::MatMul_3356': 0.0
#
# Cross model error of 'onnx::MatMul_3423': 45.0404110143182
#
# Cross model error of 'onnx::MatMul_3424': 45.83274888918673
#
# Cross model error of 'onnx::MatMul_3426': 46.979810163424105
#
# Cross model error of 'onnx::MatMul_3427': 47.38346864879298
#
# Cross model error of 'onnx::MatMul_3432': 47.679414243869786
#
# Cross model error of 'onnx::MatMul_3436': 47.71030904581391
#
# Cross model error of 'onnx::MatMul_3440': 47.869418043871015
#
# Cross model error of 'onnx::MatMul_3441': 47.83873024583666
#
# Cross model error of 'onnx::MatMul_3445': 0.0
#
# Cross model error of 'onnx::MatMul_3512': 0.0
#
# Cross model error of 'onnx::MatMul_3513': 46.69823420846686
#
# Cross model error of 'onnx::MatMul_3514': 46.97356302863294
#
# Cross model error of 'onnx::MatMul_3515': 47.69213916832133
#
# Cross model error of 'onnx::MatMul_3516': 47.721858969425256
#
# Cross model error of 'onnx::MatMul_3521': 47.44149967180165
#
# Cross model error of 'onnx::MatMul_3522': 47.11396376614389
#
# Cross model error of 'onnx::MatMul_3526': 44.26464083066713
#
# Cross model error of 'onnx::MatMul_3593': 0.0
#
# Cross model error of 'onnx::MatMul_3594': 45.90220864530282
#
# Cross model error of 'onnx::MatMul_3596': 46.832952340012504
#
# Cross model error of 'onnx::MatMul_3597': 47.3254042902481
#
# Cross model error of 'onnx::MatMul_3602': 46.796175558811505
#
# Cross model error of 'onnx::MatMul_3606': 49.4437868420935
#
# Cross model error of 'onnx::MatMul_3610': 48.14787722472013
#
# Cross model error of 'onnx::MatMul_3611': 48.25650993110955
#
# Cross model error of 'onnx::MatMul_3615': 0.0
#
# Cross model error of 'onnx::MatMul_3682': 0.0
#
# Cross model error of 'onnx::MatMul_3683': 46.524637027062646
#
# Cross model error of 'onnx::MatMul_3684': 47.11076296313534
#
# Cross model error of 'onnx::MatMul_3685': 48.05840879579833
#
# Cross model error of 'onnx::MatMul_3686': 48.04371161808973
#
# Cross model error of 'out_layer.bias': 67.06340387489395
#
# Cross model error of 'out_layer.weight': 45.55649990595632
#
# Cross model error of 'pool_S.proj.bias': 79.40191748482137
#
# Cross model error of 'pool_T.proj.bias': -0.033995177808264915
#
# Cross model error of 'pool_hS1.proj.bias': -0.033996217307541834
#
# Cross model error of 'pool_hS2.proj.bias': -0.03399569755788782
#
# Cross model error of 'pool_hT1.proj.bias': -0.03399569755788782
#
# Cross model error of 'pool_hT2.proj.bias': -0.03399569755788782
#
# Cross model error of 'pos_S': 11.02043170241745
#
# ------------------------------------------------
#
# Augmenting models to save intermediate activations......
# ------------------------------------------------
#
# Running the augmented floating point model to collect activations......
# Traceback (most recent call last):
#   File "/content/aasist/run_qdq_debug.py", line 112, in <module>
#     main()
#   File "/content/aasist/run_qdq_debug.py", line 96, in main
#     float_activations = collect_activations(aug_float_model_path, input_data_reader)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/onnxruntime/quantization/qdq_loss_debug.py", line 149, in collect_activations
#     for input_d in input_reader:
# TypeError: 'AudioDataReader' object is not iterable

# %%
## Full-sized model parameters

# %cd /content/aasist
import onnx
import onnx.helper
import numpy as np

# Load the ONNX model
model = onnx.load("aasist.onnx")

# Iterate through initializers (which store the weights)
total_params = 0
total_bytes = 0

for tensor in model.graph.initializer:
    # Number of parameters
    num_params = 1
    for dim in tensor.dims:
        num_params *= dim

    # Data type size (in bytes)
    # Use onnx.helper.tensor_dtype_to_np_dtype to get the numpy dtype
    # Then access the itemsize attribute
    dtype = onnx.helper.tensor_dtype_to_np_dtype(tensor.data_type)
    dtype_size = dtype.itemsize

    # Accumulate size
    size_bytes = num_params * dtype_size
    total_params += num_params
    total_bytes += size_bytes

    print(f"{tensor.name}: {num_params} params, {size_bytes/1024:.2f} KB")

print(f"\nTotal parameters: {total_params}")
print(f"Total weights size: {total_bytes / (1024 * 1024):.2f} MB")
# Out:
# /content/aasist
# pos_S: 1472 params, 5.75 KB
# master1: 64 params, 0.25 KB
# master2: 64 params, 0.25 KB
# first_bn.weight: 1 params, 0.00 KB
# first_bn.bias: 1 params, 0.00 KB
# first_bn.running_mean: 1 params, 0.00 KB
# first_bn.running_var: 1 params, 0.00 KB
# encoder.0.0.conv2.weight: 6144 params, 24.00 KB
# encoder.0.0.conv2.bias: 32 params, 0.12 KB
# encoder.0.0.conv_downsample.weight: 96 params, 0.38 KB
# encoder.0.0.conv_downsample.bias: 32 params, 0.12 KB
# encoder.1.0.conv2.weight: 6144 params, 24.00 KB
# encoder.1.0.conv2.bias: 32 params, 0.12 KB
# encoder.2.0.conv2.weight: 24576 params, 96.00 KB
# encoder.2.0.conv2.bias: 64 params, 0.25 KB
# encoder.2.0.conv_downsample.weight: 6144 params, 24.00 KB
# encoder.2.0.conv_downsample.bias: 64 params, 0.25 KB
# encoder.3.0.conv2.weight: 24576 params, 96.00 KB
# encoder.3.0.conv2.bias: 64 params, 0.25 KB
# encoder.4.0.conv2.weight: 24576 params, 96.00 KB
# encoder.4.0.conv2.bias: 64 params, 0.25 KB
# encoder.5.0.conv2.weight: 24576 params, 96.00 KB
# encoder.5.0.conv2.bias: 64 params, 0.25 KB
# GAT_layer_S.att_weight: 64 params, 0.25 KB
# GAT_layer_S.att_proj.bias: 64 params, 0.25 KB
# GAT_layer_S.proj_with_att.bias: 64 params, 0.25 KB
# GAT_layer_S.proj_without_att.bias: 64 params, 0.25 KB
# GAT_layer_S.bn.weight: 64 params, 0.25 KB
# GAT_layer_S.bn.bias: 64 params, 0.25 KB
# GAT_layer_S.bn.running_mean: 64 params, 0.25 KB
# GAT_layer_S.bn.running_var: 64 params, 0.25 KB
# GAT_layer_T.att_weight: 64 params, 0.25 KB
# GAT_layer_T.att_proj.bias: 64 params, 0.25 KB
# GAT_layer_T.proj_with_att.bias: 64 params, 0.25 KB
# GAT_layer_T.proj_without_att.bias: 64 params, 0.25 KB
# GAT_layer_T.bn.weight: 64 params, 0.25 KB
# GAT_layer_T.bn.bias: 64 params, 0.25 KB
# GAT_layer_T.bn.running_mean: 64 params, 0.25 KB
# GAT_layer_T.bn.running_var: 64 params, 0.25 KB
# HtrgGAT_layer_ST11.att_weight11: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.att_weight22: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.att_weight12: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.att_weightM: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.proj_type1.bias: 64 params, 0.25 KB
# HtrgGAT_layer_ST11.proj_type2.bias: 64 params, 0.25 KB
# HtrgGAT_layer_ST11.att_proj.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.att_projM.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.proj_with_att.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.proj_without_att.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.proj_with_attM.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.proj_without_attM.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.bn.weight: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.bn.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.bn.running_mean: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.bn.running_var: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.att_weight11: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.att_weight22: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.att_weight12: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.att_weightM: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.proj_type1.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.proj_type2.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.att_proj.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.att_projM.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.proj_with_att.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.proj_without_att.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.proj_with_attM.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.proj_without_attM.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.bn.weight: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.bn.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.bn.running_mean: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.bn.running_var: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.att_weight11: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.att_weight22: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.att_weight12: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.att_weightM: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.proj_type1.bias: 64 params, 0.25 KB
# HtrgGAT_layer_ST21.proj_type2.bias: 64 params, 0.25 KB
# HtrgGAT_layer_ST21.att_proj.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.att_projM.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.proj_with_att.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.proj_without_att.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.proj_with_attM.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.proj_without_attM.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.bn.weight: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.bn.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.bn.running_mean: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.bn.running_var: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.att_weight11: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.att_weight22: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.att_weight12: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.att_weightM: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.proj_type1.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.proj_type2.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.att_proj.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.att_projM.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.proj_with_att.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.proj_without_att.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.proj_with_attM.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.proj_without_attM.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.bn.weight: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.bn.bias: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.bn.running_mean: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.bn.running_var: 32 params, 0.12 KB
# pool_S.proj.bias: 1 params, 0.00 KB
# pool_T.proj.bias: 1 params, 0.00 KB
# pool_hS1.proj.bias: 1 params, 0.00 KB
# pool_hT1.proj.bias: 1 params, 0.00 KB
# pool_hS2.proj.bias: 1 params, 0.00 KB
# pool_hT2.proj.bias: 1 params, 0.00 KB
# out_layer.weight: 320 params, 1.25 KB
# out_layer.bias: 2 params, 0.01 KB
# onnx::Conv_3298: 192 params, 0.75 KB
# onnx::Conv_3299: 32 params, 0.12 KB
# onnx::Conv_3301: 6144 params, 24.00 KB
# onnx::Conv_3302: 32 params, 0.12 KB
# onnx::Conv_3304: 12288 params, 48.00 KB
# onnx::Conv_3305: 64 params, 0.25 KB
# onnx::Conv_3307: 24576 params, 96.00 KB
# onnx::Conv_3308: 64 params, 0.25 KB
# onnx::Conv_3310: 24576 params, 96.00 KB
# onnx::Conv_3311: 64 params, 0.25 KB
# onnx::Conv_3313: 24576 params, 96.00 KB
# onnx::Conv_3314: 64 params, 0.25 KB
# onnx::MatMul_3322: 4096 params, 16.00 KB
# onnx::MatMul_3323: 4096 params, 16.00 KB
# onnx::MatMul_3324: 4096 params, 16.00 KB
# onnx::MatMul_3332: 64 params, 0.25 KB
# onnx::MatMul_3343: 4096 params, 16.00 KB
# onnx::MatMul_3344: 4096 params, 16.00 KB
# onnx::MatMul_3345: 4096 params, 16.00 KB
# onnx::MatMul_3347: 64 params, 0.25 KB
# onnx::MatMul_3351: 4096 params, 16.00 KB
# onnx::MatMul_3352: 4096 params, 16.00 KB
# onnx::MatMul_3356: 2048 params, 8.00 KB
# onnx::MatMul_3423: 2048 params, 8.00 KB
# onnx::MatMul_3424: 2048 params, 8.00 KB
# onnx::MatMul_3425: 2048 params, 8.00 KB
# onnx::MatMul_3426: 2048 params, 8.00 KB
# onnx::MatMul_3427: 2048 params, 8.00 KB
# onnx::MatMul_3432: 32 params, 0.12 KB
# onnx::MatMul_3436: 32 params, 0.12 KB
# onnx::MatMul_3440: 1024 params, 4.00 KB
# onnx::MatMul_3441: 1024 params, 4.00 KB
# onnx::MatMul_3445: 1024 params, 4.00 KB
# onnx::MatMul_3512: 1024 params, 4.00 KB
# onnx::MatMul_3513: 1024 params, 4.00 KB
# onnx::MatMul_3514: 1024 params, 4.00 KB
# onnx::MatMul_3515: 1024 params, 4.00 KB
# onnx::MatMul_3516: 1024 params, 4.00 KB
# onnx::MatMul_3521: 4096 params, 16.00 KB
# onnx::MatMul_3522: 4096 params, 16.00 KB
# onnx::MatMul_3526: 2048 params, 8.00 KB
# onnx::MatMul_3593: 2048 params, 8.00 KB
# onnx::MatMul_3594: 2048 params, 8.00 KB
# onnx::MatMul_3595: 2048 params, 8.00 KB
# onnx::MatMul_3596: 2048 params, 8.00 KB
# onnx::MatMul_3597: 2048 params, 8.00 KB
# onnx::MatMul_3602: 32 params, 0.12 KB
# onnx::MatMul_3606: 32 params, 0.12 KB
# onnx::MatMul_3610: 1024 params, 4.00 KB
# onnx::MatMul_3611: 1024 params, 4.00 KB
# onnx::MatMul_3615: 1024 params, 4.00 KB
# onnx::MatMul_3682: 1024 params, 4.00 KB
# onnx::MatMul_3683: 1024 params, 4.00 KB
# onnx::MatMul_3684: 1024 params, 4.00 KB
# onnx::MatMul_3685: 1024 params, 4.00 KB
# onnx::MatMul_3686: 1024 params, 4.00 KB
#
# Total parameters: 297228
# Total weights size: 1.13 MB

# %%
## Quantized Model Parameters

# %cd /content/aasist
import onnx
import onnx.helper
import numpy as np

# Load the ONNX model
model = onnx.load("aasist_quantized.onnx")

# Iterate through initializers (which store the weights)
total_params = 0
total_bytes = 0

for tensor in model.graph.initializer:
    # Number of parameters
    num_params = 1
    for dim in tensor.dims:
        num_params *= dim

    # Data type size (in bytes)
    # Use onnx.helper.tensor_dtype_to_np_dtype to get the numpy dtype
    # Then access the itemsize attribute
    dtype = onnx.helper.tensor_dtype_to_np_dtype(tensor.data_type)
    dtype_size = dtype.itemsize

    # Accumulate size
    size_bytes = num_params * dtype_size
    total_params += num_params
    total_bytes += size_bytes

    print(f"{tensor.name}: {num_params} params, {size_bytes/1024:.2f} KB")

print(f"\nTotal parameters: {total_params}")
print(f"Total weights size: {total_bytes / (1024 * 1024):.2f} MB")
# Out:
# /content/aasist
# first_bn.running_mean: 1 params, 0.00 KB
# first_bn.running_var: 1 params, 0.00 KB
# GAT_layer_S.bn.running_mean: 64 params, 0.25 KB
# GAT_layer_S.bn.running_var: 64 params, 0.25 KB
# GAT_layer_T.bn.running_mean: 64 params, 0.25 KB
# GAT_layer_T.bn.running_var: 64 params, 0.25 KB
# /pool_hS1/Mul_output_0: 3 params, 0.02 KB
# gemm_input_shape: 2 params, 0.02 KB
# gemm_output_shape: 3 params, 0.02 KB
# gemm_input_shape_token_0: 2 params, 0.02 KB
# gemm_output_shape_token_3: 4 params, 0.03 KB
# gemm_input_shape_token_6: 2 params, 0.02 KB
# gemm_output_shape_token_9: 3 params, 0.02 KB
# gemm_input_shape_token_12: 2 params, 0.02 KB
# gemm_output_shape_token_15: 3 params, 0.02 KB
# gemm_input_shape_token_18: 2 params, 0.02 KB
# gemm_output_shape_token_21: 3 params, 0.02 KB
# gemm_input_shape_token_24: 2 params, 0.02 KB
# gemm_output_shape_token_27: 3 params, 0.02 KB
# /Unsqueeze_output_0_zero_point: 1 params, 0.00 KB
# /Unsqueeze_output_0_scale: 1 params, 0.00 KB
# /conv_time/Conv_output_0_zero_point: 1 params, 0.00 KB
# /conv_time/Conv_output_0_scale: 1 params, 0.00 KB
# /conv_time/Constant_output_0_zero_point: 70 params, 0.07 KB
# /conv_time/Constant_output_0_scale: 70 params, 0.27 KB
# /conv_time/Constant_output_0_quantized: 9030 params, 8.82 KB
# /MaxPool_output_0_zero_point: 1 params, 0.00 KB
# /MaxPool_output_0_scale: 1 params, 0.00 KB
# first_bn.weight_zero_point: 1 params, 0.00 KB
# first_bn.weight_scale: 1 params, 0.00 KB
# first_bn.weight_quantized: 1 params, 0.00 KB
# /first_bn/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /first_bn/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# /selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder/encoder.0/encoder.0.0/conv_downsample/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.0/encoder.0.0/conv_downsample/Conv_output_0_scale: 1 params, 0.00 KB
# encoder.0.0.conv_downsample.weight_zero_point: 32 params, 0.03 KB
# encoder.0.0.conv_downsample.weight_scale: 32 params, 0.12 KB
# encoder.0.0.conv_downsample.weight_quantized: 96 params, 0.09 KB
# /encoder/encoder.0/encoder.0.0/conv1/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.0/encoder.0.0/conv1/Conv_output_0_scale: 1 params, 0.00 KB
# onnx::Conv_3298_zero_point: 32 params, 0.03 KB
# onnx::Conv_3298_scale: 32 params, 0.12 KB
# onnx::Conv_3298_quantized: 192 params, 0.19 KB
# /encoder/encoder.0/encoder.0.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.0/encoder.0.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder/encoder.0/encoder.0.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.0/encoder.0.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder.0.0.conv2.weight_zero_point: 32 params, 0.03 KB
# encoder.0.0.conv2.weight_scale: 32 params, 0.12 KB
# encoder.0.0.conv2.weight_quantized: 6144 params, 6.00 KB
# /encoder/encoder.0/encoder.0.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.0/encoder.0.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder/encoder.1/encoder.1.0/conv1/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.1/encoder.1.0/conv1/Conv_output_0_scale: 1 params, 0.00 KB
# onnx::Conv_3301_zero_point: 32 params, 0.03 KB
# onnx::Conv_3301_scale: 32 params, 0.12 KB
# onnx::Conv_3301_quantized: 6144 params, 6.00 KB
# /encoder/encoder.1/encoder.1.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.1/encoder.1.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder/encoder.1/encoder.1.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.1/encoder.1.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder.1.0.conv2.weight_zero_point: 32 params, 0.03 KB
# encoder.1.0.conv2.weight_scale: 32 params, 0.12 KB
# encoder.1.0.conv2.weight_quantized: 6144 params, 6.00 KB
# /encoder/encoder.1/encoder.1.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.1/encoder.1.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder/encoder.2/encoder.2.0/conv_downsample/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.2/encoder.2.0/conv_downsample/Conv_output_0_scale: 1 params, 0.00 KB
# encoder.2.0.conv_downsample.weight_zero_point: 64 params, 0.06 KB
# encoder.2.0.conv_downsample.weight_scale: 64 params, 0.25 KB
# encoder.2.0.conv_downsample.weight_quantized: 6144 params, 6.00 KB
# /encoder/encoder.2/encoder.2.0/conv1/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.2/encoder.2.0/conv1/Conv_output_0_scale: 1 params, 0.00 KB
# onnx::Conv_3304_zero_point: 64 params, 0.06 KB
# onnx::Conv_3304_scale: 64 params, 0.25 KB
# onnx::Conv_3304_quantized: 12288 params, 12.00 KB
# /encoder/encoder.2/encoder.2.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.2/encoder.2.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder/encoder.2/encoder.2.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.2/encoder.2.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder.2.0.conv2.weight_zero_point: 64 params, 0.06 KB
# encoder.2.0.conv2.weight_scale: 64 params, 0.25 KB
# encoder.2.0.conv2.weight_quantized: 24576 params, 24.00 KB
# /encoder/encoder.2/encoder.2.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.2/encoder.2.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder/encoder.3/encoder.3.0/conv1/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.3/encoder.3.0/conv1/Conv_output_0_scale: 1 params, 0.00 KB
# onnx::Conv_3307_zero_point: 64 params, 0.06 KB
# onnx::Conv_3307_scale: 64 params, 0.25 KB
# onnx::Conv_3307_quantized: 24576 params, 24.00 KB
# /encoder/encoder.3/encoder.3.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.3/encoder.3.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder/encoder.3/encoder.3.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.3/encoder.3.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder.3.0.conv2.weight_zero_point: 64 params, 0.06 KB
# encoder.3.0.conv2.weight_scale: 64 params, 0.25 KB
# encoder.3.0.conv2.weight_quantized: 24576 params, 24.00 KB
# /encoder/encoder.3/encoder.3.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.3/encoder.3.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder/encoder.4/encoder.4.0/conv1/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.4/encoder.4.0/conv1/Conv_output_0_scale: 1 params, 0.00 KB
# onnx::Conv_3310_zero_point: 64 params, 0.06 KB
# onnx::Conv_3310_scale: 64 params, 0.25 KB
# onnx::Conv_3310_quantized: 24576 params, 24.00 KB
# /encoder/encoder.4/encoder.4.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.4/encoder.4.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder/encoder.4/encoder.4.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.4/encoder.4.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder.4.0.conv2.weight_zero_point: 64 params, 0.06 KB
# encoder.4.0.conv2.weight_scale: 64 params, 0.25 KB
# encoder.4.0.conv2.weight_quantized: 24576 params, 24.00 KB
# /encoder/encoder.4/encoder.4.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.4/encoder.4.0/Add_output_0_scale: 1 params, 0.00 KB
# /encoder/encoder.5/encoder.5.0/conv1/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.5/encoder.5.0/conv1/Conv_output_0_scale: 1 params, 0.00 KB
# onnx::Conv_3313_zero_point: 64 params, 0.06 KB
# onnx::Conv_3313_scale: 64 params, 0.25 KB
# onnx::Conv_3313_quantized: 24576 params, 24.00 KB
# /encoder/encoder.5/encoder.5.0/selu/Selu_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.5/encoder.5.0/selu/Selu_output_0_scale: 1 params, 0.00 KB
# /encoder/encoder.5/encoder.5.0/conv2/Conv_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.5/encoder.5.0/conv2/Conv_output_0_scale: 1 params, 0.00 KB
# encoder.5.0.conv2.weight_zero_point: 64 params, 0.06 KB
# encoder.5.0.conv2.weight_scale: 64 params, 0.25 KB
# encoder.5.0.conv2.weight_quantized: 24576 params, 24.00 KB
# /encoder/encoder.5/encoder.5.0/Add_output_0_zero_point: 1 params, 0.00 KB
# /encoder/encoder.5/encoder.5.0/Add_output_0_scale: 1 params, 0.00 KB
# /Transpose_output_0_zero_point: 1 params, 0.00 KB
# /Transpose_output_0_scale: 1 params, 0.00 KB
# pos_S_zero_point: 1 params, 0.00 KB
# pos_S_scale: 1 params, 0.00 KB
# pos_S_quantized: 1472 params, 1.44 KB
# /Add_output_0_zero_point: 1 params, 0.00 KB
# /Add_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_S/Expand_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_S/Expand_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_S/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_S/Transpose_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_S/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_S/Mul_1_output_0_scale: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_4_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_4_scale: 1 params, 0.00 KB
# onnx::MatMul_3322_zero_point: 64 params, 0.06 KB
# onnx::MatMul_3322_scale: 64 params, 0.25 KB
# onnx::MatMul_3322_quantized: 4096 params, 4.00 KB
# /GAT_layer_S/Tanh_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_S/Tanh_output_0_scale: 1 params, 0.00 KB
# GAT_layer_S.att_weight_zero_point: 1 params, 0.00 KB
# GAT_layer_S.att_weight_scale: 1 params, 0.00 KB
# GAT_layer_S.att_weight_quantized: 64 params, 0.06 KB
# /GAT_layer_S/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_S/MatMul_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_S/Div_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_S/Div_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_S/Softmax_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_S/Softmax_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_S/MatMul_1_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_S/MatMul_1_output_0_scale: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_10_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_10_scale: 1 params, 0.00 KB
# onnx::MatMul_3323_zero_point: 64 params, 0.06 KB
# onnx::MatMul_3323_scale: 64 params, 0.25 KB
# onnx::MatMul_3323_quantized: 4096 params, 4.00 KB
# gemm_output_reshape_arg_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_scale: 1 params, 0.00 KB
# onnx::MatMul_3324_zero_point: 64 params, 0.06 KB
# onnx::MatMul_3324_scale: 64 params, 0.25 KB
# onnx::MatMul_3324_quantized: 4096 params, 4.00 KB
# /GAT_layer_S/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_S/Add_output_0_scale: 1 params, 0.00 KB
# GAT_layer_S.bn.weight_zero_point: 1 params, 0.00 KB
# GAT_layer_S.bn.weight_scale: 1 params, 0.00 KB
# GAT_layer_S.bn.weight_quantized: 64 params, 0.06 KB
# /GAT_layer_S/bn/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_S/bn/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# gemm_input_reshape_arg_token_13_zero_point: 1 params, 0.00 KB
# gemm_input_reshape_arg_token_13_scale: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_16_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_16_scale: 1 params, 0.00 KB
# onnx::MatMul_3332_zero_point: 1 params, 0.00 KB
# onnx::MatMul_3332_scale: 1 params, 0.00 KB
# onnx::MatMul_3332_quantized: 64 params, 0.06 KB
# /pool_S/sigmoid/Sigmoid_output_0_zero_point: 1 params, 0.00 KB
# /pool_S/sigmoid/Sigmoid_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_S/act/Selu_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_S/act/Selu_output_0_scale: 1 params, 0.00 KB
# /pool_S/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /pool_S/Mul_1_output_0_scale: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_22_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_22_scale: 1 params, 0.00 KB
# onnx::MatMul_3522_zero_point: 64 params, 0.06 KB
# onnx::MatMul_3522_scale: 64 params, 0.25 KB
# onnx::MatMul_3522_quantized: 4096 params, 4.00 KB
# /Transpose_1_output_0_zero_point: 1 params, 0.00 KB
# /Transpose_1_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3345_zero_point: 64 params, 0.06 KB
# onnx::MatMul_3345_scale: 64 params, 0.25 KB
# onnx::MatMul_3345_quantized: 4096 params, 4.00 KB
# /GAT_layer_T/proj_without_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/proj_without_att/MatMul_output_0_scale: 1 params, 0.00 KB
# GAT_layer_T.proj_without_att.bias_zero_point: 1 params, 0.00 KB
# GAT_layer_T.proj_without_att.bias_scale: 1 params, 0.00 KB
# GAT_layer_T.proj_without_att.bias_quantized: 64 params, 0.06 KB
# /GAT_layer_T/proj_without_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/proj_without_att/Add_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_T/Expand_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/Expand_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_T/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/Transpose_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_T/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/Mul_1_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3343_zero_point: 64 params, 0.06 KB
# onnx::MatMul_3343_scale: 64 params, 0.25 KB
# onnx::MatMul_3343_quantized: 4096 params, 4.00 KB
# /GAT_layer_T/att_proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/att_proj/MatMul_output_0_scale: 1 params, 0.00 KB
# GAT_layer_T.att_proj.bias_zero_point: 1 params, 0.00 KB
# GAT_layer_T.att_proj.bias_scale: 1 params, 0.00 KB
# GAT_layer_T.att_proj.bias_quantized: 64 params, 0.06 KB
# /GAT_layer_T/att_proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/att_proj/Add_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_T/Tanh_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/Tanh_output_0_scale: 1 params, 0.00 KB
# GAT_layer_T.att_weight_zero_point: 1 params, 0.00 KB
# GAT_layer_T.att_weight_scale: 1 params, 0.00 KB
# GAT_layer_T.att_weight_quantized: 64 params, 0.06 KB
# /GAT_layer_T/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/MatMul_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_T/Div_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/Div_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_T/Softmax_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/Softmax_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_T/MatMul_1_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/MatMul_1_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3344_zero_point: 64 params, 0.06 KB
# onnx::MatMul_3344_scale: 64 params, 0.25 KB
# onnx::MatMul_3344_quantized: 4096 params, 4.00 KB
# /GAT_layer_T/proj_with_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/proj_with_att/MatMul_output_0_scale: 1 params, 0.00 KB
# GAT_layer_T.proj_with_att.bias_zero_point: 1 params, 0.00 KB
# GAT_layer_T.proj_with_att.bias_scale: 1 params, 0.00 KB
# GAT_layer_T.proj_with_att.bias_quantized: 64 params, 0.06 KB
# /GAT_layer_T/proj_with_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/proj_with_att/Add_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_T/Add_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/Add_output_0_scale: 1 params, 0.00 KB
# GAT_layer_T.bn.weight_zero_point: 1 params, 0.00 KB
# GAT_layer_T.bn.weight_scale: 1 params, 0.00 KB
# GAT_layer_T.bn.weight_quantized: 64 params, 0.06 KB
# /GAT_layer_T/bn/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/bn/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# /GAT_layer_T/act/Selu_output_0_zero_point: 1 params, 0.00 KB
# /GAT_layer_T/act/Selu_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3347_zero_point: 1 params, 0.00 KB
# onnx::MatMul_3347_scale: 1 params, 0.00 KB
# onnx::MatMul_3347_quantized: 64 params, 0.06 KB
# /pool_T/proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /pool_T/proj/MatMul_output_0_scale: 1 params, 0.00 KB
# pool_T.proj.bias_zero_point: 1 params, 0.00 KB
# pool_T.proj.bias_scale: 1 params, 0.00 KB
# pool_T.proj.bias_quantized: 1 params, 0.00 KB
# /pool_T/proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /pool_T/proj/Add_output_0_scale: 1 params, 0.00 KB
# /pool_T/sigmoid/Sigmoid_output_0_zero_point: 1 params, 0.00 KB
# /pool_T/sigmoid/Sigmoid_output_0_scale: 1 params, 0.00 KB
# /pool_T/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /pool_T/Mul_1_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3521_zero_point: 64 params, 0.06 KB
# onnx::MatMul_3521_scale: 64 params, 0.25 KB
# onnx::MatMul_3521_quantized: 4096 params, 4.00 KB
# /HtrgGAT_layer_ST21/proj_type1/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/proj_type1/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_type1.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_type1.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_type1.bias_quantized: 64 params, 0.06 KB
# /HtrgGAT_layer_ST21/proj_type1/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/proj_type1/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Concat_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Concat_output_0_scale: 1 params, 0.00 KB
# master2_zero_point: 1 params, 0.00 KB
# master2_scale: 1 params, 0.00 KB
# master2_quantized: 64 params, 0.06 KB
# /HtrgGAT_layer_ST21/Mul_18_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Mul_18_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3593_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3593_scale: 32 params, 0.12 KB
# onnx::MatMul_3593_quantized: 2048 params, 2.00 KB
# /HtrgGAT_layer_ST21/att_projM/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/att_projM/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_projM.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_projM.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_projM.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST21/att_projM/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/att_projM/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Tanh_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Tanh_1_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_weightM_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_weightM_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_weightM_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST21/MatMul_4_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/MatMul_4_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Div_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Div_1_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Softmax_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Softmax_1_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/MatMul_5_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/MatMul_5_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3594_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3594_scale: 32 params, 0.12 KB
# onnx::MatMul_3594_quantized: 2048 params, 2.00 KB
# /HtrgGAT_layer_ST21/proj_with_attM/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/proj_with_attM/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_with_attM.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_with_attM.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_with_attM.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST21/proj_with_attM/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/proj_with_attM/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/proj_without_attM/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/proj_without_attM/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/proj_without_attM/Add_output_0_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST21/Add_12_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Add_12_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3684_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3684_scale: 32 params, 0.12 KB
# onnx::MatMul_3684_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST22/proj_without_attM/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/proj_without_attM/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_without_attM.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_without_attM.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_without_attM.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/proj_without_attM/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/proj_without_attM/Add_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3597_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3597_scale: 32 params, 0.12 KB
# onnx::MatMul_3597_quantized: 2048 params, 2.00 KB
# /HtrgGAT_layer_ST21/proj_without_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/proj_without_att/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_without_att.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_without_att.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_without_att.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST21/proj_without_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/proj_without_att/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Expand_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Expand_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Transpose_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Mul_1_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3526_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3526_scale: 32 params, 0.12 KB
# onnx::MatMul_3526_quantized: 2048 params, 2.00 KB
# /HtrgGAT_layer_ST21/att_proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/att_proj/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_proj.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_proj.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_proj.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST21/att_proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/att_proj/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Slice_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Slice_1_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_weight11_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_weight11_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_weight11_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST21/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/MatMul_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Slice_8_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Slice_8_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_weight22_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_weight22_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_weight22_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST21/MatMul_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/MatMul_1_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Slice_14_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Slice_14_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_weight12_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_weight12_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.att_weight12_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST21/MatMul_2_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/MatMul_2_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Slice_20_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Slice_20_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/MatMul_3_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/MatMul_3_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Div_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Div_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Softmax_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Softmax_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/MatMul_6_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/MatMul_6_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3596_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3596_scale: 32 params, 0.12 KB
# onnx::MatMul_3596_quantized: 2048 params, 2.00 KB
# /HtrgGAT_layer_ST21/proj_with_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/proj_with_att/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_with_att.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_with_att.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_with_att.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST21/proj_with_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/proj_with_att/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Add_13_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Add_13_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.bn.weight_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.bn.weight_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.bn.weight_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST21/bn/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/bn/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Slice_27_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Slice_27_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3602_zero_point: 1 params, 0.00 KB
# onnx::MatMul_3602_scale: 1 params, 0.00 KB
# onnx::MatMul_3602_quantized: 32 params, 0.03 KB
# /pool_hS2/proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /pool_hS2/proj/MatMul_output_0_scale: 1 params, 0.00 KB
# pool_hS2.proj.bias_zero_point: 1 params, 0.00 KB
# pool_hS2.proj.bias_scale: 1 params, 0.00 KB
# pool_hS2.proj.bias_quantized: 1 params, 0.00 KB
# /pool_hS2/proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /pool_hS2/proj/Add_output_0_scale: 1 params, 0.00 KB
# /pool_hS2/sigmoid/Sigmoid_output_0_zero_point: 1 params, 0.00 KB
# /pool_hS2/sigmoid/Sigmoid_output_0_scale: 1 params, 0.00 KB
# /pool_hS2/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /pool_hS2/Mul_1_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3611_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3611_scale: 32 params, 0.12 KB
# onnx::MatMul_3611_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST22/proj_type2/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/proj_type2/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_type2.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_type2.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_type2.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/proj_type2/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/proj_type2/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Slice_26_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST21/Slice_26_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3606_zero_point: 1 params, 0.00 KB
# onnx::MatMul_3606_scale: 1 params, 0.00 KB
# onnx::MatMul_3606_quantized: 32 params, 0.03 KB
# /pool_hT2/proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /pool_hT2/proj/MatMul_output_0_scale: 1 params, 0.00 KB
# pool_hT2.proj.bias_zero_point: 1 params, 0.00 KB
# pool_hT2.proj.bias_scale: 1 params, 0.00 KB
# pool_hT2.proj.bias_quantized: 1 params, 0.00 KB
# /pool_hT2/proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /pool_hT2/proj/Add_output_0_scale: 1 params, 0.00 KB
# /pool_hT2/sigmoid/Sigmoid_output_0_zero_point: 1 params, 0.00 KB
# /pool_hT2/sigmoid/Sigmoid_output_0_scale: 1 params, 0.00 KB
# /pool_hT2/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /pool_hT2/Mul_1_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3610_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3610_scale: 32 params, 0.12 KB
# onnx::MatMul_3610_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST22/proj_type1/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/proj_type1/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_type1.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_type1.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_type1.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/proj_type1/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/proj_type1/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Concat_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Concat_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Mul_18_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Mul_18_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3682_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3682_scale: 32 params, 0.12 KB
# onnx::MatMul_3682_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST22/att_projM/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/att_projM/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_projM.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_projM.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_projM.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/att_projM/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/att_projM/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Tanh_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Tanh_1_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_weightM_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_weightM_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_weightM_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/MatMul_4_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/MatMul_4_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Div_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Div_1_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Softmax_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Softmax_1_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/MatMul_5_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/MatMul_5_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3683_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3683_scale: 32 params, 0.12 KB
# onnx::MatMul_3683_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST22/proj_with_attM/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/proj_with_attM/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_with_attM.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_with_attM.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_with_attM.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/proj_with_attM/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/proj_with_attM/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Add_12_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Add_12_output_0_scale: 1 params, 0.00 KB
# /Add_6_output_0_zero_point: 1 params, 0.00 KB
# /Add_6_output_0_scale: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_28_zero_point: 1 params, 0.00 KB
# gemm_output_reshape_arg_token_28_scale: 1 params, 0.00 KB
# onnx::MatMul_3352_zero_point: 64 params, 0.06 KB
# onnx::MatMul_3352_scale: 64 params, 0.25 KB
# onnx::MatMul_3352_quantized: 4096 params, 4.00 KB
# onnx::MatMul_3351_zero_point: 64 params, 0.06 KB
# onnx::MatMul_3351_scale: 64 params, 0.25 KB
# onnx::MatMul_3351_quantized: 4096 params, 4.00 KB
# /HtrgGAT_layer_ST11/proj_type1/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/proj_type1/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_type1.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_type1.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_type1.bias_quantized: 64 params, 0.06 KB
# /HtrgGAT_layer_ST11/proj_type1/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/proj_type1/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Concat_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Concat_output_0_scale: 1 params, 0.00 KB
# master1_zero_point: 1 params, 0.00 KB
# master1_scale: 1 params, 0.00 KB
# master1_quantized: 64 params, 0.06 KB
# /HtrgGAT_layer_ST11/Mul_18_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Mul_18_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3423_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3423_scale: 32 params, 0.12 KB
# onnx::MatMul_3423_quantized: 2048 params, 2.00 KB
# /HtrgGAT_layer_ST11/att_projM/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/att_projM/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_projM.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_projM.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_projM.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST11/att_projM/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/att_projM/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Tanh_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Tanh_1_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_weightM_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_weightM_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_weightM_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST11/MatMul_4_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/MatMul_4_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Div_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Div_1_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Softmax_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Softmax_1_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/MatMul_5_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/MatMul_5_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3424_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3424_scale: 32 params, 0.12 KB
# onnx::MatMul_3424_quantized: 2048 params, 2.00 KB
# /HtrgGAT_layer_ST11/proj_with_attM/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/proj_with_attM/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_with_attM.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_with_attM.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_with_attM.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST11/proj_with_attM/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/proj_with_attM/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/proj_without_attM/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/proj_without_attM/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/proj_without_attM/Add_output_0_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST11/Add_12_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Add_12_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3514_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3514_scale: 32 params, 0.12 KB
# onnx::MatMul_3514_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST12/proj_without_attM/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/proj_without_attM/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_without_attM.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_without_attM.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_without_attM.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST12/proj_without_attM/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/proj_without_attM/Add_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3427_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3427_scale: 32 params, 0.12 KB
# onnx::MatMul_3427_quantized: 2048 params, 2.00 KB
# /HtrgGAT_layer_ST11/proj_without_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/proj_without_att/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_without_att.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_without_att.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_without_att.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST11/proj_without_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/proj_without_att/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Expand_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Expand_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Transpose_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Mul_1_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3356_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3356_scale: 32 params, 0.12 KB
# onnx::MatMul_3356_quantized: 2048 params, 2.00 KB
# /HtrgGAT_layer_ST11/att_proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/att_proj/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_proj.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_proj.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_proj.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST11/att_proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/att_proj/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Slice_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Slice_1_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_weight11_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_weight11_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_weight11_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST11/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/MatMul_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Slice_8_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Slice_8_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_weight22_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_weight22_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_weight22_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST11/MatMul_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/MatMul_1_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Slice_14_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Slice_14_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_weight12_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_weight12_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.att_weight12_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST11/MatMul_2_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/MatMul_2_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Slice_20_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Slice_20_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/MatMul_3_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/MatMul_3_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Div_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Div_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Softmax_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Softmax_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/MatMul_6_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/MatMul_6_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3426_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3426_scale: 32 params, 0.12 KB
# onnx::MatMul_3426_quantized: 2048 params, 2.00 KB
# /HtrgGAT_layer_ST11/proj_with_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/proj_with_att/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_with_att.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_with_att.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_with_att.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST11/proj_with_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/proj_with_att/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Add_13_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Add_13_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.bn.weight_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.bn.weight_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.bn.weight_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST11/bn/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/bn/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Slice_27_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Slice_27_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3432_zero_point: 1 params, 0.00 KB
# onnx::MatMul_3432_scale: 1 params, 0.00 KB
# onnx::MatMul_3432_quantized: 32 params, 0.03 KB
# /pool_hS1/proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /pool_hS1/proj/MatMul_output_0_scale: 1 params, 0.00 KB
# pool_hS1.proj.bias_zero_point: 1 params, 0.00 KB
# pool_hS1.proj.bias_scale: 1 params, 0.00 KB
# pool_hS1.proj.bias_quantized: 1 params, 0.00 KB
# /pool_hS1/proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /pool_hS1/proj/Add_output_0_scale: 1 params, 0.00 KB
# /pool_hS1/sigmoid/Sigmoid_output_0_zero_point: 1 params, 0.00 KB
# /pool_hS1/sigmoid/Sigmoid_output_0_scale: 1 params, 0.00 KB
# /pool_hS1/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /pool_hS1/Mul_1_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3441_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3441_scale: 32 params, 0.12 KB
# onnx::MatMul_3441_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST12/proj_type2/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/proj_type2/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_type2.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_type2.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_type2.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST12/proj_type2/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/proj_type2/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Slice_26_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST11/Slice_26_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3436_zero_point: 1 params, 0.00 KB
# onnx::MatMul_3436_scale: 1 params, 0.00 KB
# onnx::MatMul_3436_quantized: 32 params, 0.03 KB
# /pool_hT1/proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /pool_hT1/proj/MatMul_output_0_scale: 1 params, 0.00 KB
# pool_hT1.proj.bias_zero_point: 1 params, 0.00 KB
# pool_hT1.proj.bias_scale: 1 params, 0.00 KB
# pool_hT1.proj.bias_quantized: 1 params, 0.00 KB
# /pool_hT1/proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /pool_hT1/proj/Add_output_0_scale: 1 params, 0.00 KB
# /pool_hT1/sigmoid/Sigmoid_output_0_zero_point: 1 params, 0.00 KB
# /pool_hT1/sigmoid/Sigmoid_output_0_scale: 1 params, 0.00 KB
# /pool_hT1/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /pool_hT1/Mul_1_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3440_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3440_scale: 32 params, 0.12 KB
# onnx::MatMul_3440_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST12/proj_type1/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/proj_type1/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_type1.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_type1.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_type1.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST12/proj_type1/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/proj_type1/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Concat_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Concat_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Mul_18_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Mul_18_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3512_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3512_scale: 32 params, 0.12 KB
# onnx::MatMul_3512_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST12/att_projM/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/att_projM/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_projM.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_projM.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_projM.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST12/att_projM/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/att_projM/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Tanh_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Tanh_1_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_weightM_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_weightM_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_weightM_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST12/MatMul_4_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/MatMul_4_output_0_scale: 1 params, 0.00 KB
# ...
# onnx::MatMul_3686_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST22/proj_without_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/proj_without_att/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_without_att.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_without_att.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_without_att.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/proj_without_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/proj_without_att/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Expand_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Expand_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Transpose_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Mul_1_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3615_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3615_scale: 32 params, 0.12 KB
# onnx::MatMul_3615_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST22/att_proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/att_proj/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_proj.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_proj.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_proj.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/att_proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/att_proj/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Slice_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Slice_1_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_weight11_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_weight11_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_weight11_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/MatMul_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Slice_8_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Slice_8_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_weight22_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_weight22_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_weight22_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/MatMul_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/MatMul_1_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Slice_14_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Slice_14_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_weight12_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_weight12_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.att_weight12_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/MatMul_2_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/MatMul_2_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Slice_20_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Slice_20_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/MatMul_3_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/MatMul_3_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Div_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Div_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Softmax_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Softmax_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/MatMul_6_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/MatMul_6_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3685_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3685_scale: 32 params, 0.12 KB
# onnx::MatMul_3685_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST22/proj_with_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/proj_with_att/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_with_att.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_with_att.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.proj_with_att.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/proj_with_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/proj_with_att/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Add_13_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Add_13_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.bn.weight_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.bn.weight_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.bn.weight_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST22/bn/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/bn/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Slice_27_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Slice_27_output_0_scale: 1 params, 0.00 KB
# /Add_4_output_0_zero_point: 1 params, 0.00 KB
# /Add_4_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3516_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3516_scale: 32 params, 0.12 KB
# onnx::MatMul_3516_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST12/proj_without_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/proj_without_att/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_without_att.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_without_att.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_without_att.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST12/proj_without_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/proj_without_att/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Expand_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Expand_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Transpose_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Transpose_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Mul_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Mul_1_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3445_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3445_scale: 32 params, 0.12 KB
# onnx::MatMul_3445_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST12/att_proj/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/att_proj/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_proj.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_proj.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_proj.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST12/att_proj/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/att_proj/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Slice_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Slice_1_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_weight11_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_weight11_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_weight11_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST12/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/MatMul_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Slice_8_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Slice_8_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_weight22_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_weight22_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_weight22_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST12/MatMul_1_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/MatMul_1_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Slice_14_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Slice_14_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_weight12_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_weight12_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.att_weight12_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST12/MatMul_2_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/MatMul_2_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Slice_20_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Slice_20_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/MatMul_3_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/MatMul_3_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Div_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Div_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Softmax_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Softmax_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/MatMul_6_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/MatMul_6_output_0_scale: 1 params, 0.00 KB
# onnx::MatMul_3515_zero_point: 32 params, 0.03 KB
# onnx::MatMul_3515_scale: 32 params, 0.12 KB
# onnx::MatMul_3515_quantized: 1024 params, 1.00 KB
# /HtrgGAT_layer_ST12/proj_with_att/MatMul_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/proj_with_att/MatMul_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_with_att.bias_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_with_att.bias_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.proj_with_att.bias_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST12/proj_with_att/Add_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/proj_with_att/Add_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Add_13_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Add_13_output_0_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.bn.weight_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.bn.weight_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.bn.weight_quantized: 32 params, 0.03 KB
# /HtrgGAT_layer_ST12/bn/BatchNormalization_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/bn/BatchNormalization_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Slice_27_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Slice_27_output_0_scale: 1 params, 0.00 KB
# /Add_3_output_0_zero_point: 1 params, 0.00 KB
# /Add_3_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Slice_26_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST22/Slice_26_output_0_scale: 1 params, 0.00 KB
# /Add_2_output_0_zero_point: 1 params, 0.00 KB
# /Add_2_output_0_scale: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Slice_26_output_0_zero_point: 1 params, 0.00 KB
# /HtrgGAT_layer_ST12/Slice_26_output_0_scale: 1 params, 0.00 KB
# /Add_1_output_0_zero_point: 1 params, 0.00 KB
# /Add_1_output_0_scale: 1 params, 0.00 KB
# /ReduceMax_2_output_0_zero_point: 1 params, 0.00 KB
# /ReduceMax_2_output_0_scale: 1 params, 0.00 KB
# /ReduceMean_output_0_zero_point: 1 params, 0.00 KB
# /ReduceMean_output_0_scale: 1 params, 0.00 KB
# /ReduceMax_3_output_0_zero_point: 1 params, 0.00 KB
# /ReduceMax_3_output_0_scale: 1 params, 0.00 KB
# /ReduceMean_1_output_0_zero_point: 1 params, 0.00 KB
# /ReduceMean_1_output_0_scale: 1 params, 0.00 KB
# /Squeeze_output_0_zero_point: 1 params, 0.00 KB
# /Squeeze_output_0_scale: 1 params, 0.00 KB
# embedding_zero_point: 1 params, 0.00 KB
# embedding_scale: 1 params, 0.00 KB
# logits_zero_point: 1 params, 0.00 KB
# logits_scale: 1 params, 0.00 KB
# out_layer.weight_zero_point: 2 params, 0.00 KB
# out_layer.weight_scale: 2 params, 0.01 KB
# out_layer.weight_quantized: 320 params, 0.31 KB
# first_bn.bias_quantized: 1 params, 0.00 KB
# first_bn.bias_quantized_scale: 1 params, 0.00 KB
# first_bn.bias_quantized_zero_point: 1 params, 0.00 KB
# encoder.0.0.conv_downsample.bias_quantized: 32 params, 0.12 KB
# encoder.0.0.conv_downsample.bias_quantized_scale: 32 params, 0.12 KB
# encoder.0.0.conv_downsample.bias_quantized_zero_point: 32 params, 0.12 KB
# onnx::Conv_3299_quantized: 32 params, 0.12 KB
# onnx::Conv_3299_quantized_scale: 32 params, 0.12 KB
# onnx::Conv_3299_quantized_zero_point: 32 params, 0.12 KB
# encoder.0.0.conv2.bias_quantized: 32 params, 0.12 KB
# encoder.0.0.conv2.bias_quantized_scale: 32 params, 0.12 KB
# encoder.0.0.conv2.bias_quantized_zero_point: 32 params, 0.12 KB
# onnx::Conv_3302_quantized: 32 params, 0.12 KB
# onnx::Conv_3302_quantized_scale: 32 params, 0.12 KB
# onnx::Conv_3302_quantized_zero_point: 32 params, 0.12 KB
# encoder.1.0.conv2.bias_quantized: 32 params, 0.12 KB
# encoder.1.0.conv2.bias_quantized_scale: 32 params, 0.12 KB
# encoder.1.0.conv2.bias_quantized_zero_point: 32 params, 0.12 KB
# encoder.2.0.conv_downsample.bias_quantized: 64 params, 0.25 KB
# encoder.2.0.conv_downsample.bias_quantized_scale: 64 params, 0.25 KB
# encoder.2.0.conv_downsample.bias_quantized_zero_point: 64 params, 0.25 KB
# onnx::Conv_3305_quantized: 64 params, 0.25 KB
# onnx::Conv_3305_quantized_scale: 64 params, 0.25 KB
# onnx::Conv_3305_quantized_zero_point: 64 params, 0.25 KB
# encoder.2.0.conv2.bias_quantized: 64 params, 0.25 KB
# encoder.2.0.conv2.bias_quantized_scale: 64 params, 0.25 KB
# encoder.2.0.conv2.bias_quantized_zero_point: 64 params, 0.25 KB
# onnx::Conv_3308_quantized: 64 params, 0.25 KB
# onnx::Conv_3308_quantized_scale: 64 params, 0.25 KB
# onnx::Conv_3308_quantized_zero_point: 64 params, 0.25 KB
# encoder.3.0.conv2.bias_quantized: 64 params, 0.25 KB
# encoder.3.0.conv2.bias_quantized_scale: 64 params, 0.25 KB
# encoder.3.0.conv2.bias_quantized_zero_point: 64 params, 0.25 KB
# onnx::Conv_3311_quantized: 64 params, 0.25 KB
# onnx::Conv_3311_quantized_scale: 64 params, 0.25 KB
# onnx::Conv_3311_quantized_zero_point: 64 params, 0.25 KB
# encoder.4.0.conv2.bias_quantized: 64 params, 0.25 KB
# encoder.4.0.conv2.bias_quantized_scale: 64 params, 0.25 KB
# encoder.4.0.conv2.bias_quantized_zero_point: 64 params, 0.25 KB
# onnx::Conv_3314_quantized: 64 params, 0.25 KB
# onnx::Conv_3314_quantized_scale: 64 params, 0.25 KB
# onnx::Conv_3314_quantized_zero_point: 64 params, 0.25 KB
# encoder.5.0.conv2.bias_quantized: 64 params, 0.25 KB
# encoder.5.0.conv2.bias_quantized_scale: 64 params, 0.25 KB
# encoder.5.0.conv2.bias_quantized_zero_point: 64 params, 0.25 KB
# GAT_layer_S.att_proj.bias_quantized: 64 params, 0.25 KB
# GAT_layer_S.att_proj.bias_quantized_scale: 64 params, 0.25 KB
# GAT_layer_S.att_proj.bias_quantized_zero_point: 64 params, 0.25 KB
# GAT_layer_S.proj_with_att.bias_quantized: 64 params, 0.25 KB
# GAT_layer_S.proj_with_att.bias_quantized_scale: 64 params, 0.25 KB
# GAT_layer_S.proj_with_att.bias_quantized_zero_point: 64 params, 0.25 KB
# GAT_layer_S.proj_without_att.bias_quantized: 64 params, 0.25 KB
# GAT_layer_S.proj_without_att.bias_quantized_scale: 64 params, 0.25 KB
# GAT_layer_S.proj_without_att.bias_quantized_zero_point: 64 params, 0.25 KB
# GAT_layer_S.bn.bias_quantized: 64 params, 0.25 KB
# GAT_layer_S.bn.bias_quantized_scale: 1 params, 0.00 KB
# GAT_layer_S.bn.bias_quantized_zero_point: 1 params, 0.00 KB
# pool_S.proj.bias_quantized: 1 params, 0.00 KB
# pool_S.proj.bias_quantized_scale: 1 params, 0.00 KB
# pool_S.proj.bias_quantized_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.proj_type2.bias_quantized: 64 params, 0.25 KB
# HtrgGAT_layer_ST21.proj_type2.bias_quantized_scale: 64 params, 0.25 KB
# HtrgGAT_layer_ST21.proj_type2.bias_quantized_zero_point: 64 params, 0.25 KB
# GAT_layer_T.bn.bias_quantized: 64 params, 0.25 KB
# GAT_layer_T.bn.bias_quantized_scale: 1 params, 0.00 KB
# GAT_layer_T.bn.bias_quantized_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.bn.bias_quantized: 32 params, 0.12 KB
# HtrgGAT_layer_ST21.bn.bias_quantized_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST21.bn.bias_quantized_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.proj_type2.bias_quantized: 64 params, 0.25 KB
# HtrgGAT_layer_ST11.proj_type2.bias_quantized_scale: 64 params, 0.25 KB
# HtrgGAT_layer_ST11.proj_type2.bias_quantized_zero_point: 64 params, 0.25 KB
# HtrgGAT_layer_ST11.bn.bias_quantized: 32 params, 0.12 KB
# HtrgGAT_layer_ST11.bn.bias_quantized_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST11.bn.bias_quantized_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.bn.bias_quantized: 32 params, 0.12 KB
# HtrgGAT_layer_ST22.bn.bias_quantized_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST22.bn.bias_quantized_zero_point: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.bn.bias_quantized: 32 params, 0.12 KB
# HtrgGAT_layer_ST12.bn.bias_quantized_scale: 1 params, 0.00 KB
# HtrgGAT_layer_ST12.bn.bias_quantized_zero_point: 1 params, 0.00 KB
# out_layer.bias_quantized: 2 params, 0.01 KB
# out_layer.bias_quantized_scale: 2 params, 0.01 KB
# out_layer.bias_quantized_zero_point: 2 params, 0.01 KB
#
# Total parameters: 309792
# Total weights size: 0.32 MB

# %%
import onnxruntime as ort
import torch
import numpy as np
import soundfile as sf
from scipy.signal import resample
import torch.nn.functional as F

def load_audio(path: str, target_sr: int = 16000) -> np.ndarray:
    wav, sr = sf.read(path)
    if sr != target_sr:
        num = int(len(wav) * float(target_sr) / sr)
        wav = resample(wav, num)
    # If stereo, take mean to mono
    if wav.ndim > 1:
        wav = wav.mean(axis=1)
    return wav

# ────────────────────────────────────────────────────────────
# 1. Load and preprocess audio
# ────────────────────────────────────────────────────────────
audio_path = "/content/aasist/LA/ASVspoof2019_LA_eval/flac/LA_E_5849185.flac"
wav = load_audio(audio_path, target_sr=16000)

# ONNX Runtime expects a NumPy array of shape (batch, num_samples)
input_data = wav.astype(np.float32)[None, :]  # shape = (1, 16000)
# input_data = torch.from_numpy(wav).float().unsqueeze(0)

# ────────────────────────────────────────────────────────────
# 2. Create an ONNX Runtime session
# ────────────────────────────────────────────────────────────
session = ort.InferenceSession("aasist_quantized.onnx", providers=["CPUExecutionProvider"])

# ────────────────────────────────────────────────────────────
# 3. Run inference
# ────────────────────────────────────────────────────────────
# Make sure these names match the ones you used in torch.onnx.export
output_names = ["embedding", "logits"]
embedding, logits = session.run(output_names, {"input": input_data})

# ────────────────────────────────────────────────────────────
# 4. Post-process logits into probabilities & decision
# ────────────────────────────────────────────────────────────
# logits shape: (1, 2)  →  [spoof_score, bona-fide_score]
probs = F.softmax(torch.from_numpy(logits), dim=1).numpy()[0]
pred_label = "bona-fide" if probs[1] > probs[0] else "spoof"

print(f"Embedding shape: {embedding.shape}")
print(f"Logits:          {logits}")
print(f"Probabilities:   spoof={probs[0]:.4f}, bona-fide={probs[1]:.4f}")
print(f"→ Decision:      {pred_label}")
# Out:
# Embedding shape: (1, 160)
# Logits:          [[-5.452677   3.8065858]]
# Probabilities:   spoof=0.0001, bona-fide=0.9999
# → Decision:      bona-fide

# %%
# !python inference_onnx.py \
  --onnx_model_path     aasist.onnx \
  --audio_path     LA/ASVspoof2019_LA_eval/flac/LA_E_5849185.flac
# Out:
# Output:          [[-5.3730516  3.8038929]]
# Predicted class:      Bona-fide

# %%
import os

def count_identical_filenames(folder1, folder2):
    # List all files in both folders
    files1 = set(os.listdir(folder1))
    files2 = set(os.listdir(folder2))

    # Find intersection (identical filenames)
    identical_files = files1.intersection(files2)

    print(f"Identical filenames ({len(identical_files)}):")
    for filename in identical_files:
        print(filename)

    return len(identical_files)

# Example usage
folder_path_1 = '/content/drive/MyDrive/Researches/Anti spoofing/aasist/toy_example/eval'
folder_path_2 = '/content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations'
count = count_identical_filenames(folder_path_1, folder_path_2)
print(f"Total identical filenames: {count}")
# Out:
# Identical filenames (0):
# Total identical filenames: 0

# %%
# --- Google Colab cell: build calibration/evaluation splits from protocol and copy files ---

import os
import re
import random
import shutil
from collections import defaultdict, Counter
from pathlib import Path

# =========================
# User parameters
# =========================
AUDIO_ROOT = "/content/drive/MyDrive/Scientific Projects/University of Stuttgart/ASVSpoof Datasets/2019/LA/ASVspoof2019_LA_dev/flac"   # Root folder containing audio files (recursively)
PROTOCOL_TXT = "/content/drive/MyDrive/Scientific Projects/University of Stuttgart/ASVSpoof Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.dev.trl.txt" # Path to the protocol .txt
OUTPUT_ROOT = "/content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment"                # Where to create the output folders
AUDIO_EXTS = {".flac", ".wav"}                 # Accepted audio extensions
RANDOM_SEED = 1337                             # Seed for reproducibility
# =========================

# Output folders
OUT_CAL1 = "Calibration_1_bonafide_100"
OUT_CAL2 = "Calibration_2_A01-A06_20_each"
OUT_CAL3 = "Calibration_3_train_20_each"
OUT_CAL7 = "Calibration_7_train_150_random"
# OUT_EVAL = "Evaluation_100_unique"

random.seed(RANDOM_SEED)
Path(OUTPUT_ROOT).mkdir(parents=True, exist_ok=True)

# 1) Index all available audio by stem -> full path
audio_index = {}
for p in Path(AUDIO_ROOT).rglob("*"):
    if p.is_file() and p.suffix.lower() in AUDIO_EXTS:
        audio_index[p.stem] = str(p.resolve())

print(f"Indexed {len(audio_index)} audio files by stem from {AUDIO_ROOT}")

# 2) Parse protocol
# Lines look like:
# LA_0039 LA_E_2834763 - A11 spoof
# LA_0033 LA_E_4581379 - - bonafide
def parse_line(line: str):
    toks = line.strip().split()
    if len(toks) < 2:
        return None
    # robust parsing
    # expected positions:
    # toks[1] -> filename stem
    # toks[-1] -> class token (spoof or bonafide)
    # toks[3] -> attacker type if spoof, otherwise '-'
    fname_stem = toks[1]
    label_tok = toks[-1].lower()
    # handle possible misspelling in some lists: 'bonfide'
    is_bonafide = label_tok.startswith("bona") or label_tok == "bonafide"
    label = "bonafide" if is_bonafide else "spoof"

    attacker = None
    if label == "spoof":
        # Try to read the 4th token safely
        attacker = toks[3] if len(toks) >= 4 else None
        # Normalize attacker to format A01..A19 etc.
        if attacker is not None and not re.match(r"^A\d{2}$", attacker):
            attacker = None
    return fname_stem, label, attacker

records = []
with open(PROTOCOL_TXT, "r", encoding="utf-8", errors="ignore") as f:
    for line in f:
        line = line.strip()
        if not line or line.startswith("#"):
            continue
        parsed = parse_line(line)
        if parsed is None:
            continue
        stem, label, attacker = parsed
        # Only keep entries that actually exist on disk
        if stem in audio_index:
            records.append({"stem": stem, "path": audio_index[stem], "label": label, "attacker": attacker})

print(f"Protocol matched {len(records)} files on disk")

# 3) Collect sets for selection
bonafide = [r for r in records if r["label"] == "bonafide"]
spoof = [r for r in records if r["label"] == "spoof"]
by_attacker = defaultdict(list)
for r in spoof:
    if r["attacker"] is not None:
        by_attacker[r["attacker"]].append(r)

# Helper to sample without replacement with safety checks
def sample_items(items, k):
    if k <= 0:
        return []
    if len(items) <= k:
        # Take all if not enough, and warn
        print(f"Warning: requested {k} but only {len(items)} available. Taking all.")
        return list(items)
    return random.sample(items, k)

# 4) Build selections
selected = set()  # stems already used

# Calibration 1: only bonafide, 100 samples
cal1 = sample_items([r for r in bonafide if r["stem"] not in selected], 100)
for r in cal1:
    selected.add(r["stem"])

# Calibration 2: only attacker types A01-A06, 100 samples, selected equally in quantity
target_attackers = [f"A{n:02d}" for n in range(1, 7)]  # A01..A06
# Compute near-equal targets that sum to 100
base = 100 // len(target_attackers)  # 16
rem = 100 % len(target_attackers)    # 4
targets = {atk: base + (1 if i < rem else 0) for i, atk in enumerate(target_attackers)}

cal2 = []
# for i, atk in enumerate(target_attackers):
#     pool = [r for r in by_attacker.get(atk, []) if r["stem"] not in selected]
#     need = targets[atk]
#     pick = sample_items(pool, need)
#     cal2.extend(pick)
#     for r in pick:
#         selected.add(r["stem"])

# # If still short of 100 due to scarcity, top-up from remaining A01-A06
# if len(cal2) < 100:
#     remaining_pool = [r for atk in target_attackers for r in by_attacker.get(atk, []) if r["stem"] not in selected]
#     topup = sample_items(remaining_pool, 100 - len(cal2))
#     cal2.extend(topup)
#     for r in topup:
#         selected.add(r["stem"])
for atk in target_attackers:
    pool = [r for r in by_attacker.get(atk, []) if r["stem"] not in selected]
    pick = sample_items(pool, 20)
    cal2.extend(pick)
    for r in pick:
        selected.add(r["stem"])

# Calibration 3: bonafide AND A01-A06 spoof, 20 samples each class
cal3 = []

# 20 bonafide samples
pool_bonafide = [r for r in bonafide if r["stem"] not in selected]
pick_bonafide = sample_items(pool_bonafide, 20)
cal3.extend(pick_bonafide)
for r in pick_bonafide:
    selected.add(r["stem"])

# 20 for each attacker type A01-A06
for atk in target_attackers:
    pool = [r for r in by_attacker.get(atk, []) if r["stem"] not in selected]
    pick = sample_items(pool, 20)
    cal3.extend(pick)
    for r in pick:
        selected.add(r["stem"])

# Calibration 7: 150 random samples from the entire dataset (any class)
cal7 = []
cal7 = sample_items([r for r in records if r["stem"] not in selected], 150)
for r in cal7:
    selected.add(r["stem"])

# Evaluation: 100 random samples not included above, any class
# remaining_pool = [r for r in records if r["stem"] not in selected]
# eval_set = sample_items(remaining_pool, 100)
# for r in eval_set:
#     selected.add(r["stem"])

# 5) Create output folders and copy files
def copy_set(name, items):
    out_dir = Path(OUTPUT_ROOT) / name
    out_dir.mkdir(parents=True, exist_ok=True)
    for r in items:
        dst = out_dir / f"{Path(r['path']).name}"
        shutil.copy2(r["path"], dst)
    return out_dir

out1 = copy_set(OUT_CAL1, cal1)
out2 = copy_set(OUT_CAL2, cal2)
out3 = copy_set(OUT_CAL3, cal3)
out7 = copy_set(OUT_CAL7, cal7)
# out4 = copy_set(OUT_EVAL, eval_set)

# 6) Summaries
def summarize(tag, items):
    c_label = Counter([r["label"] for r in items])
    c_atk = Counter([r["attacker"] for r in items if r["attacker"]])
    print(f"\n[{tag}] count = {len(items)}")
    print("  Labels:", dict(c_label))
    if c_atk:
        # show A01..A06 in order if applicable
        ordered = {k: c_atk.get(k, 0) for k in sorted(c_atk.keys())}
        print("  Attackers:", ordered)

summarize(OUT_CAL1, cal1)
summarize(OUT_CAL2, cal2)
summarize(OUT_CAL3, cal3)
summarize(OUT_CAL7, cal7)
# summarize(OUT_EVAL, eval_set)

print("\nDone.")
print(f"Output root: {OUTPUT_ROOT}")
print(f"Folders created:\n - {out1}\n - {out2}\n - {out3}\n - {out7}")
# Out:
# Indexed 22275 audio files by stem from /content/drive/MyDrive/Scientific Projects/University of Stuttgart/ASVSpoof Datasets/2019/LA/ASVspoof2019_LA_dev/flac
# Protocol matched 22146 files on disk
#
# [Calibration_1_bonafide_100] count = 100
#   Labels: {'bonafide': 100}
#
# [Calibration_2_A01-A06_20_each] count = 120
#   Labels: {'spoof': 120}
#   Attackers: {'A01': 20, 'A02': 20, 'A03': 20, 'A04': 20, 'A05': 20, 'A06': 20}
#
# [Calibration_3_train_20_each] count = 140
#   Labels: {'bonafide': 20, 'spoof': 120}
#   Attackers: {'A01': 20, 'A02': 20, 'A03': 20, 'A04': 20, 'A05': 20, 'A06': 20}
#
# [Calibration_7_train_150_random] count = 150
#   Labels: {'bonafide': 13, 'spoof': 137}
#   Attackers: {'A01': 25, 'A02': 21, 'A03': 22, 'A04': 22, 'A05': 21, 'A06': 26}
#
# Done.
# Output root: /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment
# Folders created:
#  - /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment/Calibration_1_bonafide_100
#  - /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment/Calibration_2_A01-A06_20_each
#  - /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment/Calibration_3_train_20_each
#  - /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment/Calibration_7_train_150_random

# %%
# %cd /content/drive/MyDrive/Researches/Anti spoofing/aasist
import os
import numpy as np
import onnxruntime
from onnxruntime.quantization import QuantFormat, QuantType, StaticQuantConfig, CalibrationMethod, CalibrationDataReader, quantize
import soundfile as sf
from scipy.signal import resample

# Paths
input_model_path = 'aasist_optimized.onnx'
output_model_path = 'aasist_quantized_scheme_8.onnx'
calibration_dataset_path = '/content/drive/MyDrive/Researches/Anti spoofing/aasist/toy_example/eval'  # folder with audio files

# Load audio with same preprocessing as inference script
def _preprocess_audio(file_path: str, target_sr: int = 16000) -> np.ndarray:
    wav, sr = sf.read(file_path)

    # Resample if needed
    if sr != target_sr:
        num = int(len(wav) * float(target_sr) / sr)
        wav = resample(wav, num)

    # Collapse to mono
    if wav.ndim > 1:
        wav = wav.mean(axis=1)

    # Normalize to [-1, 1]
    # max_val = np.max(np.abs(wav))
    # if max_val > 0:
    #     wav = wav / max_val

    return wav.astype(np.float32)[None, :]  # shape (1, num_samples)

class AudioDataReader(CalibrationDataReader):
    def __init__(self, calibration_folder: str, model_path: str):
        self.enum_data = None
        self.audio_files = [os.path.join(calibration_folder, f)
                            for f in os.listdir(calibration_folder)
                            if f.lower().endswith(('.wav', '.flac'))]
        self.input_name = onnxruntime.InferenceSession(model_path).get_inputs()[0].name
        self.audio_data_list = [_preprocess_audio(f) for f in self.audio_files]
        self.datasize = len(self.audio_data_list)

    def get_next(self):
        if self.enum_data is None:
            self.enum_data = iter(
                [{self.input_name: audio} for audio in self.audio_data_list]
            )
        return next(self.enum_data, None)

    def rewind(self):
        self.enum_data = None

# Instantiate DataReader
dr = AudioDataReader(calibration_dataset_path, input_model_path)

# Define quantization configuration
conf = StaticQuantConfig(
    calibration_data_reader=dr,
    quant_format=QuantFormat.QDQ,
    calibrate_method=CalibrationMethod.MinMax,
    # calibration_providers='CUDAExecutionProvider',
    # optimize_model=True, # Removed unsupported argument
    activation_type=QuantType.QUInt8,
    weight_type=QuantType.QInt8,
    per_channel=True,
    extra_options={"ActivationSymmetric":False,
                  "WeightSymmetric":True}
)

# Run quantization
quantize(input_model_path, output_model_path, conf)
print(f"Quantized model saved to {output_model_path}")
# Out:
# /content/drive/MyDrive/Researches/Anti spoofing/aasist
# WARNING:root:Axis 1 is out-of-range for weight 'first_bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'GAT_layer_S.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'GAT_layer_T.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'HtrgGAT_layer_ST21.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'HtrgGAT_layer_ST11.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'HtrgGAT_layer_ST22.bn.weight' with rank 1
# WARNING:root:Axis 1 is out-of-range for weight 'HtrgGAT_layer_ST12.bn.weight' with rank 1
# Quantized model saved to aasist_quantized_scheme_8.onnx

# %%
# --- Google Colab cell: create Calibration 4, Calibration 5, and a new Evaluation set ---

import os
import re
import random
import shutil
from collections import defaultdict, Counter
from pathlib import Path

# =========================
# User parameters
# =========================
AUDIO_ROOT = "/content/drive/MyDrive/Scientific Projects/University of Stuttgart/ASVSpoof Datasets/2019/LA/ASVspoof2019_LA_eval/flac"   # Root folder containing audio files (recursively)
PROTOCOL_TXT = "/content/drive/MyDrive/Scientific Projects/University of Stuttgart/ASVSpoof Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt" # Path to the protocol .txt
OUTPUT_ROOT = "/content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment"                # Root where calibration folders were or will be created
AUDIO_EXTS = {".flac", ".wav"}                 # Accepted audio extensions
RANDOM_SEED = 1337                             # Seed for reproducibility
# =========================

# New output folders
OUT_CAL4 = "Calibration_4_A07-A19_20_each"
OUT_CAL5 = "Calibration_5_bonafide_20_plus_A07-A19_20_each"
OUT_EVAL = "Evaluation_500_unique_to_all_calibrations"

random.seed(RANDOM_SEED)
Path(OUTPUT_ROOT).mkdir(parents=True, exist_ok=True)

# Helper: index audio by stem
audio_index = {}
for p in Path(AUDIO_ROOT).rglob("*"):
    if p.is_file() and p.suffix.lower() in AUDIO_EXTS:
        audio_index[p.stem] = str(p.resolve())
print(f"Indexed {len(audio_index)} audio files by stem from {AUDIO_ROOT}")

# Parse protocol lines like:
# LA_0039 LA_E_2834763 - A11 spoof
# LA_0033 LA_E_4581379 - - bonafide
def parse_line(line: str):
    toks = line.strip().split()
    if len(toks) < 2:
        return None
    fname_stem = toks[1]
    label_tok = toks[-1].lower()
    is_bonafide = label_tok.startswith("bona") or label_tok == "bonafide"
    label = "bonafide" if is_bonafide else "spoof"
    attacker = None
    if label == "spoof":
        attacker = toks[3] if len(toks) >= 4 else None
        if attacker is not None and not re.match(r"^A\d{2}$", attacker):
            attacker = None
    return fname_stem, label, attacker

# Build records that exist on disk
records = []
with open(PROTOCOL_TXT, "r", encoding="utf-8", errors="ignore") as f:
    for line in f:
        line = line.strip()
        if not line or line.startswith("#"):
            continue
        parsed = parse_line(line)
        if not parsed:
            continue
        stem, label, attacker = parsed
        if stem in audio_index:
            records.append({"stem": stem, "path": audio_index[stem], "label": label, "attacker": attacker})

print(f"Protocol matched {len(records)} files on disk")

# Split helpers
bonafide = [r for r in records if r["label"] == "bonafide"]
spoof = [r for r in records if r["label"] == "spoof"]
by_attacker = defaultdict(list)
for r in spoof:
    if r["attacker"]:
        by_attacker[r["attacker"]].append(r)

# Build a set of stems already used in any existing Calibration_* folders to keep uniqueness
selected = set()
for d in Path(OUTPUT_ROOT).glob("Calibration_*"):
    if d.is_dir():
        for f in d.iterdir():
            if f.is_file():
                selected.add(f.stem)

print(f"Found {len(selected)} already-selected stems from existing calibration folders in {OUTPUT_ROOT}")

# Sampling helper with safety
def sample_items(items, k):
    pool = list(items)
    if k <= 0:
        return []
    if len(pool) <= k:
        if len(pool) < k:
            print(f"Warning: requested {k} but only {len(pool)} available. Taking all.")
        return pool
    return random.sample(pool, k)

# Copy helper
def copy_set(name, items):
    out_dir = Path(OUTPUT_ROOT) / name
    out_dir.mkdir(parents=True, exist_ok=True)
    for r in items:
        shutil.copy2(r["path"], out_dir / Path(r["path"]).name)
    return out_dir

# Summarize helper
def summarize(tag, items):
    from collections import Counter
    c_label = Counter([r["label"] for r in items])
    c_atk = Counter([r["attacker"] for r in items if r["attacker"]])
    print(f"\n[{tag}] count = {len(items)}")
    print("  Labels:", dict(c_label))
    if c_atk:
        ordered = {k: c_atk.get(k, 0) for k in sorted(c_atk.keys())}
        print("  Attackers:", ordered)

# =========================
# Calibration 4: A07-A19, 20 samples each attacker
# =========================
target_attackers_07_19 = [f"A{n:02d}" for n in range(7, 20)]  # A07..A19 inclusive

cal4 = []
for atk in target_attackers_07_19:
    pool = [r for r in by_attacker.get(atk, []) if r["stem"] not in selected]
    pick = sample_items(pool, 20)  # fixed 20 per attacker
    cal4.extend(pick)
    for r in pick:
        selected.add(r["stem"])

out4 = copy_set(OUT_CAL4, cal4)
summarize(OUT_CAL4, cal4)

# =========================
# Calibration 5: Bonafide 20 + spoof A07-A19, 20 each
# =========================
cal5 = []

# Bonafide 20
pool_bona = [r for r in bonafide if r["stem"] not in selected]
pick_bona = sample_items(pool_bona, 20)
cal5.extend(pick_bona)
for r in pick_bona:
    selected.add(r["stem"])

# Spoof A07-A19, 20 each attacker
for atk in target_attackers_07_19:
    pool = [r for r in by_attacker.get(atk, []) if r["stem"] not in selected]
    pick = sample_items(pool, 20)
    cal5.extend(pick)
    for r in pick:
        selected.add(r["stem"])

out5 = copy_set(OUT_CAL5, cal5)
summarize(OUT_CAL5, cal5)

# =========================
# Evaluation: 500 random, unique to all calibration folders
# =========================
remaining_pool = [r for r in records if r["stem"] not in selected]
eval_set = sample_items(remaining_pool, 500)
out_eval = copy_set(OUT_EVAL, eval_set)
summarize(OUT_EVAL, eval_set)

print("\nDone.")
print(f"Output root: {OUTPUT_ROOT}")
print(f"Folders created:\n - {out4}\n - {out5}\n - {out_eval}")
# Out:
# Indexed 71933 audio files by stem from /content/drive/MyDrive/Scientific Projects/University of Stuttgart/ASVSpoof Datasets/2019/LA/ASVspoof2019_LA_eval/flac
# Protocol matched 71237 files on disk
# Found 510 already-selected stems from existing calibration folders in /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment
#
# [Calibration_4_A07-A19_20_each] count = 260
#   Labels: {'spoof': 260}
#   Attackers: {'A07': 20, 'A08': 20, 'A09': 20, 'A10': 20, 'A11': 20, 'A12': 20, 'A13': 20, 'A14': 20, 'A15': 20, 'A16': 20, 'A17': 20, 'A18': 20, 'A19': 20}
#
# [Calibration_5_bonafide_20_plus_A07-A19_20_each] count = 280
#   Labels: {'bonafide': 20, 'spoof': 260}
#   Attackers: {'A07': 20, 'A08': 20, 'A09': 20, 'A10': 20, 'A11': 20, 'A12': 20, 'A13': 20, 'A14': 20, 'A15': 20, 'A16': 20, 'A17': 20, 'A18': 20, 'A19': 20}
#
# [Evaluation_500_unique_to_all_calibrations] count = 500
#   Labels: {'spoof': 434, 'bonafide': 66}
#   Attackers: {'A07': 27, 'A08': 40, 'A09': 43, 'A10': 29, 'A11': 33, 'A12': 37, 'A13': 34, 'A14': 36, 'A15': 24, 'A16': 27, 'A17': 33, 'A18': 35, 'A19': 36}
#
# Done.
# Output root: /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment
# Folders created:
#  - /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment/Calibration_4_A07-A19_20_each
#  - /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment/Calibration_5_bonafide_20_plus_A07-A19_20_each
#  - /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations

# %%
# %cd /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment
# --- Google Colab cell: Combine Calibration 2 and Calibration 5 into Calibration 6 ---

import shutil
from pathlib import Path

# =========================
# User parameters
# =========================
OUTPUT_ROOT = "/content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment"  # Root containing existing calibration folders
CAL2_NAME = "Calibration_2_A01-A06_equal_100"
CAL5_NAME = "Calibration_5_bonafide_20_plus_A07-A19_20_each"
CAL6_NAME = "Calibration_6_combined_cal2_cal5"
# =========================

# Paths
cal2_path = Path(OUTPUT_ROOT) / CAL2_NAME
cal5_path = Path(OUTPUT_ROOT) / CAL5_NAME
cal6_path = Path(OUTPUT_ROOT) / CAL6_NAME
cal6_path.mkdir(parents=True, exist_ok=True)

# Collect unique files from both folders (by stem to avoid duplicates)
seen_stems = set()
copied_count = 0

for src_folder in [cal2_path, cal5_path]:
    if not src_folder.exists():
        print(f"Warning: {src_folder} does not exist, skipping...")
        continue
    for file in src_folder.iterdir():
        if file.is_file():
            if file.stem not in seen_stems:
                shutil.copy2(file, cal6_path / file.name)
                seen_stems.add(file.stem)
                copied_count += 1

print(f"Calibration 6 created at: {cal6_path}")
print(f"Total unique files copied: {copied_count}")
# Out:
# /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment
# Warning: /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment/Calibration_2_A01-A06_equal_100 does not exist, skipping...
# Calibration 6 created at: /content/drive/MyDrive/Researches/Anti spoofing/aasist/experiment/Calibration_6_combined_cal2_cal5
# Total unique files copied: 280

# %%
# --- Google Colab cell: analyze folder and count classes from a protocol file ---

import os
import re
from collections import defaultdict, Counter
from pathlib import Path
import csv

# =========================
# User parameters
# =========================
AUDIO_ROOT = "/content/aasist/toy_example/eval"   # Root folder containing audio files (recursively)
PROTOCOL_TXT = "/content/aasist/toy_example/protocol.txt" # Path to protocol .txt
AUDIO_EXTS = {".flac", ".wav"}                 # Accepted audio extensions
EXPORT_CSV = False                               # Set to True to write CSV summaries
OUTPUT_DIR = "/content/analysis_out"            # Where to save CSV files if EXPORT_CSV is True
# =========================

Path(OUTPUT_DIR).mkdir(parents=True, exist_ok=True)

# 1) Index audio files by stem
audio_index = {}
for p in Path(AUDIO_ROOT).rglob("*"):
    if p.is_file() and p.suffix.lower() in AUDIO_EXTS:
        audio_index[p.stem] = str(p.resolve())

print(f"Indexed {len(audio_index)} audio files by stem from: {AUDIO_ROOT}")

# 2) Protocol parsing
# Example lines:
# LA_0039 LA_E_2834763 - A11 spoof
# LA_0033 LA_E_4581379 - - bonafide
def parse_line(line: str):
    toks = line.strip().split()
    if len(toks) < 2:
        return None
    stem = toks[1]
    cls_tok = toks[-1].lower()
    is_bonafide = cls_tok.startswith("bona") or cls_tok == "bonfide"
    label = "bonafide" if is_bonafide else "spoof"
    attacker = None
    if label == "spoof":
        attacker = toks[3] if len(toks) >= 4 else None
        # Normalize only Axx patterns
        if attacker is not None and not re.match(r"^A\d{2}$", attacker):
            attacker = None
    return stem, label, attacker

records = []
all_protocol_stems = set()
with open(PROTOCOL_TXT, "r", encoding="utf-8", errors="ignore") as f:
    for line in f:
        line = line.strip()
        if not line or line.startswith("#"):
            continue
        parsed = parse_line(line)
        if not parsed:
            continue
        stem, label, attacker = parsed
        all_protocol_stems.add(stem)
        if stem in audio_index:
            records.append({"stem": stem, "path": audio_index[stem], "label": label, "attacker": attacker})

print(f"Protocol entries on disk: {len(records)}")
missing_from_disk = sorted(all_protocol_stems - set(r["stem"] for r in records))
print(f"Protocol stems missing on disk: {len(missing_from_disk)}")

# 3) Counting
total = len(records)
count_label = Counter(r["label"] for r in records)
count_attacker = Counter(r["attacker"] for r in records if r["attacker"])

def pct(x, n):
    return 0.0 if n == 0 else 100.0 * x / n

print("\n=== Summary ===")
print(f"Total matched files: {total}")
print(f"Bonafide: {count_label.get('bonafide', 0)} ({pct(count_label.get('bonafide', 0), total):.2f}%)")
print(f"Spoof:    {count_label.get('spoof', 0)} ({pct(count_label.get('spoof', 0), total):.2f}%)")

# Print per-attacker distribution sorted by attacker code
if count_attacker:
    print("\nPer-attacker counts among spoof:")
    for atk in sorted(count_attacker.keys()):
        print(f"  {atk}: {count_attacker[atk]}")

# 4) Optional CSV exports
if EXPORT_CSV:
    # CSV 1: per class counts
    cls_csv = Path(OUTPUT_DIR) / "class_counts.csv"
    with open(cls_csv, "w", newline="") as f:
        w = csv.writer(f)
        w.writerow(["class", "count", "percent"])
        for cls in ("bonafide", "spoof"):
            c = count_label.get(cls, 0)
            w.writerow([cls, c, f"{pct(c, total):.2f}"])
    print(f"\nSaved: {cls_csv}")

    # CSV 2: per attacker counts
    atk_csv = Path(OUTPUT_DIR) / "attacker_counts.csv"
    with open(atk_csv, "w", newline="") as f:
        w = csv.writer(f)
        w.writerow(["attacker", "count"])
        for atk in sorted(count_attacker.keys()):
            w.writerow([atk, count_attacker[atk]])
    print(f"Saved: {atk_csv}")

    # CSV 3: detailed matched list
    det_csv = Path(OUTPUT_DIR) / "matched_files_detailed.csv"
    with open(det_csv, "w", newline="") as f:
        w = csv.writer(f)
        w.writerow(["stem", "label", "attacker", "path"])
        for r in sorted(records, key=lambda x: (x["label"], x["attacker"] or "A00", x["stem"])):
            w.writerow([r["stem"], r["label"], r["attacker"] or "", r["path"]])
    print(f"Saved: {det_csv}")

    # CSV 4: protocol stems missing on disk
    miss_csv = Path(OUTPUT_DIR) / "protocol_missing_on_disk.csv"
    with open(miss_csv, "w", newline="") as f:
        w = csv.writer(f)
        w.writerow(["missing_stem"])
        for s in missing_from_disk:
            w.writerow([s])
    print(f"Saved: {miss_csv}")

print("\nDone.")
# Out:
# Indexed 150 audio files by stem from: /content/aasist/toy_example/eval
# Protocol entries on disk: 150
# Protocol stems missing on disk: 150
#
# === Summary ===
# Total matched files: 150
# Bonafide: 16 (10.67%)
# Spoof:    134 (89.33%)
#
# Per-attacker counts among spoof:
#   A07: 7
#   A08: 11
#   A09: 9
#   A10: 10
#   A11: 14
#   A12: 6
#   A13: 6
#   A14: 15
#   A15: 10
#   A16: 12
#   A17: 13
#   A18: 12
#   A19: 9
#
# Done.

# %%
# %cd /content/drive/MyDrive/Researches/Anti_spoofing/aasist
# !python evaluate_calib_schemes.py \
    --onnx_model_path aasist_quantized_scheme_1.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme1.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/drive/MyDrive/Researches/Anti_spoofing/aasist
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=264, TN=65, FP=0, FN=171
# Accuracy: 0.6580
# FPR: 0.0000   FNR: 0.3931   EER: 0.1966
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme1.png

# %%
# %cd /content/drive/MyDrive/Researches/Anti_spoofing/aasist
# !python evaluate_calib_schemes.py \
    --onnx_model_path aasist_quantized_scheme_2.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme2.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/drive/MyDrive/Researches/Anti_spoofing/aasist
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=320, TN=65, FP=0, FN=115
# Accuracy: 0.7700
# FPR: 0.0000   FNR: 0.2644   EER: 0.1322
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme2.png

# %%
# %cd /content/drive/MyDrive/Researches/Anti_spoofing/aasist
# !python evaluate_calib_schemes.py \
    --onnx_model_path aasist_quantized_scheme_3.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme3.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/drive/MyDrive/Researches/Anti_spoofing/aasist
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=99, TN=65, FP=0, FN=336
# Accuracy: 0.3280
# FPR: 0.0000   FNR: 0.7724   EER: 0.3862
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme3.png

# %%
# %cd /content/drive/MyDrive/Researches/Anti_spoofing/aasist
# !python evaluate_calib_schemes.py \
    --onnx_model_path aasist_quantized_scheme_4.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme4.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/drive/MyDrive/Researches/Anti_spoofing/aasist
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=171, TN=65, FP=0, FN=264
# Accuracy: 0.4720
# FPR: 0.0000   FNR: 0.6069   EER: 0.3034
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme4.png

# %%
# %cd /content/drive/MyDrive/Researches/Anti_spoofing/aasist
# !python evaluate_calib_schemes.py \
    --onnx_model_path aasist_quantized_scheme_5.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme5.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/drive/MyDrive/Researches/Anti_spoofing/aasist
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=169, TN=65, FP=0, FN=266
# Accuracy: 0.4680
# FPR: 0.0000   FNR: 0.6115   EER: 0.3057
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme5.png

# %%
# %cd /content/drive/MyDrive/Researches/Anti_spoofing/aasist
# !python evaluate_calib_schemes.py \
    --onnx_model_path aasist_quantized_scheme_6.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme6.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/drive/MyDrive/Researches/Anti_spoofing/aasist
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=169, TN=65, FP=0, FN=266
# Accuracy: 0.4680
# FPR: 0.0000   FNR: 0.6115   EER: 0.3057
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme6.png

# %%
# %cd /content/drive/MyDrive/Researches/Anti_spoofing/aasist
# !python evaluate_calib_schemes.py \
    --onnx_model_path aasist_quantized_scheme_7.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme7.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/drive/MyDrive/Researches/Anti_spoofing/aasist
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=130, TN=65, FP=0, FN=305
# Accuracy: 0.3900
# FPR: 0.0000   FNR: 0.7011   EER: 0.3506
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme7.png

# %%
# %cd /content/drive/MyDrive/Researches/Anti_spoofing/aasist
# !python evaluate_calib_schemes.py \
    --onnx_model_path aasist_quantized_scheme_8.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme8.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/drive/MyDrive/Researches/Anti_spoofing/aasist
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=312, TN=65, FP=0, FN=123
# Accuracy: 0.7540
# FPR: 0.0000   FNR: 0.2828   EER: 0.1414
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/scheme8.png

# %%
# %cd /content/drive/MyDrive/Researches/Anti_spoofing/aasist
# !python evaluate_calib_schemes.py \
    --onnx_model_path aasist.onnx \
    --audio_folder /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/Evaluation_500_unique_to_all_calibrations \
    --save_plot /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/original.png \
    --protocol_path /content/drive/MyDrive/Scientific_Projects/University_of_Stuttgart/ASVSpoof_Datasets/2019/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt
# Out:
# /content/drive/MyDrive/Researches/Anti_spoofing/aasist
#
# ------------------------------------------------------------
# Evaluated 500 files.
# TP=358, TN=65, FP=0, FN=77
# Accuracy: 0.8460
# FPR: 0.0000   FNR: 0.1770   EER: 0.0885
# Confusion matrix saved to: /content/drive/MyDrive/Researches/Anti_spoofing/aasist/experiment/original.png
